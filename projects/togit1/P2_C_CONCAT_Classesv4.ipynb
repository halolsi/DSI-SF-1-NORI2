# %%
def df_string_list(str_p):
#str_p = df_subO_EP3_['Classes'][0][1:]
    str_p = str_p.replace('[','')
    str_p = str_p.replace(']','')

    strs = str_p.split(', ')
    return strs

def df_string_listB(str_p):
    try:
        strs = str_p.split('-')
    except:
        strs = ''
    return strs

# %% [markdown]
# ### IMPORT CSV file for Organism/Classes Dataframe

# %%
import pandas as pd

df_sub_ = pd.read_csv('./out_CLASSES_utf_DOMAIN.csv', encoding='utf-8', sep=',')
df_sub_.head(2)

def df_string_listC(str_p):
    try:
        strs = str_p.split(', ')
    except:
        strs = ''
    return strs

df_sub_['Classes'] = df_sub_.Classes.map(lambda x: df_string_listC(x))

df_sub_['Classes'].loc[0] #[2]
# Out:
# [u'[[',
#  u'Deinococcus',
#  u'Deinococcaceae',
#  u'Deinococcales',
#  u'Deinococci',
#  u'Deinococcus',
#  u'Thermus',
#  u'Bacteria',
#  u'cellular organisms',
#  u'life0]]']

# %%
import numpy as np #############THIS TAKES TIME, PROBABLY SHOULD PICKLE THIS##############

# df_classesB['Taxon'] = ''

# print len(df_classesB)

# for i in df_classesB.index.values:
#     #print i
#     try:
#         df_classesB['Taxon'][i] = str(main_match([df_classesB['Names'][i]])) #API for Taxon in Open Tree!!!
#     except:
#         pass

# df_classesB.tail(10)

# %%
# READ in CSV file Taxonomy dataframe (Names of Taxons)
import pandas as pd

df_TAXONOMY = pd.read_csv('./out_TAXONOMY.csv', encoding='utf-8', sep=',')
df_TAXONOMY.head(5)
# Out:
#    Unnamed: 0                   Names  Classes    Taxon
# 0         996             Oligotropha        1    genus
# 1        1336                  Gallus        1    genus
# 2        1335             Viviparidae        1   family
# 3        1334  Aneurinibacillus group        1  no rank
# 4        1333                   Apini        1    tribe

# %%
################ CLASS COUNTS for list to REMOVE TAXONOMIES that occur less than 12x

df_classesB = df_TAXONOMY
df_classesB = df_classesB[df_classesB['Classes'] >= 10] #Mask for Classes with >= 10 counts

df_classesB['Names'] = df_classesB['Names'].map(lambda x: str(x))


df_TAXONOMY = df_classesB
df_TAXONOMY.head(3)
# Out:
# /Users/noriogura/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       Unnamed: 0             Names  Classes   Taxon
# 1718         253  Thermoproteaceae       10  family
# 1719         257      Natrialbales       10   order
# 1720         256    Thaumarchaeota       10  phylum

# %%
df_TAXONOMY[df_TAXONOMY['Taxon']=='domain']
# Out:
#       Unnamed: 0      Names  Classes   Taxon
# 1980          13    Archaea      179  domain
# 1981          12  Eukaryota      207  domain
# 1989           4   Bacteria     1968  domain

# %%
len(df_TAXONOMY[df_TAXONOMY['Taxon']=='phylum'])
# Out:
# 23

# %%
#Group by Taxons:

group_with_Names = pd.DataFrame(df_TAXONOMY.groupby(['Taxon','Names'], as_index = False).sum())
group_just_Taxon = df_TAXONOMY['Classes'].groupby(df_TAXONOMY['Taxon']).sum()
#df_Taxon = pd.DataFrame(group.sum())

# %%
group_just_Taxon
# Out:
# Taxon
# class                 1800
# domain                2354
# family                1281
# genus                  671
# infraclass              27
# infrakingdom            22
# infraorder              11
# kingdom                173
# no rank               3969
# no rank - terminal     193
# order                 1819
# parvorder               10
# phylum                2419
# subclass                60
# suborder                11
# subphylum               15
# superclass             110
# superorder              15
# tribe                   26
# Name: Classes, dtype: int64

# %% [markdown]
# Get Names of particular Taxon category for each organism. It is faster to check for a particular selected level of Taxonomy (eg, Species up to Kingdom/Domain) in each organism's list of Taxonomy against the master list of which we got from value counts of the list of all Taxonomies. Generally, I think it's more practical to look at one level of Taxonomy at a time.

# %%
#Let's do kingdom first = classes_list
classes_list_1 = group_with_Names[group_with_Names['Taxon'] =='domain']['Names'].tolist() #domain, infrakingdom
classes_list_0 = group_with_Names[group_with_Names['Taxon'] =='phylum']['Names'].tolist() #kingdom

# %%
classes_list_0
# Out:
# ['Actinobacteria',
#  'Apicomplexa',
#  'Aquificae',
#  'Arthropoda',
#  'Ascomycota',
#  'Bacteroidetes',
#  'Chlamydiae',
#  'Chlorobi',
#  'Chloroflexi',
#  'Chordata',
#  'Crenarchaeota',
#  'Cyanobacteria',
#  'Euryarchaeota',
#  'Firmicutes',
#  'Magnoliophyta',
#  'Opisthokonta',
#  'Proteobacteria',
#  'Spirochaetes',
#  'Streptophyta',
#  'Tenericutes',
#  'Thaumarchaeota',
#  'Thermotogae',
#  'Tracheophyta']

# %%
classes_list_1
# Out:
# ['Archaea', 'Bacteria', 'Eukaryota']

# %%
df_sub1_ = df_sub_

# %% [markdown]
# Add to Dataframe new Column "Taxonomy" - which gives Name of selected Taxonomy type.

# %%
df_sub1_ = df_sub_

species_n = len(df_sub1_)
classes_p = []

import numpy as np

#df_sub1_EP3B_['Organism'][13]

for i in df_sub1_.index.values:
    m = ''
    for k,l in enumerate(df_sub1_['Classes'][i]):
        print df_sub1_['Classes'][i][k]
        #print classes_list
        if df_sub1_['Classes'][i][k] in classes_list_0:
            m = df_sub1_['Classes'][i][k]
            print "Classes_list"
            break
        elif df_sub1_['Classes'][i][k] in classes_list_1:
            m = df_sub1_['Classes'][i][k]
            print "Classes_list0"
            break
        m = np.NaN
    classes_p.append(m)
    print m, " ",i
    
df_sub1_['Taxonomy'] = classes_p
df_sub1_.head(10)
#df_sub1_EP3B_[df_sub1_EP3B_['Classsub']=='']
# Out:
# [[
# Deinococcus
# Deinococcaceae
# Deinococcales
# Deinococci
# Deinococcus
# Thermus
# Bacteria
# Classes_list0
# Bacteria   0
# [[
# Acaryochloris
# FamilyI
# SubsectionI
# Cyanobacteria
# Classes_list
# Cyanobacteria   1
# [[
# Acetobacteraceae
# Rhodospirillales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2
# [[
# Acetobacter
# Acetobacteraceae
# Rhodospirillales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   3
# [[
# Acetobacter
# Acetobacteraceae
# Rhodospirillales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   4
# [[
# Acetobacter
# Acetobacteraceae
# Rhodospirillales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   5
# [[
# Acetobacterium
# Eubacteriaceae
# Clostridiales
# Clostridia
# Firmicutes
# Classes_list
# Firmicutes   6
# [[
# Acetohalobium
# Halobacteroidaceae
# Halanaerobiales
# Clostridia
# Firmicutes
# Classes_list
# Firmicutes   7
# [[
# Acholeplasma
# Acholeplasmataceae
# Acholeplasmatales
# Mollicutes
# Tenericutes
# Classes_list
# Tenericutes   8
# [[
# Acholeplasma
# Acholeplasmataceae
# Acholeplasmatales
# Mollicutes
# Tenericutes
# Classes_list
# Tenericutes   9
# [[
# Acholeplasma
# Acholeplasmataceae
# Acholeplasmatales
# Mollicutes
# Tenericutes
# Classes_list
# Tenericutes   10
# [[
# Acholeplasma
# Acholeplasmataceae
# Acholeplasmatales
# Mollicutes
# Tenericutes
# Classes_list
# Tenericutes   11
# [[
# Achromobacter
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   12
# [[
# Achromobacter
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   13
# [[
# Acidaminococcus
# Acidaminococcaceae
# Selenomonadales
# Negativicutes
# Firmicutes
# Classes_list
# Firmicutes   14
# [[
# Acidaminococcus
# Acidaminococcaceae
# Selenomonadales
# Negativicutes
# Firmicutes
# Classes_list
# Firmicutes   15
# [[
# Acidianus
# Sulfolobaceae
# Sulfolobales
# Thermoprotei
# Crenarchaeota
# Classes_list
# Crenarchaeota   16
# [[
# Acidilobus
# Acidilobaceae
# Acidilobales
# Thermoprotei
# Crenarchaeota
# Classes_list
# Crenarchaeota   17
# [[
# Acidimicrobium
# Acidimicrobiaceae
# Acidimicrobiales
# Acidimicrobiia
# Actinobacteria sup.
# Bacteria
# Classes_list0
# Bacteria   18
# [[
# Acidiphilium
# Acetobacteraceae
# Rhodospirillales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   19
# [[
# Acidiphilium
# Acetobacteraceae
# Rhodospirillales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   20
# [[
# Acidithiobacillus
# Acidithiobacillaceae
# Acidithiobacillales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   21
# [[
# Acidithiobacillus
# Acidithiobacillaceae
# Acidithiobacillales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   22
# [[
# Acidithiobacillus
# Acidithiobacillaceae
# Acidithiobacillales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   23
# [[
# Acidobacteria subdivision 22
# Acidobacteria
# Acidobacteria sup.
# Bacteria
# Classes_list0
# Bacteria   24
# [[
# Acidobacterium
# Acidobacteriaceae (Subgroup 1)
# Acidobacteriales
# Acidobacteria
# Acidobacteria sup.
# Bacteria
# Classes_list0
# Bacteria   25
# [[
# Acidothermus
# Acidothermaceae
# Frankiales
# Actinobacteria
# Classes_list
# Actinobacteria   26
# [[
# Comamonadaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   27
# [[
# Acidovorax
# Comamonadaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   28
# [[
# Acidovorax
# Comamonadaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   29
# [[
# Acidovorax
# Comamonadaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   30
# [[
# Deep Sea Hydrothermal Vent Gp 2(DHVEG
# 2)
# Thermoplasmatales
# Thermoplasmata
# Euryarchaeota
# Classes_list
# Euryarchaeota   31
# [[
# Candidatus Aciduliprofundum
# Deep Sea Hydrothermal Vent Gp 2(DHVEG
# 2)
# Thermoplasmatales
# Thermoplasmata
# Euryarchaeota
# Classes_list
# Euryarchaeota   32
# [[
# Moraxellaceae
# Pseudomonadales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   33
# [[
# Acinetobacter
# Moraxellaceae
# Pseudomonadales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   34
# [[
# Acinetobacter
# Moraxellaceae
# Pseudomonadales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   35
# [[
# Acinetobacter
# Moraxellaceae
# Pseudomonadales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   36
# [[
# Acinetobacter
# Moraxellaceae
# Pseudomonadales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   37
# [[
# Acinetobacter
# Moraxellaceae
# Pseudomonadales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   38
# [[
# Acinetobacter
# Moraxellaceae
# Pseudomonadales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   39
# [[
# Acinetobacter
# Moraxellaceae
# Pseudomonadales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   40
# [[
# Acinetobacter
# Moraxellaceae
# Pseudomonadales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   41
# [[
# Actinobacillus
# Pasteurellaceae
# Pasteurellales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   42
# [[
# Actinobacillus
# Pasteurellaceae
# Pasteurellales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   43
# [[
# Necropsobacter
# Pasteurellaceae
# Pasteurellales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   44
# [[
# Actinobacillus
# Pasteurellaceae
# Pasteurellales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   45
# [[
# Actinobacteria
# Classes_list
# Actinobacteria   46
# [[
# Actinomycetaceae
# Actinomycineae
# Actinomycetales
# Actinobacteria
# Classes_list
# Actinobacteria   47
# [[
# Actinomyces
# Actinomycetaceae
# Actinomycineae
# Actinomycetales
# Actinobacteria
# Classes_list
# Actinobacteria   48
# [[
# Actinomyces
# Actinomycetaceae
# Actinomycineae
# Actinomycetales
# Actinobacteria
# Classes_list
# Actinobacteria   49
# [[
# Actinomyces
# Actinomycetaceae
# Actinomycineae
# Actinomycetales
# Actinobacteria
# Classes_list
# Actinobacteria   50
# [[
# Micromonosporaceae
# Micromonosporales
ae
# Micrococcales
# Actinobacteria
# Classes_list
# Actinobacteria   251
# [[
# Bibersteinia
# Pasteurellaceae
# Pasteurellales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   252
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   253
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   254
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   255
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   256
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   257
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   258
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   259
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   260
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   261
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   262
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   263
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   264
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   265
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   266
# [[
# Bifidobacterium
# Bifidobacteriaceae
# Bifidobacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   267
# [[
# Blastochloris
# Hyphomicrobiaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   268
# [[
# Blastococcus
# Geodermatophilaceae
# Frankiales
# Actinobacteria
# Classes_list
# Actinobacteria   269
# [[
# Blattabacteriaceae
# Flavobacteriales
# Flavobacteria
# Bacteroidetes
# Classes_list
# Bacteroidetes   270
# [[
# Blautia
# Lachnospiraceae
# Clostridiales
# Clostridia
# Firmicutes
# Classes_list
# Firmicutes   271
# [[
# Candidatus Blochmannia
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   272
# [[
# Candidatus Blochmannia
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   273
# [[
# Bombus subgenus Bombus
# Bombus
# Bombini
# Bombinae
# Apidae
# Apoidea
# Aculeata
# Apocrita
# Hymenoptera
# Endopterygota
# Neoptera
# Pterygota
# Dicondylia
# Insecta
# Hexapoda
# Pancrustacea
# Mandibulata
# Arthropoda
# Classes_list
# Arthropoda   274
# [[
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   275
# [[
# Bordetella
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   276
# [[
# Bordetella
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   277
# [[
# Bordetella
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   278
# [[
# Bordetella
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   279
# [[
# Bordetella
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   280
# [[
# Bordetella
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   281
# [[
# Bordetella
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   282
# [[
# Bordetella
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   283
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   284
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   285
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   286
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   287
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   288
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   289
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   290
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   291
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   292
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   293
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   294
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   295
# [[
# Borrelia
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   296
# [[
# Bos
# Bovinae
# Bovidae
# Pecora
# Ruminantia
# Cetartiodactyla
# Laurasiatheria
# Boreoeutheria
# Eutheria
# Theria
# Mammalia
# Amniota
# Tetrapoda
# Dipnotetrapodomorpha
# Sarcopterygii
# Euteleostomi
# Teleostomi
# Gnathostomata
# Vertebrata
# Craniata
# Chordata
# Classes_list
# Chordata   297
# [[
# Botrytis
# Sclerotiniaceae
# Helotiales
# Leotiomycetidae
# Leotiomycetes
# Sordariomyceta
# Leotiomyceta
# Pezizomycotina
# Ascomycota
# Classes_list
# Ascomycota   298
# [[
# Brachybacterium
# Dermabacteraceae
# Micrococcales
# Actinobacteria
# Classes_list
# Actinobacteria   299
# [[
# Brachyspira
# Brachyspiraceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   300
# [[
# Brachyspira
# Brachyspiraceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   301
# [[
# Brachyspira
# Brachyspiraceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   302
# [[
# 6C
# Afipia
# Bradyrhizobiaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   303
# [[
# Bradyrhizobiaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   304
# [[
# Bradyrhizobium
# Bradyrhizobiaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   305
# [[
# Bradyrhizobium
# Bradyrhizobiaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   306
# [[
# Brassica
# Brassiceae
# Brassicaceae
# Brassicales
# malvids
# rosids
# Pentapetalae
# Gunneridae
# eudicotyledons
# Mesangiospermae
# Magnoliophyta
# Classes_list
# Magnoliophyta   307
# [[
# Brassica
# Brassiceae
# Brassicaceae
# Brassicales
# malvids
# rosids
# Pentapetalae
# Gunneridae
# eudicotyledons
# Mesangiospermae
# Magnoliophyta
# Classes_list
# Magnoliophyta   308
# [[
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   309
# [[
# Brevibacillus
# Paenibacillaceae
# Bacillales
# Bacilli
# Firmicutes
# Classes_list
# Firmicutes   310
# [[
# Brevibacterium
# Brevibacteriaceae
# Micrococcales
# Actinobacteria
# Classes_list
# Actinobacteria   311
# [[
# Brevibacterium
# Brevibacteriaceae
# Micrococcales
# Actinobacteria
# Classes_list
# Actinobacteria   312
# [[
# Caulobacteraceae
# Caulobacterales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   313
# [[
# Brevundimonas
# Caulobacteraceae
# Caulobacterales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   314
# [[
# Brevundimonas
# Caulobacteraceae
# Caulobacterales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   315
# [[
# Brucella
# Brucellaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   316
# [[
# Brucella
# Brucellaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   317
# [[
# Brucella
# Brucellaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   318
# [[
# Brucella
# Brucellaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   319
# [[
# Brucella
# Brucellaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   320
# [[
# Brucella
# Brucellaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria
teobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   379
# [[
# Candida
# Candida/Lodderomyces clade
# Debaryomycetaceae
# Saccharomycetales
# Ascomycota
# Classes_list
# Ascomycota   380
# [[
# Candida
# Candida/Lodderomyces clade
# Debaryomycetaceae
# Saccharomycetales
# Ascomycota
# Classes_list
# Ascomycota   381
# [[
# Nakaseomyces/Candida clade
# Nakaseomyces
# Saccharomycetaceae
# Saccharomycetales
# Ascomycota
# Classes_list
# Ascomycota   382
# [[
# 1
# Candidate division SR1
# Bacteria
# Classes_list0
# Bacteria   383
# [[
# Candidate division SR1
# Bacteria
# Classes_list0
# Bacteria   384
# [[
# candidate division TM6
# Bacteria
# Classes_list0
# Bacteria   385
# [[
# candidate division WWE3
# Bacteria
# Classes_list0
# Bacteria   386
# [[
# Propionivibrio
# Rhodocyclaceae
# Rhodocyclales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   387
# [[
# Candidatus Amoebophilus
# Flammeovirgaceae
# Cytophagales
# Cytophagia
# Bacteroidetes
# Classes_list
# Bacteroidetes   388
# [[
# Clostridiaceae
# Clostridiales
# Clostridia
# Firmicutes
# Classes_list
# Firmicutes   389
# [[
# A
# marine group
# FamilyI
# SubsectionI
# Cyanobacteria
# Classes_list
# Cyanobacteria   390
# [[
# Candidatus Azobacteroides
# Porphyromonadaceae
# Bacteroidales
# Bacteroidia
# Bacteroidetes
# Classes_list
# Bacteroidetes   391
# [[
# Candidatus Babela
# Deltaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   392
# [[
# Candidatus Baumannia
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   393
# [[
# Candidatus Blochmannia
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   394
# [[
# Candidatus Blochmannia
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   395
# [[
# Caedibacter
# Rickettsiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   396
# [[
# Candidatus Caldiarchaeum
# Terrestrial Hot Spring Gp(THSCG)
# Thaumarchaeota
# Classes_list
# Thaumarchaeota   397
# [[
# Candidatus Carsonella
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   398
# [[
# Candidatus Desulforudis
# Peptococcaceae
# Clostridiales
# Clostridia
# Firmicutes
# Classes_list
# Firmicutes   399
# [[
# Thalassobaculum
# Rhodospirillaceae
# Rhodospirillales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   400
# [[
# Candidatus Evansia
# Halomonadaceae
# Oceanospirillales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   401
# [[
# Filomicrobium
# Hyphomicrobiaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   402
# [[
# Candidatus Hamiltonella
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   403
# [[
# Candidatus Hepatoplasma
# Entomoplasmatales
# Mollicutes
# Tenericutes
# Classes_list
# Tenericutes   404
# [[
# Candidatus Ishikawaella
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   405
# [[
# Candidatus Kinetoplastibacterium
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   406
# [[
# Candidatus Kinetoplastibacterium
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   407
# [[
# Candidatus Kinetoplastibacterium
# Alcaligenaceae
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   408
# [[
# Candidatus Korarchaeum
# Korarchaeota
# Archaea
# Classes_list0
# Archaea   409
# [[
# Candidatus Koribacter
# Acidobacteriaceae (Subgroup 1)
# Acidobacteriales
# Acidobacteria
# Acidobacteria sup.
# Bacteria
# Classes_list0
# Bacteria   410
# [[
# Candidatus Liberibacter
# Rhizobiaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   411
# [[
# Candidatus Liberibacter
# Rhizobiaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   412
# [[
# Candidatus Liberibacter
# Rhizobiaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   413
# [[
# Candidatus Liberibacter
# Rhizobiaceae
# Rhizobiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   414
# [[
# Methanomassiliicoccus
# Thermoplasmatales
# Thermoplasmata
# Euryarchaeota
# Classes_list
# Euryarchaeota   415
# [[
# Candidatus Methanomethylophilus
# Thermoplasmatales
# Thermoplasmata
# Euryarchaeota
# Classes_list
# Euryarchaeota   416
# [[
# Candidatus Methanoplasma
# Methanomassiliicoccaceae
# Methanomassiliicoccales
# Thermoplasmata
# Euryarchaeota
# Classes_list
# Euryarchaeota   417
# [[
# Candidatus Methylomirabilis
# Nitrospirales
# Nitrospira
# Nitrospirae
# Bacteria
# Classes_list0
# Bacteria   418
# [[
# Candidatus Methylopumilus
# Methylophilaceae
# Methylophilales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   419
# [[
# Candidatus Methylopumilus
# Methylophilaceae
# Methylophilales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   420
# [[
# Candidatus Midichloria
# Rickettsiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   421
# [[
# Candidatus Moranella
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   422
# [[
# Mycoplasma
# Mycoplasmataceae
# Mycoplasmatales
# Mollicutes
# Tenericutes
# Classes_list
# Tenericutes   423
# [[
# Mycoplasma
# Mycoplasmataceae
# Mycoplasmatales
# Mollicutes
# Tenericutes
# Classes_list
# Tenericutes   424
# [[
# symbiont of Nephotettix cincticeps
# Candidatus Vidania
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   425
# [[
# Candidatus Nitrosopelagicus
# Thaumarchaeota
# Classes_list
# Thaumarchaeota   426
# [[
# Candidatus Nitrosopumilus
# Marine Group I
# Thaumarchaeota
# Classes_list
# Thaumarchaeota   427
# [[
# Candidatus Nitrosopumilus
# Marine Group I
# Thaumarchaeota
# Classes_list
# Thaumarchaeota   428
# [[
# Candidatus Nitrosopumilus
# Marine Group I
# Thaumarchaeota
# Classes_list
# Thaumarchaeota   429
# [[
# Candidatus Nitrosopumilus
# Marine Group I
# Thaumarchaeota
# Classes_list
# Thaumarchaeota   430
# [[
# Pantoea
# Enterobacteriaceae
# Enterobacteriales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   431
# [[
# Candidatus Paracaedibacter
# Rickettsiales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   432
# [[
# Surface 1
# SAR11 clade
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   433
# [[
# Candidatus Pelagibacter
# Surface 1
# SAR11 clade
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   434
# [[
# Candidatus Phaeomarinobacter
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   435
# [[
# Candidatus Phytoplasma
# Acholeplasmataceae
# Acholeplasmatales
# Mollicutes
# Tenericutes
# Classes_list
# Tenericutes   436
# [[
# Candidatus Phytoplasma
# Acholeplasmataceae
# Acholeplasmatales
# Mollicutes
# Tenericutes
# Classes_list
# Tenericutes   437
# [[
# Candidatus Phytoplasma
# Acholeplasmataceae
# Acholeplasmatales
# Mollicutes
# Tenericutes
# Classes_list
# Tenericutes   438
# [[
# Candidatus Portiera
# Halomonadaceae
# Oceanospirillales
# Gammaproteobacteria
# Proteobacteria
# ...
# Ascomycota
# Classes_list
# Ascomycota   2133
# [[
# Tetrapisispora
# Saccharomycetaceae
# Saccharomycetales
# Ascomycota
# Classes_list
# Ascomycota   2134
# [[
# Thalassiosira
# Mediophyceae
# Bacillariophytina
# Bacillariophyta
# Stramenopiles
# SAR
# Eukaryota
# Classes_list0
# Eukaryota   2135
# [[
# Thalassolituus
# Oceanospirillaceae
# Oceanospirillales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2136
# [[
# Thalassospira
# Rhodospirillaceae
# Rhodospirillales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2137
# [[
# Rhodocyclaceae
# Rhodocyclales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2138
# [[
# Thauera
# Rhodocyclaceae
# Rhodocyclales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2139
# [[
# Thaumarchaeota
# Classes_list
# Thaumarchaeota   2140
# [[
# Theileria
# Piroplasmorida
# Aconoidasida
# Apicomplexa
# Classes_list
# Apicomplexa   2141
# [[
# Babesia
# Piroplasmorida
# Aconoidasida
# Apicomplexa
# Classes_list
# Apicomplexa   2142
# [[
# Theileria
# Piroplasmorida
# Aconoidasida
# Apicomplexa
# Classes_list
# Apicomplexa   2143
# [[
# Theileria
# Piroplasmorida
# Aconoidasida
# Apicomplexa
# Classes_list
# Apicomplexa   2144
# [[
# Theobroma
# Byttnerioideae
# Malvaceae
# Malvales
# malvids
# rosids
# Pentapetalae
# Gunneridae
# eudicotyledons
# Mesangiospermae
# Magnoliophyta
# Classes_list
# Magnoliophyta   2145
# [[
# Thermacetogenium
# Thermoanaerobacteraceae
# Thermoanaerobacterales
# Clostridia
# Firmicutes
# Classes_list
# Firmicutes   2146
# [[
# Thermaerobacter
# Syntrophomonadaceae
# Clostridiales
# Clostridia
# Firmicutes
# Classes_list
# Firmicutes   
ae
# Chromatiales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2226
# [[
# Thioflavicoccus
# Chromatiaceae
# Chromatiales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2227
# [[
# Thiolapillus
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2228
# [[
# Thiomicrospira
# Piscirickettsiaceae
# Thiotrichales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2229
# [[
# Thiomonas
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2230
# [[
# Thiomonas
# Burkholderiales
# Betaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2231
# [[
# Thioploca
# Thiotrichaceae
# Thiotrichales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2232
# [[
# Tistrella
# Rhodospirillaceae
# Rhodospirillales
# Alphaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2233
# [[
# Tolumonas
# Aeromonadaceae
# Aeromonadales
# Gammaproteobacteria
# Proteobacteria
# Classes_list
# Proteobacteria   2234
# [[
# Torulaspora
# Saccharomycetaceae
# Saccharomycetales
# Ascomycota
# Classes_list
# Ascomycota   2235
# [[
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2236
# [[
# Treponema
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2237
# [[
# Treponema
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2238
# [[
# Spirochaeta
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2239
# [[
# Treponema
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2240
# [[
# Treponema
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2241
# [[
# Treponema
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2242
# [[
# Treponema
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2243
# [[
# Treponema
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2244
# [[
# Treponema
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2245
# [[
# Treponema
# Spirochaetaceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2246
# [[
# Tribolium
# Tenebrioninae
# Tenebrionidae
# Tenebrionoidea
# Cucujiformia
# Polyphaga
# Coleoptera
# Endopterygota
# Neoptera
# Pterygota
# Dicondylia
# Insecta
# Hexapoda
# Pancrustacea
# Mandibulata
# Arthropoda
# Classes_list
# Arthropoda   2247
# [[
# Trichodesmium
# FamilyI
# SubsectionIII
# Cyanobacteria
# Classes_list
# Cyanobacteria   2248
# [[
# Trichormus
# FamilyI
# SubsectionIV
# Cyanobacteria
# Classes_list
# Cyanobacteria   2249
# [[
# Tropheryma
# Cellulomonadaceae
# Micrococcales
# Actinobacteria
# Classes_list
# Actinobacteria   2250
# [[
# Truepera
# Trueperaceae
# Deinococcales
# Deinococci
# Deinococcus
# Thermus
# Bacteria
# Classes_list0
# Bacteria   2251
# [[
# Trueperella
# Actinomycetaceae
# Actinomycineae
# Actinomycetales
# Actinobacteria
# Classes_list
# Actinobacteria   2252
# [[
# Trypanozoon
# Trypanosoma
# Trypanosomatida
# Metakinetoplastina
# Kinetoplastea
# Euglenozoa
# Discicristata
# Discoba
# Excavata
# Eukaryota
# Classes_list0
# Eukaryota   2253
# [[
# Tsukamurella
# Tsukamurellaceae
# Corynebacteriales
# Actinobacteria
# Classes_list
# Actinobacteria   2254
# [[
# Erysipelotrichaceae
# Erysipelotrichales
# Erysipelotrichi
# Firmicutes
# Classes_list
# Firmicutes   2255
# [[
# Turneriella
# Leptospiraceae
# Spirochaetales
# Spirochaetes
# Classes_list
# Spirochaetes   2256
#    Unnamed: 0  Unnamed: 0.1                            Organism   Kingdom  \
# 0           0             0  'Deinococcus soli' Cha et al. 2014  Bacteria
# 1           1            12                Acaryochloris marina  Bacteria
# 2           2            13                         Acetobacter  Bacteria
# 3           3            14               Acetobacter ghanensis  Bacteria
# 4           4            15            Acetobacter pasteurianus  Bacteria
# 5           5            16            Acetobacter senegalensis  Bacteria
# 6           6            17               Acetobacterium woodii  Bacteria
# 7           7            18            Acetohalobium arabaticum  Bacteria
# 8           8            24              Acholeplasma brassicae  Bacteria
# 9           9            25              Acholeplasma laidlawii  Bacteria
#
#       Size  Chr            url     RPR    GC  \
# 0  3.23698  1.0  /genome/38191  3038.0  70.2
# 1  8.36160  1.0   /genome/1179  7179.0  35.5
# 2  3.10640  1.0  /genome/18005  1775.0  57.1
# 3  2.84394  1.0  /genome/42306  2437.0  53.9
# 4  3.34025  1.0    /genome/904  2955.0  57.2
# 5  3.96991  1.0  /genome/42303  3373.0  55.5
# 6  4.04478  1.0  /genome/11436  3521.0  36.6
# 7  2.46960  1.0   /genome/1846  2286.0  50.4
# 8  1.87779  1.0  /genome/22962  1672.0  29.6
# 9  1.49699  1.0   /genome/1515  1352.0  27.8
#
#                                              Classes  \
# 0  [[[, Deinococcus, Deinococcaceae, Deinococcale...
# 1  [[[, Acaryochloris, FamilyI, SubsectionI, Cyan...
# 2  [[[, Acetobacteraceae, Rhodospirillales, Alpha...
# 3  [[[, Acetobacter, Acetobacteraceae, Rhodospiri...
# 4  [[[, Acetobacter, Acetobacteraceae, Rhodospiri...
# 5  [[[, Acetobacter, Acetobacteraceae, Rhodospiri...
# 6  [[[, Acetobacterium, Eubacteriaceae, Clostridi...
# 7  [[[, Acetohalobium, Halobacteroidaceae, Halana...
# 8  [[[, Acholeplasma, Acholeplasmataceae, Acholep...
# 9  [[[, Acholeplasma, Acholeplasmataceae, Acholep...
#
#                                            Classsub1        Taxonomy      _Cat
# 0  [Deinococcus, Deinococcaceae, Deinococcales, D...        Bacteria  Bacteria
# 1  [Acaryochloris, FamilyI, SubsectionI, Cyanobac...   Cyanobacteria  Bacteria
# 2  [Acetobacter, Acetobacteraceae, Rhodospirillal...  Proteobacteria  Bacteria
# 3  [Acetobacter, Acetobacteraceae, Rhodospirillal...  Proteobacteria  Bacteria
# 4  [Acetobacter, Acetobacteraceae, Rhodospirillal...  Proteobacteria  Bacteria
# 5  [Acetobacter, Acetobacteraceae, Rhodospirillal...  Proteobacteria  Bacteria
# 6  [Acetobacterium, Eubacteriaceae, Clostridiales...      Firmicutes  Bacteria
# 7  [Acetohalobium, Halobacteroidaceae, Halanaerob...      Firmicutes  Bacteria
# 8  [Acholeplasma, Acholeplasmataceae, Acholeplasm...     Tenericutes  Bacteria
# 9  [Acholeplasma, Acholeplasmataceae, Acholeplasm...     Tenericutes  Bacteria

# %%
classes_p
# Out:
# [u'Bacteria',
#  u'Cyanobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Tenericutes',
#  u'Tenericutes',
#  u'Tenericutes',
#  u'Tenericutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Crenarchaeota',
#  u'Crenarchaeota',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Crenarchaeota',
#  u'Crenarchaeota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Bacteria',
#  u'Firmicutes',
#  u'Chloroflexi',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Magnoliophyta',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Chordata',
#  u'Arthropoda',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Arthropoda',
#  u'Aquificae',
#  u'Magnoliophyta',
#  u'Magnoliophyta',
#  u'Magnoliophyta',
#  u'Magnoliophyta',
#  u'Actinobacteria',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Archaea',
#  u'Archaea',
#  u'Archaea',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Proteobacteria',
#  u'Ascomycota',
#  u'Ascomycota',
#  u'Tenericutes',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Apicomplexa',
#  u'Apicomplexa',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Bacteria',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Magnoliophyta',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Bacteroidetes',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Arthropoda',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Chordata',
#  u'Ascomycota',
#  u'Actinobacteria',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Spirochaetes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Magnoliophyta',
#  u'Magnoliophyta',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Opisthokonta',
#  u'Opisthokonta',
#  u'Magnoliophyta',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Chloroflexi',
#  u'Bacteria',
#  u'Crenarchaeota',
#  u'Bacteria',
#  u'Crenarchaeota',
#  u'Chordata',
#  u'Cyanobacteria',
#  u'Magnoliophyta',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Ascomycota',
#  u'Ascomycota',
#  u'Ascomycota',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Firmicutes',
#  u'Cyanobacteria',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Thaumarchaeota',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Tenericutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Archaea',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Tenericutes',
#  u'Tenericutes',
#  u'Proteobacteria',
#  u'Thaumarchaeota',
#  u'Thaumarchaeota',
#  u'Thaumarchaeota',
#  u'Thaumarchaeota',
#  u'Thaumarchaeota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Tenericutes',
#  u'Tenericutes',
#  u'Tenericutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Chlamydiae',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Chordata',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Chordata',
#  u'Magnoliophyta',
#  u'Firmicutes',
#  u'Bacteroidetes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Thaumarchaeota',
#  u'Cyanobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Chlamydiae',
#  u'Chlamydiae',
#  u'Chlamydiae',
#  u'Chlamydiae',
#  u'Chlamydiae',
#  u'Chlamydiae',
#  u'Chlamydiae',
#  u'Chlamydiae',
#  u'Chlamydiae',
#  u'Chlamydiae',
#  u'Bacteria',
#  u'Chlorobi',
#  u'Chlorobi',
#  u'Chlorobi',
#  u'Chlorobi',
#  u'Chlorobi',
#  u'Chlorobi',
#  u'Chordata',
#  u'Chloroflexi',
#  u'Chloroflexi',
#  u'Chloroflexi',
#  u'Chlorobi',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Cyanobacteria',
#  u'Chordata',
#  u'Bacteroidetes',
#  u'Bacteria',
#  u'Magnoliophyta',
#  u'Chordata',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Magnoliophyta',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Chordata',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Cyanobacteria',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Bacteria',
#  u'Opisthokonta',
#  u'Apicomplexa',
#  u'Magnoliophyta',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Eukaryota',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Ascomycota',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Cyanobacteria',
#  u'Chordata',
#  u'Bacteroidetes',
#  u'Cyanobacteria',
#  u'Chordata',
#  u'Magnoliophyta',
#  u'Ascomycota',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Thermotogae',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Chloroflexi',
#  u'Chloroflexi',
#  u'Chloroflexi',
#  u'Chloroflexi',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Aquificae',
#  u'Crenarchaeota',
#  u'Crenarchaeota',
#  u'Crenarchaeota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Eukaryota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Ascomycota',
#  u'Arthropoda',
#  u'Arthropoda',
#  u'Arthropoda',
#  u'Arthropoda',
#  u'Arthropoda',
#  u'Arthropoda',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Eukaryota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Apicomplexa',
#  u'Magnoliophyta',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteria',
#  u'Bacteroidetes',
#  u'Bacteria',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Chordata',
#  u'Ascomycota',
#  u'Ascomycota',
#  u'Ascomycota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Chordata',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Magnoliophyta',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Chordata',
#  u'Proteobacteria',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Crenarchaeota',
#  u'Thermotogae',
#  u'Thermotogae',
#  u'Thermotogae',
#  u'Bacteroidetes',
#  u'Bacteria',
#  u'Chordata',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Bacteria',
#  u'Firmicutes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Bacteroidetes',
#  u'Magnoliophyta',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Ascomycota',
#  u'Ascomycota',
#  u'Ascomycota',
#  u'Ascomycota',
#  u'Ascomycota',
#  u'Bacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Chordata',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Actinobacteria',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Cyanobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Magnoliophyta',
#  u'Actinobacteria',
#  u'Actinobacteria',
#  u'Bacteria',
#  u'Chordata',
#  u'Magnoliophyta',
#  u'Magnoliophyta',
#  u'Magnoliophyta',
#  u'Firmicutes',
#  u'Bacteroidetes',
#  u'Proteobacteria',
#  u'Bacteria',
#  u'Bacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Firmicutes',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Bacteroidetes',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Firmicutes',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Euryarchaeota',
#  u'Euryarchaeota',
#  u'Proteobacteria',
#  u'Euryarchaeota',
#  u'Cyanobacteria',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Euryarchaeota',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Firmicutes',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  u'Chloroflexi',
#  u'Proteobacteria',
#  u'Proteobacteria',
#  ...]

# %%
df_sub2_ = df_sub1_.dropna().reset_index(drop=True) #for now...

# %%
df_sub2_['_Cat'] =df_sub2_['Taxonomy']
df_sub2_.head(4)
# Out:
#    Unnamed: 0  Unnamed: 0.1                            Organism   Kingdom  \
# 0           0             0  'Deinococcus soli' Cha et al. 2014  Bacteria
# 1           1            12                Acaryochloris marina  Bacteria
# 2           2            13                         Acetobacter  Bacteria
# 3           3            14               Acetobacter ghanensis  Bacteria
#
#       Size  Chr            url     RPR    GC  \
# 0  3.23698  1.0  /genome/38191  3038.0  70.2
# 1  8.36160  1.0   /genome/1179  7179.0  35.5
# 2  3.10640  1.0  /genome/18005  1775.0  57.1
# 3  2.84394  1.0  /genome/42306  2437.0  53.9
#
#                                              Classes  \
# 0  [[[, Deinococcus, Deinococcaceae, Deinococcale...
# 1  [[[, Acaryochloris, FamilyI, SubsectionI, Cyan...
# 2  [[[, Acetobacteraceae, Rhodospirillales, Alpha...
# 3  [[[, Acetobacter, Acetobacteraceae, Rhodospiri...
#
#                                            Classsub1        Taxonomy  \
# 0  [Deinococcus, Deinococcaceae, Deinococcales, D...        Bacteria
# 1  [Acaryochloris, FamilyI, SubsectionI, Cyanobac...   Cyanobacteria
# 2  [Acetobacter, Acetobacteraceae, Rhodospirillal...  Proteobacteria
# 3  [Acetobacter, Acetobacteraceae, Rhodospirillal...  Proteobacteria
#
#              _Cat
# 0        Bacteria
# 1   Cyanobacteria
# 2  Proteobacteria
# 3  Proteobacteria

# %%
#print df_sub1_[df_sub1_.Organism == 'Acaryochloris marina'].Classes

# %%
print len(df_sub1_)
print len(df_sub2_)
# Out:
# 2257
# 2257

# %%
df_sub2_.Taxonomy.value_counts()
# Out:
# Proteobacteria    853
# Firmicutes        348
# Actinobacteria    250
# Euryarchaeota     126
# Bacteroidetes     112
# Bacteria          111
# Tenericutes        65
# Cyanobacteria      48
# Chordata           44
# Ascomycota         43
# Spirochaetes       39
# Magnoliophyta      37
# Crenarchaeota      37
# Thermotogae        22
# Apicomplexa        19
# Eukaryota          18
# Chloroflexi        15
# Chlamydiae         14
# Chlorobi           12
# Aquificae          11
# Arthropoda         11
# Thaumarchaeota     10
# Archaea             6
# Opisthokonta        6
# Name: Taxonomy, dtype: int64

# %%
# Baseline:

baseline = 853 * 1.0/2257
baseline
# Out:
# 0.3779353123615419

# %%
## Checking the categories

df_sub2_.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1                            Organism   Kingdom  \
# 0           0             0  'Deinococcus soli' Cha et al. 2014  Bacteria
# 1           1            12                Acaryochloris marina  Bacteria
# 2           2            13                         Acetobacter  Bacteria
#
#       Size  Chr            url     RPR    GC  \
# 0  3.23698  1.0  /genome/38191  3038.0  70.2
# 1  8.36160  1.0   /genome/1179  7179.0  35.5
# 2  3.10640  1.0  /genome/18005  1775.0  57.1
#
#                                              Classes  \
# 0  [[[, Deinococcus, Deinococcaceae, Deinococcale...
# 1  [[[, Acaryochloris, FamilyI, SubsectionI, Cyan...
# 2  [[[, Acetobacteraceae, Rhodospirillales, Alpha...
#
#                                            Classsub1        Taxonomy  \
# 0  [Deinococcus, Deinococcaceae, Deinococcales, D...        Bacteria
# 1  [Acaryochloris, FamilyI, SubsectionI, Cyanobac...   Cyanobacteria
# 2  [Acetobacter, Acetobacteraceae, Rhodospirillal...  Proteobacteria
#
#              _Cat
# 0        Bacteria
# 1   Cyanobacteria
# 2  Proteobacteria

# %% [markdown]
# Now that we have all the categories, we can start modeling for predicting the classification.

# %% [markdown]
# Manually assign Multinomial categories of Kingdoms

# %%
df_CAT0 = pd.DataFrame(df_sub2_._Cat.value_counts())
df_CAT1 = pd.DataFrame(data = df_CAT0.index)
df_CAT = pd.DataFrame(data = df_CAT1.index, index=df_CAT1[0])
df_CAT
# Out:
#                  0
# 0
# Proteobacteria   0
# Firmicutes       1
# Actinobacteria   2
# Euryarchaeota    3
# Bacteroidetes    4
# Bacteria         5
# Tenericutes      6
# Cyanobacteria    7
# Chordata         8
# Ascomycota       9
# Spirochaetes    10
# Magnoliophyta   11
# Crenarchaeota   12
# Thermotogae     13
# Apicomplexa     14
# Eukaryota       15
# Chloroflexi     16
# Chlamydiae      17
# Chlorobi        18
# Aquificae       19
# Arthropoda      20
# Thaumarchaeota  21
# Archaea         22
# Opisthokonta    23

# %%
def def_category(x):
    for i in df_CAT.index:
        if x == i:
            y = df_CAT.loc[i]
    return y[0]

# %%
#Dataframe for Modeling
df_C1 = df_sub2_[["Size","Chr","GC", "_Cat", "RPR"]] #Include target
#Add Multinommial Classification integers
df_C1['__Cat'] = df_C1['_Cat'].map(lambda x: def_category(x))
df_C1.tail(5)
# Out:
# /Users/noriogura/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#           Size   Chr    GC            _Cat     RPR  __Cat
# 2252   1.92400   1.0  38.5  Actinobacteria  1920.0      2
# 2253  22.14810  11.0  46.0       Eukaryota  9267.0     15
# 2254   4.47972   1.0  43.1  Actinobacteria  4172.0      2
# 2255   2.94747   1.0  53.5      Firmicutes  2449.0      1
# 2256   4.40930   1.0  55.4    Spirochaetes  4132.0     10

# %%
#LOGISTIC REGRESSION MULTINOMIAL MANUAL, Test Train Split

formula_c =  '__Cat ~ (Size + Chr + GC + RPR - 1)' #Score: 0.574834634511
formula_c = str(formula_c)
#######################

#COEFFICIENTS...
import patsy
from patsy import dmatrices
Yf, Xf = patsy.dmatrices(formula_c, data=df_C1, return_type='dataframe')

formula_c = str(formula_c)
print formula_c
Yb, Xb = dmatrices(formula_c, data = df_C1, return_type='dataframe')
#########################


from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression #LOGISTIC REGRESSION
from sklearn.metrics import accuracy_score


###NORMALIZE THE PREDICTOR VARIABLES!
Xb_mat = ((Xf - Xf.mean())/ Xf.std()).values


# Kiefer: try cross_val_score with cv=5, its like doing 5 of these train_test_splits
# take the mean of the 5 scores you get out of cross_val_score
# you could even try cv=3 since you have little data.. 

# Better estimate of training accuracy of out of sample performance
X_train, X_test, Y_train, Y_test = train_test_split(Xb_mat, Yb, test_size=0.5, random_state=42)


logreg = LogisticRegression(multi_class='multinomial', solver='lbfgs')

#fit a model on the training data and test on the testing data
model = logreg.fit(X_train, Y_train)
# print model
predictions = logreg.predict(X_test)

print "Score:", model.score(X_test, Y_test)     
#print accuracy_score(Y_test, predictions) ###ERRORS for Logistic Regression

t = logreg.coef_
#tt = t.reshape(-1)

print t.shape
print Xb.shape

print "Model fit:", logreg.score(X_test, Y_test)
print logreg.intercept_, logreg.coef_[0]

###################K folds CV

# from sklearn.linear_model import LogisticRegressionCV

# logreg0 = LogisticRegressionCV(multi_class='multinomial', solver='lbfgs', cv=5)
# model0 = logreg0.fit(X_train, Y_train)
# predictions0 = pd.Series(logreg0.predict(X_test))
# print "ACCURACY: ", accuracy_score(Y_test, predictions0)
# Out:
# __Cat ~ (Size + Chr + GC + RPR - 1)
# Score: 0.436669619132
# (24, 4)
# (2257, 4)
# Model fit: 0.436669619132
# [ 3.67470879  2.62106064  2.34985959  1.50757716  1.79109312  1.51471602
#   0.2189156   1.12333521 -4.8266915   0.69726743  0.53224726 -1.63233793
#   0.42745017  0.12811064 -1.42764689 -1.94647768  0.14196438 -0.3755479
#  -1.11614484 -0.46073302 -0.76472958 -1.38378897 -1.56375189 -1.23045582] [-0.78837952 -1.56977453  0.16954483  0.89555671]
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print len(Xb_mat)
print len(Yb)
# Out:
# 2257
# 2257

# %%
Y_train.__Cat.value_counts()
# Out:
# 0.0     411
# 1.0     191
# 2.0     117
# 3.0      61
# 4.0      60
# 5.0      55
# 6.0      36
# 7.0      25
# 9.0      23
# 8.0      23
# 11.0     20
# 12.0     19
# 10.0     19
# 13.0     12
# 15.0     10
# 16.0     10
# 17.0      7
# 19.0      6
# 20.0      6
# 18.0      5
# 22.0      3
# 14.0      3
# 21.0      3
# 23.0      3
# Name: __Cat, dtype: int64

# %%
Y_test.__Cat.value_counts()
# Out:
# 0.0     442
# 1.0     157
# 2.0     133
# 3.0      65
# 5.0      56
# 4.0      52
# 6.0      29
# 7.0      23
# 8.0      21
# 10.0     20
# 9.0      20
# 12.0     18
# 11.0     17
# 14.0     16
# 13.0     10
# 15.0      8
# 17.0      7
# 18.0      7
# 21.0      7
# 16.0      5
# 19.0      5
# 20.0      5
# 22.0      3
# 23.0      3
# Name: __Cat, dtype: int64

# %%
#DROPNA, RESET INDEX otherwise - index match up problem with Xbmat, Xf later...

df_C1D = df_C1.dropna().reset_index(drop=True)
#df_C1D.loc[181]

# %%
#LOGISTIC REGRESSION MULTINOMIAL MANUAL, K-FOLDS

formula_c =  '__Cat ~ (Size + Chr + GC + RPR - 1)' #Score: 0.574834634511
formula_c = str(formula_c)
#######################

#COEFFICIENTS...
import patsy
from patsy import dmatrices
Yf, Xf = patsy.dmatrices(formula_c, data=df_C1D, return_type='dataframe')

formula_c = str(formula_c)
print formula_c
Yb, Xb = dmatrices(formula_c, data = df_C1D, return_type='dataframe')
#########################


from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression #LOGISTIC REGRESSION
from sklearn.metrics import accuracy_score


###NORMALIZE THE PREDICTOR VARIABLES!
Xb_mat = ((Xf - Xf.mean())/ Xf.std()).values


# Kiefer: try cross_val_score with cv=5, its like doing 5 of these train_test_splits
# take the mean of the 5 scores you get out of cross_val_score
# you could even try cv=3 since you have little data.. 

# Better estimate of training accuracy of out of sample performance
X_train, X_test, Y_train, Y_test = train_test_split(Xb_mat, Yb, test_size=0.5, random_state=42)


logreg = LogisticRegression(multi_class='multinomial', solver='lbfgs')

#fit a model on the training data and test on the testing data
model = logreg.fit(X_train, Y_train)
# print model
predictions = logreg.predict(X_test)

print "Score:", model.score(X_test, Y_test)     
#print accuracy_score(Y_test, predictions) ###ERRORS for Logistic Regression

t = logreg.coef_
#tt = t.reshape(-1)

print t.shape
print Xb.shape

print "Model fit:", logreg.score(X_test, Y_test)
print logreg.intercept_, logreg.coef_[0]

###################K folds CV

from sklearn.linear_model import LogisticRegressionCV

logreg0 = LogisticRegressionCV(multi_class='multinomial', solver='lbfgs', cv=10)
model0 = logreg0.fit(Xb_mat, Yb)
predictions0 = pd.Series(logreg0.predict(Xb_mat))
print "Score:", model0.score(Xb_mat, Yb)
# Out:
# __Cat ~ (Size + Chr + GC + RPR - 1)
# Score: 0.436669619132
# (24, 4)
# (2257, 4)
# Model fit: 0.436669619132
# [ 3.67470879  2.62106064  2.34985959  1.50757716  1.79109312  1.51471602
#   0.2189156   1.12333521 -4.8266915   0.69726743  0.53224726 -1.63233793
#   0.42745017  0.12811064 -1.42764689 -1.94647768  0.14196438 -0.3755479
#  -1.11614484 -0.46073302 -0.76472958 -1.38378897 -1.56375189 -1.23045582] [-0.78837952 -1.56977453  0.16954483  0.89555671]
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 6 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=10.
#   % (min_labels, self.n_folds)), Warning)
# Score: 0.447053610988

# %% [markdown]
# We should check in greater detail where the misclassifcation is happening. We can make a function to compare test and predicted values, and look at the features.

# %% [markdown]
# Prediction data frame with the same index as the Y_test - we should keep the same index so that we can examine the features of the mislabeled Kingdoms

# %%
def def_comp_test(df_predict):
    row_ids = df_predict[df_predict["_C"] != df_predict["predict1"]].index    
    return row_ids

def def_comp_test0(df_predict):
    row_ids = df_predict[df_predict["_C"] == df_predict["predict1"]].index    
    return row_ids

def def_comp_test2(df_predict):
    row_ids = df_predict[df_predict["_C"] == df_predict["predict1"]] #.index    
    row_ids = row_ids[row_ids["_C"] == 1.0].index
    return row_ids

# %%
df_predict  = pd.DataFrame() #Dataframe with test values and predictions
loo_predictions1_ = pd.DataFrame(data=predictions, columns={"predict1"}, index=Y_test.index) 
Y_test_ = pd.DataFrame(data=Y_test.values, columns={"_C"}, index=Y_test.index) 

df_predict = pd.concat([Y_test_, loo_predictions1_], axis=1)
df_predict.head(5)
# Out:
#        _C  predict1
# 561   0.0       0.0
# 440   0.0       0.0
# 1513  5.0       0.0
# 1360  2.0       0.0
# 259   2.0       0.0

# %%
g = (def_comp_test(df_predict)) #Indexes of misclassifications
df_miss = df_predict.loc[g]
print len(df_miss)
df_miss.head(5)
# Out:
# 636
#        _C  predict1
# 1513  5.0       0.0
# 1360  2.0       0.0
# 259   2.0       0.0
# 535   1.0       0.0
# 2002  1.0       0.0

# %%
print df_CAT
df_C1D.loc[741] #original features for missclassification of Archaea(2) as Bacteria(1)
# Out:
#                  0
# 0
# Proteobacteria   0
# Firmicutes       1
# Actinobacteria   2
# Euryarchaeota    3
# Bacteroidetes    4
# Bacteria         5
# Tenericutes      6
# Cyanobacteria    7
# Chordata         8
# Ascomycota       9
# Spirochaetes    10
# Magnoliophyta   11
# Crenarchaeota   12
# Thermotogae     13
# Apicomplexa     14
# Eukaryota       15
# Chloroflexi     16
# Chlamydiae      17
# Chlorobi        18
# Aquificae       19
# Arthropoda      20
# Thaumarchaeota  21
# Archaea         22
# Opisthokonta    23
# Size        34.205
# Chr              6
# GC            38.6
# _Cat     Eukaryota
# RPR          13315
# __Cat           15
# Name: 741, dtype: object

# %% [markdown]
# Visualize Errors with seaborn pairplot. Will need to take original Dataframe, and merge with the missed categories dataframe. Will give a special category for the missed categories "Error"

# %%
df_C1D.head(2)
# Out:
#       Size  Chr    GC           _Cat     RPR  __Cat
# 0  3.23698  1.0  70.2       Bacteria  3038.0      5
# 1  8.36160  1.0  35.5  Cyanobacteria  7179.0      7

# %%
df_miss_VIS = df_miss
df_miss_VIS['MISS'] = 'ERROR'

#MERGE with original Dataframe with predictors
df_C1D_VIS = pd.merge(df_C1D[['Size', 'Chr','GC', '_Cat','RPR', '__Cat']], df_miss_VIS[['_C', 'predict1', 'MISS']],
                       left_index = True, right_index = True, how = "left")

#Take MISS Column, if not MISS, fill with Category Name for Visualization in plotly
import numpy as np

df_C1D_VIS['MISS_'] = df_C1D_VIS.apply(lambda df_C1D_VIS: df_C1D_VIS['_Cat'] if df_C1D_VIS['MISS'] is np.nan else df_C1D_VIS['MISS'], axis=1)

df_C1D_VIS.head(5)
# Out:
#       Size  Chr    GC            _Cat     RPR  __Cat  _C  predict1 MISS  \
# 0  3.23698  1.0  70.2        Bacteria  3038.0      5 NaN       NaN  NaN
# 1  8.36160  1.0  35.5   Cyanobacteria  7179.0      7 NaN       NaN  NaN
# 2  3.10640  1.0  57.1  Proteobacteria  1775.0      0 NaN       NaN  NaN
# 3  2.84394  1.0  53.9  Proteobacteria  2437.0      0 NaN       NaN  NaN
# 4  3.34025  1.0  57.2  Proteobacteria  2955.0      0 NaN       NaN  NaN
#
#             MISS_
# 0        Bacteria
# 1   Cyanobacteria
# 2  Proteobacteria
# 3  Proteobacteria
# 4  Proteobacteria

# %% [markdown]
# SEABORN pair plot of ERRORS

# %%
import seaborn as sns
# %matplotlib inline

sns.pairplot(df_C1D_VIS[['Size', 'Chr','GC','_Cat', 'RPR', 'MISS_']], hue="MISS_")
#sns.pairplot(df_C1D_VIS[['Size', 'Chr']]) #, hue="MISS_")

# As one may expect, ERRORS in classification occurs where there is the biggest overlap of the categories, 
# where size, Chromosome #, and RPR are small. Only GC% has an even error distribution over
# over the GC distribution.

# %%
df_C1D_VIS.MISS_.value_counts()
# Out:
# Proteobacteria    851
# ERROR             636
# Firmicutes        191
# Actinobacteria    117
# Euryarchaeota      61
# Bacteroidetes      60
# Bacteria           55
# Chordata           40
# Ascomycota         38
# Tenericutes        36
# Magnoliophyta      35
# Cyanobacteria      25
# Crenarchaeota      19
# Spirochaetes       19
# Eukaryota          15
# Thermotogae        12
# Chloroflexi        10
# Chlamydiae          7
# Arthropoda          7
# Aquificae           6
# Chlorobi            5
# Opisthokonta        3
# Thaumarchaeota      3
# Archaea             3
# Apicomplexa         3
# Name: MISS_, dtype: int64

# %%
# Baseline is 84%

print df_C1D_VIS._Cat.value_counts()
print 1968*1.0/len(df_C1D_VIS)
# Out:
# Proteobacteria    853
# Firmicutes        348
# Actinobacteria    250
# Euryarchaeota     126
# Bacteroidetes     112
# Bacteria          111
# Tenericutes        65
# Cyanobacteria      48
# Chordata           44
# Ascomycota         43
# Spirochaetes       39
# Magnoliophyta      37
# Crenarchaeota      37
# Thermotogae        22
# Apicomplexa        19
# Eukaryota          18
# Chloroflexi        15
# Chlamydiae         14
# Chlorobi           12
# Aquificae          11
# Arthropoda         11
# Thaumarchaeota     10
# Archaea             6
# Opisthokonta        6
# Name: _Cat, dtype: int64
# 0.871953921134

# %% [markdown]
# Create Dataframe with elements for Confusion Matrix

# %%
df_T0 = pd.DataFrame(df_miss._C.value_counts()) #False Negatives Counts
df_T1 = pd.DataFrame(df_miss.predict1.value_counts()) #False Positive Counts
df_T2 = pd.DataFrame(df_predict._C.value_counts()) #Actual Test Counts
df_T3 = pd.DataFrame(df_predict.predict1.value_counts()) #Actual Predition Counts

df_T0.columns= ['FN'] #rename prediction column
df_T1.columns= ['FP'] #rename prediction column
df_T3 = pd.concat([df_T0, df_T1, df_T2, df_T3], axis=1) #Concatenate value count dataframes for t
df_T3
# Out:
#        FN     FP   _C  predict1
# 0.0     2  610.0  442    1050.0
# 1.0   157    NaN  157       NaN
# 2.0   133    2.0  133       2.0
# 3.0    65    NaN   65       NaN
# 4.0    52    NaN   52       NaN
# 5.0    56    NaN   56       NaN
# 6.0    29    NaN   29       NaN
# 7.0    23    NaN   23       NaN
# 8.0     4    2.0   21      19.0
# 9.0     5   13.0   20      28.0
# 10.0   20    NaN   20       NaN
# 11.0    2    6.0   17      21.0
# 12.0   18    NaN   18       NaN
# 13.0   10    NaN   10       NaN
# 14.0   16    NaN   16       NaN
# 15.0    3    3.0    8       8.0
# 16.0    5    NaN    5       NaN
# 17.0    7    NaN    7       NaN
# 18.0    7    NaN    7       NaN
# 19.0    5    NaN    5       NaN
# 20.0    4    NaN    5       1.0
# 21.0    7    NaN    7       NaN
# 22.0    3    NaN    3       NaN
# 23.0    3    NaN    3       NaN

# %%
df_CAT2 = pd.concat([df_CAT1, df_T3], axis=1, join='outer', join_axes=None, ignore_index=False,
       keys=None, levels=None, names=None, verify_integrity=False)

#Replace NaNs with 0
df_CAT2 = df_CAT2.fillna(0)

#total predictions
p_tot = df_CAT2['_C'].sum()

#Missclassification Rate = (FN + FP)/total
df_CAT2['Miss%'] = 100.*(df_CAT2['FN']+df_CAT2['FP'])/p_tot
#Accuracy = 1- Misscalc
df_CAT2['Accu%'] = 100. - df_CAT2['Miss%']
#False Positive Rate = FP/actual
df_CAT2['FP%'] = df_CAT2['FP']*100./df_CAT2['_C']
#False Negative Rate = FN/actual
df_CAT2['FN%'] = df_CAT2['FN']*100./df_CAT2['_C']
df_CAT2
# Out:
#                  0   FN     FP   _C  predict1      Miss%      Accu%  \
# 0   Proteobacteria    2  610.0  442    1050.0  54.207263  45.792737
# 1       Firmicutes  157    0.0  157       0.0  13.906112  86.093888
# 2   Actinobacteria  133    2.0  133       2.0  11.957484  88.042516
# 3    Euryarchaeota   65    0.0   65       0.0   5.757307  94.242693
# 4    Bacteroidetes   52    0.0   52       0.0   4.605846  95.394154
# 5         Bacteria   56    0.0   56       0.0   4.960142  95.039858
# 6      Tenericutes   29    0.0   29       0.0   2.568645  97.431355
# 7    Cyanobacteria   23    0.0   23       0.0   2.037201  97.962799
# 8         Chordata    4    2.0   21      19.0   0.531444  99.468556
# 9       Ascomycota    5   13.0   20      28.0   1.594331  98.405669
# 10    Spirochaetes   20    0.0   20       0.0   1.771479  98.228521
# 11   Magnoliophyta    2    6.0   17      21.0   0.708592  99.291408
# 12   Crenarchaeota   18    0.0   18       0.0   1.594331  98.405669
# 13     Thermotogae   10    0.0   10       0.0   0.885740  99.114260
# 14     Apicomplexa   16    0.0   16       0.0   1.417183  98.582817
# 15       Eukaryota    3    3.0    8       8.0   0.531444  99.468556
# 16     Chloroflexi    5    0.0    5       0.0   0.442870  99.557130
# 17      Chlamydiae    7    0.0    7       0.0   0.620018  99.379982
# 18        Chlorobi    7    0.0    7       0.0   0.620018  99.379982
# 19       Aquificae    5    0.0    5       0.0   0.442870  99.557130
# 20      Arthropoda    4    0.0    5       1.0   0.354296  99.645704
# 21  Thaumarchaeota    7    0.0    7       0.0   0.620018  99.379982
# 22         Archaea    3    0.0    3       0.0   0.265722  99.734278
# 23    Opisthokonta    3    0.0    3       0.0   0.265722  99.734278
#
#            FP%         FN%
# 0   138.009050    0.452489
# 1     0.000000  100.000000
# 2     1.503759  100.000000
# 3     0.000000  100.000000
# 4     0.000000  100.000000
# 5     0.000000  100.000000
# 6     0.000000  100.000000
# 7     0.000000  100.000000
# 8     9.523810   19.047619
# 9    65.000000   25.000000
# 10    0.000000  100.000000
# 11   35.294118   11.764706
# 12    0.000000  100.000000
# 13    0.000000  100.000000
# 14    0.000000  100.000000
# 15   37.500000   37.500000
# 16    0.000000  100.000000
# 17    0.000000  100.000000
# 18    0.000000  100.000000
# 19    0.000000  100.000000
# 20    0.000000   80.000000
# 21    0.000000  100.000000
# 22    0.000000  100.000000
# 23    0.000000  100.000000

# %% [markdown]
# Redo Leave one out KFolds with Manual Multinomial Classifier

# %%
##### New Code ###############

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import patsy
from sklearn.cross_validation import LeaveOneOut, KFold

df_C1 = df_C1D[["Size","Chr","GC", "__Cat", "RPR"]] #Include target
formula_c =  '__Cat ~ (Size + Chr + GC + RPR - 1)' 
formula_c = str(formula_c)
print formula_c

Yf, Xf = patsy.dmatrices(formula_c, data=df_C1, return_type='dataframe')

Yf = np.ravel(Yf)

###NORMALIZE THE PREDICTOR VARIABLES!
Xfmat = ((Xf - Xf.mean())/ Xf.std()).values
Xfmat = pd.DataFrame(Xfmat)


# for explanation of below see: 
# https://en.wikipedia.org/wiki/Coefficient_of_determination
# calculate the total sum of squares
def calculate_r2(ytrue, ypred):
    ss_tot = np.sum([(y_ - np.mean(ytrue))**2 for y_ in ytrue])
    ss_res = np.sum([(yt - yp)**2 for yt, yp in zip(ytrue, ypred)])
    
    r2 = 1. - (ss_res/ss_tot)
    return r2
    

loo_inds = LeaveOneOut(Xf.shape[0])
Yf_test = []
loo_predictions1 = []
loo_predictions2 = []
loo_predictions3 = []

for train_inds, test_inds in loo_inds:
    #Xtest, Xtrain = Xfmat.iloc[test_inds, :], Xfmat.iloc[train_inds, :]
    Xtest, Xtrain = Xfmat.iloc[test_inds, :], Xfmat.iloc[train_inds, :]
    Ytest, Ytrain = Yf[test_inds], Yf[train_inds]
    
    model1 = LogisticRegression(multi_class='multinomial', solver='lbfgs') #()
    model2 = DecisionTreeClassifier(max_depth=4, random_state=1)
    model3 = KNeighborsClassifier(weights='distance', n_neighbors=4) ##MODEL HERE    
    
    #knnr.fit(Xtrain, Ytrain) ## FIT MODEL HERE
    model1.fit(Xtrain, Ytrain)
    model2.fit(Xtrain, Ytrain)
    model3.fit(Xtrain, Ytrain)
        
    loo_predictions1.append(model1.predict(Xtest)[0])  ##MODEL PREDICTION
    loo_predictions2.append(model2.predict(Xtest)[0])  ##MODEL PREDICTION
    loo_predictions3.append(model3.predict(Xtest)[0])  ##MODEL PREDICTION
    
    Yf_test.append(Ytest)
    

loo1_cv_r2 = calculate_r2(Yf, loo_predictions1)
loo2_cv_r2 = calculate_r2(Yf, loo_predictions2)
loo3_cv_r2 = calculate_r2(Yf, loo_predictions3)
print loo1_cv_r2
print loo2_cv_r2
print loo3_cv_r2
#print Yf
#print loo_predictions
# Out:
# __Cat ~ (Size + Chr + GC + RPR - 1)
# -0.0853974221845
# 0.0914248226578
# -0.136410780188

# %%
def mk_RESULTS(loo_predictions, Yf):

    df_predict  = pd.DataFrame() #Dataframe with test values and predictions
    loo_predictions1_ = pd.DataFrame(data=pd.Series(loo_predictions), columns={"predict1"}) 
    Yf_ = pd.DataFrame(data=pd.Series(Yf), columns={"_C"}) 
    
    ## Dataframe with test values and predictions
    df_predict = pd.concat([Yf_, loo_predictions1_], axis=1)
    df_predict.head(5)

    ## Dataframe with just missclassification
    g = (def_comp_test(df_predict)) #Indexes of misclassifications
    df_miss = df_predict.loc[g]
    df_miss.head(5)

    ## Create Dataframe with elements for Confusion Matrix
    df_T0 = pd.DataFrame(df_miss._C.value_counts()) #False Negatives Counts
    df_T1 = pd.DataFrame(df_miss.predict1.value_counts()) #False Positive Counts
    df_T2 = pd.DataFrame(df_predict._C.value_counts()) #Actual Test Counts
    df_T3 = pd.DataFrame(df_predict.predict1.value_counts()) #Actual Predition Counts

    df_T0.columns= ['FN'] #rename prediction column
    df_T1.columns= ['FP'] #rename prediction column
    df_T3 = pd.concat([df_T0, df_T1, df_T2, df_T3], axis=1) #Concatenate value count dataframes for t
    df_T3

    ## Confusion Matrix-like Dataframe
    df_CAT2 = pd.concat([df_CAT1, df_T3], axis=1, join='outer', join_axes=None, ignore_index=False,
           keys=None, levels=None, names=None, verify_integrity=False)

    #Replace NaNs with 0
    df_CAT2 = df_CAT2.fillna(0)

    #total predictions
    p_tot = df_CAT2['_C'].sum()
    #print p_tot
    
    #Missclassification Rate = (FN + FP)/total
    df_CAT2['Miss%'] = 100.*(df_CAT2['FN']+df_CAT2['FP'])/p_tot
    #Accuracy = 1- Misscalc
    df_CAT2['Accu%'] = 100. - df_CAT2['Miss%']
    #False Positive Rate = FP/actual
    df_CAT2['FP%'] = df_CAT2['FP']*100./df_CAT2['_C']
    #False Negative Rate = FN/actual
    df_CAT2['FN%'] = df_CAT2['FN']*100./df_CAT2['_C']
    return df_CAT2

# %%
#RESULTS from LOGISITIC MULTINOMIAL
print "R2 score: ", loo1_cv_r2
mk_RESULTS(loo_predictions1, Yf)
# 15       Eukaryota    6    3   18        15   0.398759  99.601241   16.666667
# 16     Chloroflexi   15    3   15         3   0.797519  99.202481   20.000000
# 17      Chlamydiae   11    6   14         9   0.753212  99.246788   42.857143
# 18        Chlorobi   12    6   12         6   0.797519  99.202481   50.000000
# 19       Aquificae   11    7   11         7   0.797519  99.202481   63.636364
# 20      Arthropoda    6    6   11        11   0.531679  99.468321   54.545455
# 21  Thaumarchaeota   10   11   10        11   0.930439  99.069561  110.000000
# 22         Archaea    6    4    6         4   0.443066  99.556934   66.666667
# 23    Opisthokonta    6    3    6         3   0.398759  99.601241   50.000000
#
#            FN%
# 0    42.555686
# 1    70.689655
# 2    78.400000
# 3    92.063492
# 4    98.214286
# 5    91.891892
# 6    52.307692
# 7    97.916667
# 8    11.363636
# 9    30.232558
# 10   94.871795
# 11   18.918919
# 12   97.297297
# 13   95.454545
# 14   57.894737
# 15   33.333333
# 16  100.000000
# 17   78.571429
# 18  100.000000
# 19  100.000000
# 20   54.545455
# 21  100.000000
# 22  100.000000
# 23  100.000000

# %%
t1 = model1
t2 = model2
t3 = model3
print t1.intercept_, t1.coef_[0]
#print t2.feature_importances_
#print t3.outputs_2d_

house_coefs = pd.DataFrame({'feature': Xf.columns, "LOG_coeff": t1.coef_[0], "DT_Feature_importance": t2.feature_importances_})
house_coefs
# Out:
# [ 3.81121346  2.47415249  2.28027709  1.34428068  1.7875307   1.54557771
#  -0.52346758  1.21881533 -4.07334933  0.64803731  0.39589975 -2.58767441
#   0.18693774 -0.08385524 -0.08496768 -2.2367077  -0.04741646 -0.4975344
#  -0.49017607 -0.61516844 -0.80876878 -0.64486184 -1.52779546 -1.47097888] [-1.10517893 -1.45669738  0.13203503  1.27868305]
#    DT_Feature_importance  LOG_coeff feature
# 0               0.192710  -1.105179    Size
# 1               0.381454  -1.456697     Chr
# 2               0.015498   0.132035      GC
# 3               0.410337   1.278683     RPR

# %% [markdown]
# Set up for Next Model

# %%
# Logistic Regression on Kingdom for Classification Eukaryotes

df_C1 = df_C1D[["Size","Chr","GC", "RPR", "_Cat"]] 

Y = df_C1D["_Cat"] #target

# %%
##Patsy
df_C1 = df_C1D[["Size","Chr","GC", "_Cat", "RPR"]] #Include target
formula_c2 =  '_Cat ~ Size + Chr + GC + RPR - 1' #Score: 0.574834634511
formula_c2 = str(formula_c2)

# %%
from patsy import dmatrices

Yb2, Xb = dmatrices(formula_c2, data = df_C1D, return_type='dataframe')

###NORMALIZE THE PREDICTOR VARIABLES!
Xb_mat = ((Xb - Xb.mean())/ Xb.std()).values

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
def mk_RESULTS1(loo_predictions, Yf, Category):

    df_predict  = pd.DataFrame() #Dataframe with test values and predictions
    #loo_predictions1_ = pd.DataFrame(data=pd.Series(loo_predictions.values), columns={"predict1"}) 
    #Yf_ = pd.DataFrame(data=pd.Series(Yf.values), columns={"_C"}) 
    loo_predictions1_ = loo_predictions
    Yf_ = Yf
    
    Yf_.columns = ["_C"]
    loo_predictions1_.columns = ["predict1"]
    #print Yf_.columns
    
    ##CHECK
    #print "QQQ", Yf_[388], loo_predictions1_[388] 
    #print Yf_.head(5)
    
    ## Dataframe with test values and predictions
    df_predict = pd.concat([Yf_, loo_predictions1_], axis=1)
    #print "RRR"
    df_predict.columns = ["_C","predict1"]
    #print df_predict.head(5)
    #print df_predict.columns

    ## Dataframe with just missclassification
    g = (def_comp_test(df_predict)) #Indexes of misclassifications
    h = (def_comp_test2(df_predict)) #Indexes of correctly classified positive

    #print type(g)
    df_miss = df_predict.loc[g]
    #print df_miss.head(5)
    
    ##Seaborn plotly of missed categories
    df_miss_VIS = df_miss
    df_miss_VIS[('MISS_')] = 'ERROR'
    
    #Get categories "1"
    df_miss_not = df_predict.loc[h]
    #print df_miss_not.head(10)
    
    #Concatenate category 1 and miss dataframes
    df_miss_VIS1 = pd.DataFrame()
    df_miss_VIS1 = pd.concat([df_miss_not, df_miss_VIS], axis=0)
    index_list = df_miss_VIS1.index
    df_C1D_VIS1 = df_C1D.loc[index_list]
    
    #MERGE with original Dataframe with predictors
    df_C1D_VIS = pd.concat([df_C1D_VIS1, df_miss_VIS1], axis=1)
    
    
#     df_C1D_VIS = pd.merge(df_C1D[['Size', 'Chr','GC','Kingdom', 'RPR', 'King_C']], df_miss[['_C', 'predict1', 'MISS']],
#         left_index = True, right_index = True, how = "right") #right merge for category1

#     #MERGE with original Dataframe with predictors
#     df_C1D_VIS = pd.merge(df_C1D[['Size', 'Chr','GC','Kingdom', 'RPR', 'King_C']], df_miss_VIS1[['_C', 'predict1']],
#                            left_index = True, right_index = True, how = "right") #right merge for category1

#     Concatenate category 1 and miss dataframes
#     df_miss_VIS2 = pd.concat([df_C1D, df_miss_VIS1], axis=1)


    
#     #Concatenate category 1 and miss dataframes
#     df_miss_VIS2 = pd.concat([df_miss_VIS, df_miss_not], axis=0, join='outer', join_axes=None, ignore_index=False, 
#                             keys=None, levels=None, names=None, verify_integrity=False)
    
#     #MERGE with original Dataframe with predictors
#     df_C1D_VIS = pd.merge(df_C1D[['Size', 'Chr','GC','Kingdom', 'RPR', 'King_C']], df_miss_VIS2[['_C', 'predict1', 'MISS']],
#                            left_index = True, right_index = True, how = "right") #right merge for category1

    

    #Take MISS Column, if not MISS, fill with Category Name for Visualization in plotly
    df_C1D_VIS[('MISS_'+Category)] = df_C1D_VIS.apply(lambda df_C1D_VIS: ('CORRECT'+Category) if df_C1D_VIS['MISS_'] is np.nan else df_C1D_VIS['_Cat'], axis=1)

#     #print df_C1D_VIS.head(10)
    sns.pairplot(df_C1D_VIS[['Size', 'Chr','GC','_Cat', 'RPR', ('MISS_'+Category)]], hue=("MISS_"+Category), palette="muted")
    

    ## Create Dataframe with elements for Confusion Matrix
    df_T0 = pd.DataFrame(df_miss._C.value_counts()) #False Negatives Counts
    df_T1 = pd.DataFrame(df_miss.predict1.value_counts()) #False Positive Counts
    df_T2 = pd.DataFrame(df_predict._C.value_counts()) #Actual Test Counts
    df_T3 = pd.DataFrame(df_predict.predict1.value_counts()) #Actual Predition Counts

    df_T0.columns= ['FN'] #rename prediction column
    df_T1.columns= ['FP'] #rename prediction column
    df_T3 = pd.concat([df_T0, df_T1, df_T2, df_T3], axis=1) #Concatenate value count dataframes for t
    
    df_CAT2 = df_T3
    
    

    #Replace NaNs with 0
    df_CAT2 = df_CAT2.fillna(0)

    #total predictions
    p_tot = df_CAT2['_C'].sum()
    #print p_tot
    
    #Missclassification Rate = (FN + FP)/total
    df_CAT2['Miss%'] = 100.*(df_CAT2['FN']+df_CAT2['FP'])/p_tot
    #Accuracy = 1- Misscalc
    df_CAT2['Accu%'] = 100. - df_CAT2['Miss%']
    #False Positive Rate = FP/actual
    df_CAT2['FP%'] = df_CAT2['FP']*100./df_CAT2['_C']
    #False Negative Rate = FN/actual
    df_CAT2['FN%'] = df_CAT2['FN']*100./df_CAT2['_C']
    
    #Sensitivity/Recall: TP/Actual
    df_CAT2['Recall'] = (df_CAT2['predict1'] - df_CAT2['FP'])*100./df_CAT2['_C']
    #Precision: TP/Predicted Yes
    df_CAT2['Precision'] = (df_CAT2['predict1'] - df_CAT2['FP'])*100./df_CAT2['predict1']
    
#     ##return pd.DataFrame(df_CAT2.iloc[1]).T
    
    return df_CAT2.loc[1]

    #return df_miss_VIS1

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.cross_validation import cross_val_score

for i, j in enumerate(Yb2.columns): #Loop through Classification 
# for i in [0]:
#     j = Yb2.columns[0]
    print "*********************************"
    print i, j
    Yb_0 = Yb2.iloc[:,i] #Target Series
    
    #Separate Logistic Model, kfold cv
    logreg0 = LogisticRegressionCV(cv=5) #Logistic Regression
    #logreg0 = DecisionTreeClassifier(max_depth=5) # Decision Tree
    
    #fit a model on the training data and test on the testing data
    #model0 = logreg0.fit(Xb_mat, Yb_0) #Logistic Regression
    
    logreg0.fit(X=Xb_mat, y=Yb_0) #Decision Tree
    scores = cross_val_score(estimator=logreg0, X=Xb_mat, y=Yb_0, cv=20, n_jobs=4) #Decision Tre
    
    #predictions
    predictions0 = pd.Series(logreg0.predict(Xb_mat)) #Logistic Regression


    
    #print "PREDICTIONS ", len(predictions0), len(Yb_0)
    
    print "ACTUALS"
    print Yb_0.value_counts()
    print "PREDICTIONS"
    print predictions0.value_counts()
    print "ACCURACY: ", accuracy_score(Yb_0, predictions0)
    print "PRECISION: ", precision_score(Yb_0, predictions0)
    print "RECALL: ", recall_score(Yb_0, predictions0)
    house_coefs = pd.DataFrame({'feature': Xb.columns, "coef": model0.coef_.ravel()})
    #print house_coefs
    print "+++++++++++++++++++++++++++++++"
    
    #print mk_RESULTS1(predictions0, Yb_0, j) #Recall < Precision, more FN than FP
    
    #df_A = (mk_RESULTS1(predictions0, Yb_0, j))
    
    #print df_A.loc[388]
    
    #print df_C1D.loc[181] 
    #print "ZZZ", predictions0[181] #, Yb_0[181]
    ##print df_A.loc[58]
    #print Yb_0
# Out:
# *********************************
# 0 _Cat[Actinobacteria]
# ACTUALS
# 0.0    2007
# 1.0     250
# Name: _Cat[Actinobacteria], dtype: int64
# PREDICTIONS
# 0.0    2234
# 1.0      23
# dtype: int64
# ACCURACY:  0.894107221976
# PRECISION:  0.739130434783
# RECALL:  0.068
# +++++++++++++++++++++++++++++++
# *********************************
# 1 _Cat[Apicomplexa]
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 19 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=20.
#   % (min_labels, self.n_folds)), Warning)
# ACTUALS
# 0.0    2238
# 1.0      19
# Name: _Cat[Apicomplexa], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.99158174568
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 2 _Cat[Aquificae]
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 11 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=20.
#   % (min_labels, self.n_folds)), Warning)
# ACTUALS
# 0.0    2246
# 1.0      11
# Name: _Cat[Aquificae], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.995126273815
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 3 _Cat[Archaea]
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 6 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=20.
#   % (min_labels, self.n_folds)), Warning)
# ACTUALS
# 0.0    2251
# 1.0       6
# Name: _Cat[Archaea], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.997341603899
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 4 _Cat[Arthropoda]
# ACTUALS
# 0.0    2246
# 1.0      11
# Name: _Cat[Arthropoda], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.995126273815
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 5 _Cat[Ascomycota]
# ACTUALS
# 0.0    2214
# 1.0      43
# Name: _Cat[Ascomycota], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.980948161276
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 6 _Cat[Bacteria]
# ACTUALS
# 0.0    2146
# 1.0     111
# Name: _Cat[Bacteria], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.950819672131
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 7 _Cat[Bacteroidetes]
# ACTUALS
# 0.0    2145
# 1.0     112
# Name: _Cat[Bacteroidetes], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.950376606114
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 8 _Cat[Chlamydiae]
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 14 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=20.
#   % (min_labels, self.n_folds)), Warning)
# ACTUALS
# 0.0    2243
# 1.0      14
# Name: _Cat[Chlamydiae], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.993797075764
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 9 _Cat[Chlorobi]
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 12 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=20.
#   % (min_labels, self.n_folds)), Warning)
# ACTUALS
# 0.0    2245
# 1.0      12
# Name: _Cat[Chlorobi], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.994683207798
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 10 _Cat[Chloroflexi]
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 15 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=20.
#   % (min_labels, self.n_folds)), Warning)
# ACTUALS
# 0.0    2242
# 1.0      15
# Name: _Cat[Chloroflexi], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.993354009747
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 11 _Cat[Chordata]
# ACTUALS
# 0.0    2213
# 1.0      44
# Name: _Cat[Chordata], dtype: int64
# PREDICTIONS
# 0.0    2223
# 1.0      34
# dtype: int64
# ACCURACY:  0.992910943731
# PRECISION:  0.911764705882
# RECALL:  0.704545454545
# +++++++++++++++++++++++++++++++
# *********************************
# 12 _Cat[Crenarchaeota]
# ACTUALS
# 0.0    2220
# 1.0      37
# Name: _Cat[Crenarchaeota], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.983606557377
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 13 _Cat[Cyanobacteria]
# ACTUALS
# 0.0    2209
# 1.0      48
# Name: _Cat[Cyanobacteria], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.978732831192
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 14 _Cat[Eukaryota]
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 18 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=20.
#   % (min_labels, self.n_folds)), Warning)
# ACTUALS
# 0.0    2239
# 1.0      18
# Name: _Cat[Eukaryota], dtype: int64
# PREDICTIONS
# 0.0    2247
# 1.0      10
# dtype: int64
# ACCURACY:  0.996455471865
# PRECISION:  1.0
# RECALL:  0.555555555556
# +++++++++++++++++++++++++++++++
# *********************************
# 15 _Cat[Euryarchaeota]
# ACTUALS
# 0.0    2131
# 1.0     126
# Name: _Cat[Euryarchaeota], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.944173681879
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 16 _Cat[Firmicutes]
# ACTUALS
# 0.0    1909
# 1.0     348
# Name: _Cat[Firmicutes], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.845813026141
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 17 _Cat[Magnoliophyta]
# ACTUALS
# 0.0    2220
# 1.0      37
# Name: _Cat[Magnoliophyta], dtype: int64
# PREDICTIONS
# 0.0    2230
# 1.0      27
# dtype: int64
# ACCURACY:  0.991138679663
# PRECISION:  0.814814814815
# RECALL:  0.594594594595
# +++++++++++++++++++++++++++++++
# *********************************
# 18 _Cat[Opisthokonta]
# ACTUALS
# 0.0    2251
# 1.0       6
# Name: _Cat[Opisthokonta], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.997341603899
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 19 _Cat[Proteobacteria]
# ACTUALS
# 0.0    1404
# 1.0     853
# Name: _Cat[Proteobacteria], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.622064687638
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 20 _Cat[Spirochaetes]
# ACTUALS
# 0.0    2218
# 1.0      39
# Name: _Cat[Spirochaetes], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.982720425343
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 21 _Cat[Tenericutes]
# ACTUALS
# 0.0    2192
# 1.0      65
# Name: _Cat[Tenericutes], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.971200708906
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 22 _Cat[Thaumarchaeota]
# /Users/noriogura/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 10 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=20.
#   % (min_labels, self.n_folds)), Warning)
# ACTUALS
# 0.0    2247
# 1.0      10
# Name: _Cat[Thaumarchaeota], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.995569339832
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++
# *********************************
# 23 _Cat[Thermotogae]
# ACTUALS
# 0.0    2235
# 1.0      22
# Name: _Cat[Thermotogae], dtype: int64
# PREDICTIONS
# 0.0    2257
# dtype: int64
# ACCURACY:  0.99025254763
# PRECISION:  0.0
# RECALL:  0.0
# +++++++++++++++++++++++++++++++

# %%
df_sub2_.head(4)
# Out:
#    Unnamed: 0  Unnamed: 0.1                            Organism   Kingdom  \
# 0           0             0  'Deinococcus soli' Cha et al. 2014  Bacteria
# 1           1            12                Acaryochloris marina  Bacteria
# 2           2            13                         Acetobacter  Bacteria
# 3           3            14               Acetobacter ghanensis  Bacteria
#
#       Size  Chr            url     RPR    GC  \
# 0  3.23698  1.0  /genome/38191  3038.0  70.2
# 1  8.36160  1.0   /genome/1179  7179.0  35.5
# 2  3.10640  1.0  /genome/18005  1775.0  57.1
# 3  2.84394  1.0  /genome/42306  2437.0  53.9
#
#                                              Classes  \
# 0  [[[, Deinococcus, Deinococcaceae, Deinococcale...
# 1  [[[, Acaryochloris, FamilyI, SubsectionI, Cyan...
# 2  [[[, Acetobacteraceae, Rhodospirillales, Alpha...
# 3  [[[, Acetobacter, Acetobacteraceae, Rhodospiri...
#
#                                            Classsub1  Taxonomy      _Cat
# 0  [Deinococcus, Deinococcaceae, Deinococcales, D...  Bacteria  Bacteria
# 1  [Acaryochloris, FamilyI, SubsectionI, Cyanobac...  Bacteria  Bacteria
# 2  [Acetobacter, Acetobacteraceae, Rhodospirillal...  Bacteria  Bacteria
# 3  [Acetobacter, Acetobacteraceae, Rhodospirillal...  Bacteria  Bacteria

# %%
#df_sub2_['Kingdom']

# %% [markdown]
# Multinomial Classification for predicting NCBI labeled 'Kingdoms'¶

# %% [markdown]
# For a first pass that has an existing classification from the NCBI database, we can classify according to Kingdom using several models. This is a supervised multinomial classification problem, so it makes sense to use the machine learning models of Logistic Regression, Decision Tree Classifiers, and KNN. The code below using the simple linear formula 'C(Kingdom) ~ Size + Chr + GC + RPR - 1' takes advantages of patsies to arrange the data in matricies for analysis. The predictor variables are normalized so that we can compare relative importance between the predictor variables of Size (Nucleotide length), Chromosome number (Chr), Guanine Cytosine % (GC), and Protein count (RPR).

# %% [markdown]
# Manually assign Multinomial categories of Kingdoms
