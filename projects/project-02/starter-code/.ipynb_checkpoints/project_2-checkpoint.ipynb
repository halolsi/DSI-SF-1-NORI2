# %% [markdown]
# # Project 2
# ## Step 1: Exploring your data.
#
# ##### Load your data in using Pandas and start to explore. Save all of your early exploration code here and include in your final submission.

# %%
pwd
# Out:
# u'/Users/noriogura/Desktop/DSI-SF-1-NORI2/projects/project-02/starter-code'

# %%
import pandas as pd
import numpy as np
import csv

data_path= "../assets/billboard.csv"
a = pd.read_csv(data_path)

a.head() #Read columns
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week     ...      \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0     ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0     ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0     ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0     ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0     ...
#
# ...

# %%
a = pd.read_csv(data_path)

# %%
def def_count_unique(df):
    cols = pd.Series(df.columns.values) #Series of column headers
    
    y = []
    for x in df:
        z = len(np.unique(df[x]))
        y.append(z)
                
#    unique_df = pd.DataFrame(y).T #For some reason, y as list has 83 rows instead of columns, had to transpose 
#    unique_df.columns = a.columns.values
    
    q = pd.DataFrame(y, index = df.columns.values, columns=["unique_s"])
    #print q
    r = q.sort_values("unique_s", ascending=False)
    return r.T

# %%
b = def_count_unique(a)
b
# Out:
#           x76th.week  x58th.week  x55th.week  x54th.week  x53rd.week  \
# unique_s         317         317         317         317         317
#
#           x52nd.week  x51st.week  x50th.week  x48th.week  x47th.week  ...   \
# unique_s         317         317         317         317         317  ...
#
#           time  x5th.week  x4th.week  x3rd.week  x2nd.week  date.entered  \
# unique_s   126        116        105         89         77            68
#
#           x1st.week  date.peaked  genre  year
# unique_s         63           54     11     1
#
# [1 rows x 83 columns]

# %%
#REORDER ORGINAL DATAFRAME WITH NEW ORDER
#print b

def def_reorder(df_orig, df_new):
    c = pd.DataFrame()
    for x in df_new.columns:
        c[x] = df_orig[x]
    return c

# %%
c = def_reorder(a,b)
c.head()
# Out:
#    x76th.week  x58th.week  x55th.week  x54th.week  x53rd.week  x52nd.week  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    x51st.week  x50th.week  x48th.week  x47th.week  ...   time  x5th.week  \
# 0         NaN         NaN         NaN         NaN  ...   3:38       23.0
# 1         NaN         NaN         NaN         NaN  ...   4:18        2.0
# 2         NaN         NaN         NaN         NaN  ...   4:07       20.0
# 3         NaN         NaN         NaN         NaN  ...   3:45        2.0
# 4         NaN         NaN         NaN         NaN  ...   3:38       23.0
#
#    x4th.week  x3rd.week  x2nd.week  date.entered  x1st.week  date.peaked  \
# ...

# %%
#PATTERNS - FIND COLUMNS with LARGE NUMBER OF UNIQUE VALUES WITH SIMILAR NAMES - remove them
str_a = ".we"

cols = b.columns

m0 = [str_a not in x for x in cols] # COLUMNS without ".we" in it "week"/"wek"

m0 = c.loc[:,m0]
m0.head()
#m.sort_values(axis=0)
#unique_df[mask]
#filtered = unique_df.mask(lambda x: x['column'] == 'year')
# Out:
#                                    track      artist.inverted  time  \
# 0               Independent Women Part I      Destiny's Child  3:38
# 1                           Maria, Maria              Santana  4:18
# 2                     I Knew I Loved You        Savage Garden  4:07
# 3                                  Music              Madonna  3:45
# 4  Come On Over Baby (All I Want Is You)  Aguilera, Christina  3:38
#
#   date.entered date.peaked genre  year
# 0   2000-09-23  2000-11-18  Rock  2000
# 1   2000-02-12  2000-04-08  Rock  2000
# 2   1999-10-23  2000-01-29  Rock  2000
# 3   2000-08-12  2000-09-16  Rock  2000
# 4   2000-08-05  2000-10-14  Rock  2000

# %%
def d_rid_dots(t):
    z0=[x.replace(".","") for x in t]
    return z0

# %%
m0.columns = d_rid_dots(m0.columns.values.tolist()) #SHORT DF

c.columns= d_rid_dots(c.columns.values.tolist()) #COMPLETE DF

# %%
m1 = m0

z3 = m1.groupby(list(m1.columns)).count() #GROUPBY

print list(m1.columns)

m1.sort_values(list(m1.columns))
#m.shape[0]

print type(m1)
m1.head()

m1["one"] = [1]*len(m1.index)

m1.head()

#print list(m['track'].values)

#n['track'] = m1['track'].value_counts() > 1

#print n.head(10)
#x = pd.DataFrame({'track':list(m['track'].values)})#, 'counts':counts})
# Out:
# ['track', 'artistinverted', 'time', 'dateentered', 'datepeaked', 'genre', 'year', 'one']
# <class 'pandas.core.frame.DataFrame'>
# /Users/noriogura/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    track       artistinverted  time  \
# 0               Independent Women Part I      Destiny's Child  3:38
# 1                           Maria, Maria              Santana  4:18
# 2                     I Knew I Loved You        Savage Garden  4:07
# 3                                  Music              Madonna  3:45
# 4  Come On Over Baby (All I Want Is You)  Aguilera, Christina  3:38
#
#   dateentered  datepeaked genre  year  one
# ...

# %% [markdown]
# ## Step 2: Clean your data.

# %% [markdown]
# ##### Do some rudimentary cleaning. Rename any columns that are poorly named, shorten any strings that may be too long, fill in any missing values.

# %%
#FUNCTION: Look for Duplicates
def check_duplicates(df):
    return True

#FUNCTION: Look for NaN
def check_NaN(df):
    print df.isnull().values.any()

check_NaN(a)

#FUNCTION: Look for Blanks
def check_blanks(dataframe):
    return True

#FUNCTION: Bad data types
def check_types(dataframe):
    print c_long.dtypes
    return True

#FUNCTION: Dimensions
def check_dimensions(dataframe):
    return True

#FUNCTION: Value lengths
def check_valuelen(dataframe):
    return True

#CHECK DATA TYPES
print c_long.dtypes
# Out:
# True
# track              object
# artistinverted     object
# time               object
# dateentered        object
# datepeaked         object
# genre              object
# year                int64
# Week               object
# Ranking           float64
# dtype: object

# %% [markdown]
# ##### Using Pandas' built in `melt` function, pivot the weekly ranking data to be long rather than wide. As a result, you will have removed the 72 'week' columns and replace it with two: Week and Ranking. There will now be multiple entries for each song, one for each week on the Billboard rankings.

# %%
#Column names with week/wek
#CLEANED ABOVE ALREADY

id_cols = m0.columns.tolist() 
print id_cols

## Melt Function
c_long = pd.melt(c, id_vars=id_cols, value_vars=None, var_name='Week', value_name='Ranking')

##Sort by Ranking
c_long.sort_values(['genre','Ranking','track','artistinverted'])
print c_long.head()

print c_long.shape #24092 ROWS, 9 COLUMNS
print c_long.describe()
print c_long.head(10)
# Out:
# ['track', 'artistinverted', 'time', 'dateentered', 'datepeaked', 'genre', 'year', 'one']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-209-40a6984e78cf> in <module>()
#       6
#       7 ## Melt Function
# ----> 8 c_long = pd.melt(c, id_vars=id_cols, value_vars=None, var_name='Week', value_name='Ranking')
#       9
#      10 ##Sort by Ranking
#
# /Users/noriogura/anaconda/lib/python2.7/site-packages/pandas/core/reshape.pyc in melt(frame, id_vars, value_vars, var_name, value_name, col_level)
#     784     mdata = {}
#     785     for col in id_vars:
# --> 786         mdata[col] = np.tile(frame.pop(col).values, K)
#     787
#     788     mcolumns = id_vars + var_name + [value_name]
#
# /Users/noriogura/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in pop(self, item)
#     503         Return item and drop from frame. Raise KeyError if not found.
# ...

# %%
########CLEAN UP NaN's#########################

mask = ~c_long.isnull() #MASK for Good Values

row_mask = mask.apply(np.sum, axis=1) #IF ALL TRUE(non null) sum should == column length
f = lambda x: x == mask.shape[1]
row_mask = row_mask.apply(f)

mask = mask[row_mask]

#print mask.iloc[325:]
#print row_mask.iloc[325:]


##Apply Mask to df_c_long
c_long1= c_long[mask]
c_long1

#df.apply(np.sum, axis=1)
#m0 = [str_a not in x for x in cols] # COLUMNS without ".we" in it "week"/"wek"
#m0 = c.loc[:,m0]
# Out:
#                                                    track    artistinverted  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                                                    NaN               NaN
# 5                                                    NaN               NaN
# 6                                                    NaN               NaN
# 7                                                    NaN               NaN
# 8                                                    NaN               NaN
# 9                                                    NaN               NaN
# 10                                                   NaN               NaN
# ...

# %%
# MIN of COLS

def d_min_ser(df):
    f = c_long1.apply(np.min, axis=0)
    return pd.Series(f) #COLUMNS

# %%
#MAX of COLS
def d_max_ser(df):
    f = df.apply(np.max, axis=0) #COLUMNS
    return pd.Series(f)

# %%
#DATATYPE of COLS
def d_type(df):
    f = df.apply(np.dtype, axis=0) #COLUMNS
    return pd.Series(f)

# %%
desc = pd.DataFrame()
desc['min'] = d_min_ser(c_long1)
desc['max'] = d_max_ser(c_long1)
desc['type'] = d_type(c_long1)
desc
# Out:
#                         min              max    type
# track                   inf       www.memory  object
# artistinverted          inf  matchbox twenty  object
# time                    inf             7:50  object
# dateentered             inf       2000-12-30  object
# datepeaked              inf       2000-12-30  object
# genre                   inf             Rock  object
# year            2000.000000             2000  object
# Week                    inf         x9thweek  object
# Ranking            1.000000              100  object

# %%
h1 = c_long1['Ranking'].get_dtype_counts().astype(list)
h2= c_long1['genre'].get_dtype_counts().astype(list)
h = c_long1.genre.get_dtype_counts().astype(list)
#print c_long1.track
type(c_long1['Ranking'])
# Out:
# pandas.core.series.Series

# %%
c_long2 = c_long1
c_long2.replace([np.inf, -np.inf], np.nan)

desc = pd.DataFrame()
desc['min'] = d_min_ser(c_long2)
desc['max'] = d_max_ser(c_long2)
desc['type'] = d_type(c_long2)
desc

#df.drop(df.index[[1,3]])

#idx = row_mask.apply(index.value, axis=0)  #Earlier list of NaN
#idx

for x, y in enumerate(row_mask): 
    if y is True: #is None
        print y
    else:
        print y
        
#A= pd.DataFrame([1,2,3,4])
#B= pd.DataFrame([True, False, True, False])
#A(B)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
c_long1.describe()

#idx = df[df['BoolCol']].index.tolist()
# Out:
#          year      Ranking
# count  5279.0  5279.000000
# mean   2000.0    51.228452
# std       0.0    28.906470
# min    2000.0     1.000000
# 25%    2000.0    26.000000
# 50%    2000.0    52.000000
# 75%    2000.0    76.000000
# max    2000.0   100.000000

# %%
dfc2 = c_long1
mask = dfc2.apply

f = lambda x: x == mask.shape[1]
row_mask = dfc2.apply(f) #IF ALL TRUE(non null) sum should == column length
row_mask = row_mask.apply(f)


#idx = dfc2['Week' ].index.tolist()

# %% [markdown]
# ##### Using a plotting utility of your choice, create visualizations that will provide context to your data. There is no minimum or maximum number of graphs you should generate, but there should be a clear and consistent story being told. Give insights to the distribution, statistics, and relationships of the data.

# %% [markdown]
# ## Step 4: Create a Problem Statement.
#
# ##### Having explored the data, come up with a problem statement for this data set. You can feel free to introduce data from any other source to support your problem statement, just be sure to provide a link to the origin of the data. Once again- be creative!

# %% [markdown]
# ## Step 5: Brainstorm your Approach.
# ##### In bullet-list form, provide a proposed approach for evaluating your problem statement. This can be somewhat high-level, but start to think about ways you can massage the data for maximum efficacy.

# %% [markdown]
# ## Step 6: Create a blog post with your code snippets and visualizations.
# ##### Data Science is a growing field, and the Tech industry thrives off of collaboration and sharing of knowledge. Blogging is a powerful means for pushing the needle forward in our field. Using your blogging platform of choice, create a post describing each of the 5 steps above. Rather than writing a procedural text, imagine you're describing the data, visualizations, and conclusions you've arrived at to your peers. Aim for roughly 800-1,000 words.

# %% [markdown]
# ## BONUS: The Content Managers working for the Podcast Publishing Company have recognized you as a thought leader in your field. They've asked you to pen a white paper (minimum 600 words) on the subject of 'What It Means To Have Clean Data'. This will be an opinion piece read by a wide audience, so be sure to back up your statements with real world examples or scenarios.
#
# ##### Hint: To get started, look around on the internet for articles, blog posts, papers, youtube videos, podcasts, reddit discussions, anything that will help you understand the challenges and implications of dealing with big data. This should be a personal reflection on everything you've learned this week, and the learning goals that have been set out for you going forward.

# %%
d = {
    col:ol.replace('Q','')
}
