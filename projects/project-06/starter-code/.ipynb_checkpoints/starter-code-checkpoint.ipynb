# %% [markdown]
# # Project 6: IMDB
#
# This project involves NLP, decision trees, bagging, boosting, and more!
#
# ---

# %% [markdown]
# ## Load packages
#
# You are likely going to need to install the `imdbpie` package:
#
#     > pip install imdbpie
#
# ---

# %%
import os
import subprocess
import collections
import re
import csv
import json

import pandas as pd
import numpy as np
import scipy

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

import psycopg2
import requests
from imdbpie import Imdb
import nltk

import urllib
from bs4 import BeautifulSoup
import nltk

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ---
#
# ## Part 1: Acquire the Data
#
# You will connect to the IMDB API to query for movies.
#
# See here for documentation on how to use the package:
#
# https://github.com/richardasaurus/imdb-pie

# %% [markdown]
# #### 1. Connect to the IMDB API

# %%
from imdbpie import Imdb
imdb = Imdb()
imdb = Imdb(anonymize=True) # to proxy requests

# Creating an instance with caching enabled
# Note that the cached responses expire every 2 hours or so.
# The API response itself dictates the expiry time)
imdb = Imdb(cache=True)

# %% [markdown]
# #### 2. Query the top 250 rated movies in the database

# %%
imdb.top_250()
# Out:
# [{u'can_rate': True,
#   u'image': {u'height': 1388,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_.jpg',
#    u'width': 933},
#   u'num_votes': 1660260,
#   u'rating': 9.3,
#   u'tconst': u'tt0111161',
#   u'title': u'The Shawshank Redemption',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjEyMjcyNDI4MF5BMl5BanBnXkFtZTcwMDA5Mzg3OA@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 1136368,
#   u'rating': 9.2,
#   u'tconst': u'tt0068646',
#   u'title': u'The Godfather',
#   u'type': u'feature',
#   u'year': u'1972'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDc2NTM3MzU1Nl5BMl5BanBnXkFtZTcwMTA5Mzg3OA@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 776109,
#   u'rating': 9,
#   u'tconst': u'tt0071562',
#   u'title': u'The Godfather: Part II',
#   u'type': u'feature',
#   u'year': u'1974'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_.jpg',
#    u'width': 1383},
#   u'num_votes': 1645935,
#   u'rating': 9,
#   u'tconst': u'tt0468569',
#   u'title': u'The Dark Knight',
#   u'type': u'feature',
#   u'year': u'2008'},
#  {u'can_rate': True,
#   u'image': {u'height': 679,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMzMwMTM4MDU2N15BMl5BanBnXkFtZTgwMzQ0MjMxMDE@._V1_.jpg',
#    u'width': 439},
#   u'num_votes': 849374,
#   u'rating': 8.9,
#   u'tconst': u'tt0108052',
#   u'title': u"Schindler's List",
#   u'type': u'feature',
#   u'year': u'1993'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BODQwOTc5MDM2N15BMl5BanBnXkFtZTcwODQxNTEzNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 437922,
#   u'rating': 8.9,
#   u'tconst': u'tt0050083',
#   u'title': u'12 Angry Men',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkxMTA5OTAzMl5BMl5BanBnXkFtZTgwNjA5MDc3NjE@._V1_.jpg',
#    u'width': 1010},
#   u'num_votes': 1301183,
#   u'rating': 8.9,
#   u'tconst': u'tt0110912',
#   u'title': u'Pulp Fiction',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 519,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjE4MjA1NTAyMV5BMl5BanBnXkFtZTcwNzM1NDQyMQ@@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 1194767,
#   u'rating': 8.9,
#   u'tconst': u'tt0167260',
#   u'title': u'The Lord of the Rings: The Return of the King',
#   u'type': u'feature',
#   u'year': u'2003'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BOTQ5NDI3MTI4MF5BMl5BanBnXkFtZTgwNDQ4ODE5MDE@._V1_.jpg',
#    u'width': 1344},
#   u'num_votes': 494916,
#   u'rating': 8.9,
#   u'tconst': u'tt0060196',
#   u'title': u'The Good, the Bad and the Ugly',
#   u'type': u'feature',
#   u'year': u'1966'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIwNTYzMzE1M15BMl5BanBnXkFtZTcwOTE5Mzg3OA@@._V1_.jpg',
#    u'width': 336},
#   u'num_votes': 1321861,
#   u'rating': 8.9,
#   u'tconst': u'tt0137523',
#   u'title': u'Fight Club',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNTEyMjAwMDU1OV5BMl5BanBnXkFtZTcwNDQyNTkxMw@@._V1_.jpg',
#    u'width': 342},
#   u'num_votes': 1218200,
#   u'rating': 8.8,
#   u'tconst': u'tt0120737',
#   u'title': u'The Lord of the Rings: The Fellowship of the Ring',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjE2MzQwMTgxN15BMl5BanBnXkFtZTcwMDQzNjk2OQ@@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 821418,
#   u'rating': 8.8,
#   u'tconst': u'tt0080684',
#   u'title': u'Star Wars: Episode V - The Empire Strikes Back',
#   u'type': u'feature',
#   u'year': u'1980'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTI1Nzk1MzQwMV5BMl5BanBnXkFtZTYwODkxOTA5._V1_.jpg',
#    u'width': 331},
#   u'num_votes': 1225084,
#   u'rating': 8.8,
#   u'tconst': u'tt0109830',
#   u'title': u'Forrest Gump',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 1037,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_.jpg',
#    u'width': 700},
#   u'num_votes': 1439479,
#   u'rating': 8.8,
#   u'tconst': u'tt1375666',
#   u'title': u'Inception',
#   u'type': u'feature',
#   u'year': u'2010'},
#  {u'can_rate': True,
#   u'image': {u'height': 512,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTAyNDU0NjY4NTheQTJeQWpwZ15BbWU2MDk4MTY2Nw@@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 1080893,
#   u'rating': 8.7,
#   u'tconst': u'tt0167261',
#   u'title': u'The Lord of the Rings: The Two Towers',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk5OTA4NTc0NF5BMl5BanBnXkFtZTcwNzI5Mzg3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 668685,
#   u'rating': 8.7,
#   u'tconst': u'tt0073486',
#   u'title': u"One Flew Over the Cuckoo's Nest",
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY2OTE5MzQ3MV5BMl5BanBnXkFtZTgwMTY2NTYxMTE@._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 715698,
#   u'rating': 8.7,
#   u'tconst': u'tt0099685',
#   u'title': u'Goodfellas',
#   u'type': u'feature',
#   u'year': u'1990'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkxNDYxOTA4M15BMl5BanBnXkFtZTgwNTk0NzQxMTE@._V1_.jpg',
#    u'width': 334},
#   u'num_votes': 1196367,
#   u'rating': 8.7,
#   u'tconst': u'tt0133093',
#   u'title': u'The Matrix',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 1900,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc5MDY1MjU5MF5BMl5BanBnXkFtZTgwNDM2OTE4MzE@._V1_.jpg',
#    u'width': 1354},
#   u'num_votes': 225396,
#   u'rating': 8.7,
#   u'tconst': u'tt0047478',
#   u'title': u'Seven Samurai',
#   u'type': u'feature',
#   u'year': u'1954'},
#  {u'can_rate': True,
#   u'image': {u'height': 1270,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BOTIyMDY2NGQtOGJjNi00OTk4LWFhMDgtYmE3M2NiYzM0YTVmXkEyXkFqcGdeQXVyNTU1NTcwOTk@._V1_.jpg',
#    u'width': 831},
#   u'num_votes': 895015,
#   u'rating': 8.7,
#   u'tconst': u'tt0076759',
#   u'title': u'Star Wars',
#   u'type': u'feature',
#   u'year': u'1977'},
#  {u'can_rate': True,
#   u'image': {u'height': 593,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA4ODQ3ODkzNV5BMl5BanBnXkFtZTYwOTc4NDI3._V1_.jpg',
#    u'width': 400},
#   u'num_votes': 524682,
#   u'rating': 8.7,
#   u'tconst': u'tt0317248',
#   u'title': u'City of God',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQwNTU3MTE4NF5BMl5BanBnXkFtZTcwOTgxNDM2Mg@@._V1_.jpg',
#    u'width': 326},
#   u'num_votes': 1004235,
#   u'rating': 8.6,
#   u'tconst': u'tt0114369',
#   u'title': u'Se7en',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ2NzkzMDI4OF5BMl5BanBnXkFtZTcwMDA0NzE1NA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 869467,
#   u'rating': 8.6,
#   u'tconst': u'tt0102926',
#   u'title': u'The Silence of the Lambs',
#   u'type': u'feature',
#   u'year': u'1991'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTMzMzY5NDc4M15BMl5BanBnXkFtZTcwMzc4NjIxNw@@._V1_.jpg',
#    u'width': 1372},
#   u'num_votes': 271085,
#   u'rating': 8.6,
#   u'tconst': u'tt0038650',
#   u'title': u"It's a Wonderful Life",
#   u'type': u'feature',
#   u'year': u'1946'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMzI1MjI5MDQyOV5BMl5BanBnXkFtZTcwNzE4Mjg3NA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 727988,
#   u'rating': 8.6,
#   u'tconst': u'tt0114814',
#   u'title': u'The Usual Suspects',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQwMTM2MjE4Ml5BMl5BanBnXkFtZTgwODQ2NTYxMTE@._V1_.jpg',
#    u'width': 334},
#   u'num_votes': 410934,
#   u'rating': 8.6,
#   u'tconst': u'tt0118799',
#   u'title': u'Life Is Beautiful',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgzMzg4MDkwNF5BMl5BanBnXkFtZTcwODAwNDg3OA@@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 711974,
#   u'rating': 8.6,
#   u'tconst': u'tt0110413',
#   u'title': u'L\xe9on: The Professional',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTEyODQzNDkzNjVeQTJeQWpwZ15BbWU4MDgyODk1NDEx._V1_.jpg',
#    u'width': 352},
#   u'num_votes': 212260,
#   u'rating': 8.6,
#   u'tconst': u'tt0064116',
#   u'title': u'Once Upon a Time in the West',
#   u'type': u'feature',
#   u'year': u'1968'},
#  {u'can_rate': True,
#   u'image': {u'height': 635,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjYxMDcyMzIzNl5BMl5BanBnXkFtZTYwNDg2MDU3._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 408101,
#   u'rating': 8.6,
#   u'tconst': u'tt0245429',
#   u'title': u'Spirited Away',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNjczODkxNTAxN15BMl5BanBnXkFtZTcwMTcwNjUxMw@@._V1_.jpg',
#    u'width': 368},
#   u'num_votes': 864652,
#   u'rating': 8.6,
#   u'tconst': u'tt0120815',
#   u'title': u'Saving Private Ryan',
#   u'type': u'feature',
#   u'year': u'1998'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjMzNDUwNTIyMF5BMl5BanBnXkFtZTcwNjMwNDg3OA@@._V1_.jpg',
#    u'width': 391},
#   u'num_votes': 769798,
#   u'rating': 8.6,
#   u'tconst': u'tt0120586',
#   u'title': u'American History X',
#   u'type': u'feature',
#   u'year': u'1998'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjQwNDYyNTk2N15BMl5BanBnXkFtZTgwMjQ0OTMyMjE@._V1_.jpg',
#    u'width': 334},
#   u'num_votes': 381676,
#   u'rating': 8.6,
#   u'tconst': u'tt0034583',
#   u'title': u'Casablanca',
#   u'type': u'feature',
#   u'year': u'1942'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIxNTU4MzY4MF5BMl5BanBnXkFtZTgwMzM4ODI3MjE@._V1_.jpg',
#    u'width': 1311},
#   u'num_votes': 899054,
#   u'rating': 8.6,
#   u'tconst': u'tt0816692',
#   u'title': u'Interstellar',
#   u'type': u'feature',
#   u'year': u'2014'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgzMzM3NDY0NF5BMl5BanBnXkFtZTgwNDgwNDgwNzE@._V1_.jpg',
#    u'width': 978},
#   u'num_votes': 414338,
#   u'rating': 8.5,
#   u'tconst': u'tt0054215',
#   u'title': u'Psycho',
#   u'type': u'feature',
#   u'year': u'1960'},
#  {u'can_rate': True,
#   u'image': {u'height': 476,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA3NDQ5MDMzOV5BMl5BanBnXkFtZTgwODY2MjcyMjE@._V1_.jpg',
#    u'width': 320},
#   u'num_votes': 105767,
#   u'rating': 8.6,
#   u'tconst': u'tt0021749',
#   u'title': u'City Lights',
#   u'type': u'feature',
#   u'year': u'1931'},
#  {u'can_rate': True,
#   u'image': {u'height': 1536,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA0ODEzMTc1Nl5BMl5BanBnXkFtZTcwODM2MjAxNA@@._V1_.jpg',
#    u'width': 1021},
#   u'num_votes': 650014,
#   u'rating': 8.5,
#   u'tconst': u'tt0082971',
#   u'title': u'Raiders of the Lost Ark',
#   u'type': u'feature',
#   u'year': u'1981'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTYxNDA3MDQwNl5BMl5BanBnXkFtZTcwNTU4Mzc1Nw@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 490678,
#   u'rating': 8.6,
#   u'tconst': u'tt1675434',
#   u'title': u'The Intouchables',
#   u'type': u'feature',
#   u'year': u'2011'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjAxNDM0NTcyOV5BMl5BanBnXkFtZTgwODE1NjM0MTE@._V1_.jpg',
#    u'width': 332},
#   u'num_votes': 310513,
#   u'rating': 8.5,
#   u'tconst': u'tt0047396',
#   u'title': u'Rear Window',
#   u'type': u'feature',
#   u'year': u'1954'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjAyMTkxNjI5OF5BMl5BanBnXkFtZTYwMjI2MjA5._V1_.jpg',
#    u'width': 347},
#   u'num_votes': 139742,
#   u'rating': 8.6,
#   u'tconst': u'tt0027977',
#   u'title': u'Modern Times',
#   u'type': u'feature',
#   u'year': u'1936'},
#  {u'can_rate': True,
#   u'image': {u'height': 740,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_.jpg',
#    u'width': 500},
#   u'num_votes': 766376,
#   u'rating': 8.5,
#   u'tconst': u'tt0120689',
#   u'title': u'The Green Mile',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 473,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTI4MDAwMDY3N15BMl5BanBnXkFtZTcwODIwMzMzMQ@@._V1._CR46,1,342,473_.jpg',
#    u'width': 342},
#   u'num_votes': 732369,
#   u'rating': 8.5,
#   u'tconst': u'tt0103064',
#   u'title': u'Terminator 2: Judgment Day',
#   u'type': u'feature',
#   u'year': u'1991'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc4OTkyOTA3OF5BMl5BanBnXkFtZTYwMDIxNjk5._V1_.jpg',
#    u'width': 315},
#   u'num_votes': 488202,
#   u'rating': 8.5,
#   u'tconst': u'tt0253474',
#   u'title': u'The Pianist',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 665,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTI1MTY2OTIxNV5BMl5BanBnXkFtZTYwNjQ4NjY3._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 857502,
#   u'rating': 8.5,
#   u'tconst': u'tt0407887',
#   u'title': u'The Departed',
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 1893,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1218},
#   u'num_votes': 717018,
#   u'rating': 8.5,
#   u'tconst': u'tt0088763',
#   u'title': u'Back to the Future',
#   u'type': u'feature',
#   u'year': u'1985'},
#  {u'can_rate': True,
#   u'image': {u'height': 755,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU4OTQ3MDUyMV5BMl5BanBnXkFtZTgwOTA2MjU0MjE@._V1_.jpg',
#    u'width': 509},
#   u'num_votes': 381967,
#   u'rating': 8.5,
#   u'tconst': u'tt2582802',
#   u'title': u'Whiplash',
#   u'type': u'feature',
#   u'year': u'2014'},
#  {u'can_rate': True,
#   u'image': {u'height': 1377,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgwMzQzNTQ1Ml5BMl5BanBnXkFtZTgwMDY2NTYxMTE@._V1_.jpg',
#    u'width': 930},
#   u'num_votes': 965428,
#   u'rating': 8.5,
#   u'tconst': u'tt0172495',
#   u'title': u'Gladiator',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc4MjUxNDAwN15BMl5BanBnXkFtZTcwMDMwNDg3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 831345,
#   u'rating': 8.5,
#   u'tconst': u'tt0209144',
#   u'title': u'Memento',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTcyMzQ5NDM4OV5BMl5BanBnXkFtZTcwODUwNDg3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 443806,
#   u'rating': 8.5,
#   u'tconst': u'tt0078788',
#   u'title': u'Apocalypse Now',
#   u'type': u'feature',
#   u'year': u'1979'},
#  {u'can_rate': True,
#   u'image': {u'height': 667,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA4NDI0MTIxNF5BMl5BanBnXkFtZTYwNTM0MzY2._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 826750,
#   u'rating': 8.5,
#   u'tconst': u'tt0482571',
#   u'title': u'The Prestige',
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 1651,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjEyMzgwNTUzMl5BMl5BanBnXkFtZTcwNTMxMzM3Ng@@._V1_.jpg',
#    u'width': 1275},
#   u'num_votes': 629985,
#   u'rating': 8.5,
#   u'tconst': u'tt0110357',
#   u'title': u'The Lion King',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 1102,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU2ODM2NTkxNF5BMl5BanBnXkFtZTcwOTMwMzU3Mg@@._V1_.jpg',
#    u'width': 740},
#   u'num_votes': 337092,
#   u'rating': 8.5,
#   u'tconst': u'tt0057012',
#   u'title': u'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   u'type': u'feature',
#   u'year': u'1964'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc3NDYzODAwNV5BMl5BanBnXkFtZTgwODg1MTczMTE@._V1_.jpg',
#    u'width': 332},
#   u'num_votes': 137064,
#   u'rating': 8.5,
#   u'tconst': u'tt0043014',
#   u'title': u'Sunset Blvd.',
#   u'type': u'feature',
#   u'year': u'1950'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU1ODQ4NjQyOV5BMl5BanBnXkFtZTgwOTQ3NDU2MTE@._V1_.jpg',
#    u'width': 1365},
#   u'num_votes': 553582,
#   u'rating': 8.5,
#   u'tconst': u'tt0078748',
#   u'title': u'Alien',
#   u'type': u'feature',
#   u'year': u'1979'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ5NDAwMDgzOV5BMl5BanBnXkFtZTgwNDI2MjA0MjE@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 134513,
#   u'rating': 8.5,
#   u'tconst': u'tt0032553',
#   u'title': u'The Great Dictator',
#   u'type': u'feature',
#   u'year': u'1940'},
#  {u'can_rate': True,
#   u'image': {u'height': 675,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDUzNjYwNDYyNl5BMl5BanBnXkFtZTcwNjU3ODQ0MQ@@._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 255071,
#   u'rating': 8.5,
#   u'tconst': u'tt0405094',
#   u'title': u'The Lives of Others',
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 499,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIzMTgzOTEwOF5BMl5BanBnXkFtZTgwNTUxNjcxMTE@._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 149189,
#   u'rating': 8.5,
#   u'tconst': u'tt0095765',
#   u'title': u'Cinema Paradiso',
#   u'type': u'feature',
#   u'year': u'1988'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIyNTQ5NjQ1OV5BMl5BanBnXkFtZTcwODg1MDU4OA@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 933966,
#   u'rating': 8.5,
#   u'tconst': u'tt1853728',
#   u'title': u'Django Unchained',
#   u'type': u'feature',
#   u'year': u'2012'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BODMxMjE3NTA4Ml5BMl5BanBnXkFtZTgwNDc0NTIxMDE@._V1_.jpg',
#    u'width': 1024},
#   u'num_votes': 598207,
#   u'rating': 8.4,
#   u'tconst': u'tt0081505',
#   u'title': u'The Shining',
#   u'type': u'feature',
#   u'year': u'1980'},
#  {u'can_rate': True,
#   u'image': {u'height': 497,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTUxNTcxMjI5NV5BMl5BanBnXkFtZTcwNTcyNjI3Mw@@._V1._CR17,1,331,497_.jpg',
#    u'width': 331},
#   u'num_votes': 118624,
#   u'rating': 8.5,
#   u'tconst': u'tt0050825',
#   u'title': u'Paths of Glory',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgyMzUwMTMxMl5BMl5BanBnXkFtZTgwODYyMDk2MjE@._V1_.jpg',
#    u'width': 342},
#   u'num_votes': 134611,
#   u'rating': 8.5,
#   u'tconst': u'tt0095327',
#   u'title': u'Grave of the Fireflies',
#   u'type': u'feature',
#   u'year': u'1988'},
#  {u'can_rate': True,
#   u'image': {u'height': 755,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTczOTA3MzY2N15BMl5BanBnXkFtZTcwOTYwNjE2MQ@@._V1_.jpg',
#    u'width': 510},
#   u'num_votes': 702788,
#   u'rating': 8.4,
#   u'tconst': u'tt0910970',
#   u'title': u'WALL\xb7E',
#   u'type': u'feature',
#   u'year': u'2008'},
#  {u'can_rate': True,
#   u'image': {u'height': 720,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_.jpg',
#    u'width': 486},
#   u'num_votes': 1123277,
#   u'rating': 8.5,
#   u'tconst': u'tt1345836',
#   u'title': u'The Dark Knight Rises',
#   u'type': u'feature',
#   u'year': u'2012'},
#  {u'can_rate': True,
#   u'image': {u'height': 1377,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjM4NTI5NzYyNV5BMl5BanBnXkFtZTgwNTkxNTYxMTE@._V1_.jpg',
#    u'width': 930},
#   u'num_votes': 809239,
#   u'rating': 8.4,
#   u'tconst': u'tt0169547',
#   u'title': u'American Beauty',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTYzNzU5MzQ4OV5BMl5BanBnXkFtZTcwMDcxNDg3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 480824,
#   u'rating': 8.4,
#   u'tconst': u'tt0090605',
#   u'title': u'Aliens',
#   u'type': u'feature',
#   u'year': u'1986'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjgzNTUwODQzN15BMl5BanBnXkFtZTcwMTc4ODE3OQ@@._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 216854,
#   u'rating': 8.4,
#   u'tconst': u'tt0119698',
#   u'title': u'Princess Mononoke',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 666,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTI3NTQyMzU5M15BMl5BanBnXkFtZTcwMTM2MjgyMQ@@._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 348933,
#   u'rating': 8.4,
#   u'tconst': u'tt0364569',
#   u'title': u'Oldboy',
#   u'type': u'feature',
#   u'year': u'2003'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ2Mjc1MDQwMl5BMl5BanBnXkFtZTcwNzUyOTUyMg@@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 293470,
#   u'rating': 8.4,
#   u'tconst': u'tt0033467',
#   u'title': u'Citizen Kane',
#   u'type': u'feature',
#   u'year': u'1941'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjQwMTQ0MzgwNl5BMl5BanBnXkFtZTgwNjc4ODE4MzE@._V1_.jpg',
#    u'width': 1309},
#   u'num_votes': 217068,
#   u'rating': 8.4,
#   u'tconst': u'tt0053125',
#   u'title': u'North by Northwest',
#   u'type': u'feature',
#   u'year': u'1959'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDMwMDcyODkzOV5BMl5BanBnXkFtZTcwNTQ1Njg3OA@@._V1_.jpg',
#    u'width': 353},
#   u'num_votes': 217095,
#   u'rating': 8.4,
#   u'tconst': u'tt0087843',
#   u'title': u'Once Upon a Time in America',
#   u'type': u'feature',
#   u'year': u'1984'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjE5Mzk5OTQ0Nl5BMl5BanBnXkFtZTYwNzUwMTQ5._V1_.jpg',
#    u'width': 297},
#   u'num_votes': 165651,
#   u'rating': 8.4,
#   u'tconst': u'tt0082096',
#   u'title': u'Das Boot',
#   u'type': u'feature',
#   u'year': u'1981'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNzY0NzQyNzQzOF5BMl5BanBnXkFtZTcwMTgwNTk4OQ@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 243941,
#   u'rating': 8.4,
#   u'tconst': u'tt0052357',
#   u'title': u'Vertigo',
#   u'type': u'feature',
#   u'year': u'1958'},
#  {u'can_rate': True,
#   u'image': {u'height': 1861,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ0MzI1NjYwOF5BMl5BanBnXkFtZTgwODU3NDU2MTE@._V1._CR93,97,1209,1861_.jpg',
#    u'width': 1209},
#   u'num_votes': 667816,
#   u'rating': 8.4,
#   u'tconst': u'tt0086190',
#   u'title': u'Star Wars: Episode VI - Return of the Jedi',
#   u'type': u'feature',
#   u'year': u'1983'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc0MjgyNTUyNF5BMl5BanBnXkFtZTcwNDQzMDg0Nw@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 61447,
#   u'rating': 8.4,
#   u'tconst': u'tt0051201',
#   u'title': u'Witness for the Prosecution',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQyNjA5NzU5MV5BMl5BanBnXkFtZTgwMDk1MTA5MTE@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 97400,
#   u'rating': 8.4,
#   u'tconst': u'tt0022100',
#   u'title': u'M',
#   u'type': u'feature',
#   u'year': u'1931'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQxMTAwMDQ3Nl5BMl5BanBnXkFtZTcwODMwNTgzMQ@@._V1_.jpg',
#    u'width': 353},
#   u'num_votes': 652083,
#   u'rating': 8.4,
#   u'tconst': u'tt0105236',
#   u'title': u'Reservoir Dogs',
#   u'type': u'feature',
#   u'year': u'1992'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTYzNjkxMTczOF5BMl5BanBnXkFtZTgwODg5NDc2MjE@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 525173,
#   u'rating': 8.4,
#   u'tconst': u'tt0211915',
#   u'title': u'Am\xe9lie',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNjA4ODYxMDU3Nl5BMl5BanBnXkFtZTcwMzkzMTk3OA@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 724729,
#   u'rating': 8.4,
#   u'tconst': u'tt0112573',
#   u'title': u'Braveheart',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 433,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkzODMzODYwOF5BMl5BanBnXkFtZTcwODM2NjA2NQ@@._V1_.jpg',
#    u'width': 300},
#   u'num_votes': 563577,
#   u'rating': 8.4,
#   u'tconst': u'tt0180093',
#   u'title': u'Requiem for a Dream',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 1300,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY3MjM1Mzc4N15BMl5BanBnXkFtZTgwODM0NzAxMDE@._V1_.jpg',
#    u'width': 878},
#   u'num_votes': 547637,
#   u'rating': 8.4,
#   u'tconst': u'tt0066921',
#   u'title': u'A Clockwork Orange',
#   u'type': u'feature',
#   u'year': u'1971'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ1Nzg3MDQwN15BMl5BanBnXkFtZTcwNDE2NDU2MQ@@._V1_.jpg',
#    u'width': 368},
#   u'num_votes': 497021,
#   u'rating': 8.3,
#   u'tconst': u'tt0075314',
#   u'title': u'Taxi Driver',
#   u'type': u'feature',
#   u'year': u'1976'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQzOTE4MTIzMV5BMl5BanBnXkFtZTgwODc1NDQ5MDE@._V1_.jpg',
#    u'width': 329},
#   u'num_votes': 95899,
#   u'rating': 8.4,
#   u'tconst': u'tt0036775',
#   u'title': u'Double Indemnity',
#   u'type': u'feature',
#   u'year': u'1944'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgxOTY4Mjc0MF5BMl5BanBnXkFtZTcwNTA4MDQyMw@@._V1_.jpg',
#    u'width': 1448},
#   u'num_votes': 532816,
#   u'rating': 8.3,
#   u'tconst': u'tt0435761',
#   u'title': u'Toy Story 3',
#   u'type': u'feature',
#   u'year': u'2010'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMzAwMjM4NzA2OV5BMl5BanBnXkFtZTcwMDI0NzAwMQ@@._V1_.jpg',
#    u'width': 324},
#   u'num_votes': 189381,
#   u'rating': 8.4,
#   u'tconst': u'tt0056172',
#   u'title': u'Lawrence of Arabia',
#   u'type': u'feature',
#   u'year': u'1962'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA4MzI1NDY2Nl5BMl5BanBnXkFtZTcwMTcyODc5Mw@@._V1_.jpg',
#    u'width': 328},
#   u'num_votes': 210884,
#   u'rating': 8.4,
#   u'tconst': u'tt0056592',
#   u'title': u'To Kill a Mockingbird',
#   u'type': u'feature',
#   u'year': u'1962'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY4NzcwODg3Nl5BMl5BanBnXkFtZTcwNTEwOTMyMw@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 654216,
#   u'rating': 8.3,
#   u'tconst': u'tt0338013',
#   u'title': u'Eternal Sunshine of the Spotless Mind',
#   u'type': u'feature',
#   u'year': u'2004'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA4NzY4ODk4Nl5BMl5BanBnXkFtZTgwOTcxNTYxMTE@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 475809,
#   u'rating': 8.3,
#   u'tconst': u'tt0093058',
#   u'title': u'Full Metal Jacket',
#   u'type': u'feature',
#   u'year': u'1987'},
#  {u'can_rate': True,
#   u'image': {u'height': 704,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTg5NDkwMTk5N15BMl5BanBnXkFtZTYwODg3MDk2._V1_.jpg',
#    u'width': 475},
#   u'num_votes': 266121,
#   u'rating': 8.3,
#   u'tconst': u'tt0086879',
#   u'title': u'Amadeus',
#   u'type': u'feature',
#   u'year': u'1984'},
#  {u'can_rate': True,
#   u'image': {u'height': 1388,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY5MjM1OTAyOV5BMl5BanBnXkFtZTgwMDkwODg4MDE@._V1._CR52,57,915,1388_.jpg',
#    u'width': 915},
#   u'num_votes': 172472,
#   u'rating': 8.3,
#   u'tconst': u'tt0070735',
#   u'title': u'The Sting',
#   u'type': u'feature',
#   u'year': u'1973'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDYyMDgxNDQ5Nl5BMl5BanBnXkFtZTcwMjc1ODg3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 419124,
#   u'rating': 8.3,
#   u'tconst': u'tt0062622',
#   u'title': u'2001: A Space Odyssey',
#   u'type': u'feature',
#   u'year': u'1968'},
#  {u'can_rate': True,
#   u'image': {u'height': 3300,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIzMzAyMzg1Nl5BMl5BanBnXkFtZTgwMzMyNzk0MTE@._V1_.jpg',
#    u'width': 2285},
#   u'num_votes': 92492,
#   u'rating': 8.3,
#   u'tconst': u'tt0040522',
#   u'title': u'Bicycle Thieves',
#   u'type': u'feature',
#   u'year': u'1948'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTUxMTIyNTI4Nl5BMl5BanBnXkFtZTcwNTk1ODQyMg@@._V1_.jpg',
#    u'width': 324},
#   u'num_votes': 147400,
#   u'rating': 8.3,
#   u'tconst': u'tt0045152',
#   u'title': u"Singin' in the Rain",
#   u'type': u'feature',
#   u'year': u'1952'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk5NzE0MDQyNl5BMl5BanBnXkFtZTcwNzk4Mjk3OA@@._V1_.jpg',
#    u'width': 344},
#   u'num_votes': 591621,
#   u'rating': 8.3,
#   u'tconst': u'tt0208092',
#   u'title': u'Snatch.',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgwMjI4MzU5N15BMl5BanBnXkFtZTcwMTMyNTk3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 609637,
#   u'rating': 8.3,
#   u'tconst': u'tt0114709',
#   u'title': u'Toy Story',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkzODczMTgwM15BMl5BanBnXkFtZTYwNTAwODI5._V1_.jpg',
#    u'width': 271},
#   u'num_votes': 376294,
#   u'rating': 8.3,
#   u'tconst': u'tt0071853',
#   u'title': u'Monty Python and the Holy Grail',
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 1441,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIzMDI4MTUzOV5BMl5BanBnXkFtZTcwNDY3NjA3Mg@@._V1_.jpg',
#    u'width': 974},
#   u'num_votes': 866609,
#   u'rating': 8.3,
#   u'tconst': u'tt0361748',
#   u'title': u'Inglourious Basterds',
#   u'type': u'feature',
#   u'year': u'2009'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkzNTgxMDU1OF5BMl5BanBnXkFtZTgwOTQ3MjI2MzE@._V1_.jpg',
#    u'width': 358},
#   u'num_votes': 65406,
#   u'rating': 8.4,
#   u'tconst': u'tt0012349',
#   u'title': u'The Kid',
#   u'type': u'feature',
#   u'year': u'1921'},
#  {u'can_rate': True,
#   u'image': {u'height': 488,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjMzOTc2MDI3N15BMl5BanBnXkFtZTgwNTE4Njc3NjE@._V1_.jpg',
#    u'width': 329},
#   u'num_votes': 408201,
#   u'rating': 8.3,
#   u'tconst': u'tt0119488',
#   u'title': u'L.A. Confidential',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQzMjIzOTEzMF5BMl5BanBnXkFtZTcwMTUzNTk3NA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 153861,
#   u'rating': 8.3,
#   u'tconst': u'tt0059578',
#   u'title': u'For a Few Dollars More',
#   u'type': u'feature',
#   u'year': u'1965'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTM1OTc4MzgzNl5BMl5BanBnXkFtZTcwNTE2NjgyMw@@._V1_.jpg',
#    u'width': 1234},
#   u'num_votes': 107291,
#   u'rating': 8.3,
#   u'tconst': u'tt0053604',
#   u'title': u'The Apartment',
#   u'type': u'feature',
#   u'year': u'1960'},
#  {u'can_rate': True,
#   u'image': {u'height': 683,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjEzMzA4NDE2OF5BMl5BanBnXkFtZTcwNTc5MDI2NQ@@._V1._CR0,0,503,683_.jpg',
#    u'width': 503},
#   u'num_votes': 100655,
#   u'rating': 8.3,
#   u'tconst': u'tt0042876',
#   u'title': u'Rashomon',
#   u'type': u'feature',
#   u'year': u'1950'},
#  {u'can_rate': True,
#   u'image': {u'height': 1535,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQxMTUyODg2OF5BMl5BanBnXkFtZTcwNDM2MjAxNA@@._V1_.jpg',
#    u'width': 1014},
#   u'num_votes': 506362,
#   u'rating': 8.3,
#   u'tconst': u'tt0097576',
#   u'title': u'Indiana Jones and the Last Crusade',
#   u'type': u'feature',
#   u'year': u'1989'},
#  {u'can_rate': True,
#   u'image': {u'height': 1000,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjAzOTM4MzEwNl5BMl5BanBnXkFtZTgwMzU1OTc1MDE@._V1_.jpg',
#    u'width': 675},
#   u'num_votes': 528176,
#   u'rating': 8.3,
#   u'tconst': u'tt0086250',
#   u'title': u'Scarface',
#   u'type': u'feature',
#   u'year': u'1983'},
#  {u'can_rate': True,
#   u'image': {u'height': 1323,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTYzMzU4NDUwOF5BMl5BanBnXkFtZTcwMTM5MjA5Ng@@._V1_.jpg',
#    u'width': 893},
#   u'num_votes': 148933,
#   u'rating': 8.4,
#   u'tconst': u'tt1832382',
#   u'title': u'A Separation',
#   u'type': u'feature',
#   u'year': u'2011'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDAzNTkyODg1MF5BMl5BanBnXkFtZTgwMDA3NDkwMDE@._V1_.jpg',
#    u'width': 323},
#   u'num_votes': 109841,
#   u'rating': 8.3,
#   u'tconst': u'tt0017136',
#   u'title': u'Metropolis',
#   u'type': u'feature',
#   u'year': u'1927'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY2MTAzODI5NV5BMl5BanBnXkFtZTgwMjM4NzQ0MjE@._V1_.jpg',
#    u'width': 1000},
#   u'num_votes': 81573,
#   u'rating': 8.3,
#   u'tconst': u'tt0042192',
#   u'title': u'All About Eve',
#   u'type': u'feature',
#   u'year': u'1950'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjAwNTQ3ODUyMl5BMl5BanBnXkFtZTgwNDg5ODQyNjE@._V1_.jpg',
#    u'width': 345},
#   u'num_votes': 72651,
#   u'rating': 8.3,
#   u'tconst': u'tt0055630',
#   u'title': u'Yojimbo',
#   u'type': u'feature',
#   u'year': u'1961'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ4MzUzOTYwOV5BMl5BanBnXkFtZTgwNDA4MzgyMjE@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 77834,
#   u'rating': 8.3,
#   u'tconst': u'tt0040897',
#   u'title': u'The Treasure of the Sierra Madre',
#   u'type': u'feature',
#   u'year': u'1948'},
#  {u'can_rate': True,
#   u'image': {u'height': 721,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNTM3OTc0MzM2OV5BMl5BanBnXkFtZTYwNzUwMTI3._V1_.jpg',
#    u'width': 485},
#   u'num_votes': 962506,
#   u'rating': 8.3,
#   u'tconst': u'tt0372784',
#   u'title': u'Batman Begins',
#   u'type': u'feature',
#   u'year': u'2005'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTg0OTk4MDEwMV5BMl5BanBnXkFtZTYwNzMwNzI5._V1_.jpg',
#    u'width': 331},
#   u'num_votes': 25517,
#   u'rating': 8.5,
#   u'tconst': u'tt0118849',
#   u'title': u'Children of Heaven',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 5906,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTg2NDg3ODg4NF5BMl5BanBnXkFtZTcwNzk3NTc3Nw@@._V1_.jpg',
#    u'width': 4134},
#   u'num_votes': 165046,
#   u'rating': 8.3,
#   u'tconst': u'tt2106476',
#   u'title': u'The Hunt',
#   u'type': u'feature',
#   u'year': u'2012'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTMyOTg0ODQ1OF5BMl5BanBnXkFtZTcwNjc0NTMwNQ@@._V1_.jpg',
#    u'width': 1445},
#   u'num_votes': 200669,
#   u'rating': 8.4,
#   u'tconst': u'tt1187043',
#   u'title': u'3 Idiots',
#   u'type': u'feature',
#   u'year': u'2009'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNzYzMDkzNDQ0N15BMl5BanBnXkFtZTcwNzQ0NDQyNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 172247,
#   u'rating': 8.3,
#   u'tconst': u'tt0053291',
#   u'title': u'Some Like It Hot',
#   u'type': u'feature',
#   u'year': u'1959'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk0NjY0Mzg5MF5BMl5BanBnXkFtZTcwNzM1OTM2MQ@@._V1_.jpg',
#    u'width': 341},
#   u'num_votes': 592796,
#   u'rating': 8.3,
#   u'tconst': u'tt0119217',
#   u'title': u'Good Will Hunting',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkzNTc0NDc4OF5BMl5BanBnXkFtZTcwNTY1ODg3OA@@._V1_.jpg',
#    u'width': 353},
#   u'num_votes': 272947,
#   u'rating': 8.3,
#   u'tconst': u'tt0105695',
#   u'title': u'Unforgiven',
#   u'type': u'feature',
#   u'year': u'1992'},
#  {u'can_rate': True,
#   u'image': {u'height': 1060,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk3NDE2NzI4NF5BMl5BanBnXkFtZTgwNzE1MzEyMTE@._V1_.jpg',
#    u'width': 704},
#   u'num_votes': 649701,
#   u'rating': 8.3,
#   u'tconst': u'tt1049413',
#   u'title': u'Up',
#   u'type': u'feature',
#   u'year': u'2009'},
#  {u'can_rate': True,
#   u'image': {u'height': 1185,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjMwNzMzMTQ0Ml5BMl5BanBnXkFtZTgwNjExMzUwNjE@._V1_.jpg',
#    u'width': 800},
#   u'num_votes': 111819,
#   u'rating': 8.3,
#   u'tconst': u'tt0041959',
#   u'title': u'The Third Man',
#   u'type': u'feature',
#   u'year': u'1949'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIxOTg3OTc5MF5BMl5BanBnXkFtZTcwNzkwNjMwNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 231572,
#   u'rating': 8.3,
#   u'tconst': u'tt0081398',
#   u'title': u'Raging Bull',
#   u'type': u'feature',
#   u'year': u'1980'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTM1OTI1MjE2Nl5BMl5BanBnXkFtZTcwMTEwMzc4NA@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 244738,
#   u'rating': 8.3,
#   u'tconst': u'tt0363163',
#   u'title': u'Downfall',
#   u'type': u'feature',
#   u'year': u'2004'},
#  {u'can_rate': True,
#   u'image': {u'height': 1609,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BOTgxMDQwMDk0OF5BMl5BanBnXkFtZTgwNjU5OTg2NDE@._V1_.jpg',
#    u'width': 1086},
#   u'num_votes': 320750,
#   u'rating': 8.3,
#   u'tconst': u'tt2096673',
#   u'title': u'Inside Out',
#   u'type': u'feature',
#   u'year': u'2015'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY4ODM0OTc2M15BMl5BanBnXkFtZTcwNzE0MTk3OA@@._V1_.jpg',
#    u'width': 335},
#   u'num_votes': 583210,
#   u'rating': 8.2,
#   u'tconst': u'tt0095016',
#   u'title': u'Die Hard',
#   u'type': u'feature',
#   u'year': u'1988'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjI2MTQwNDI3Nl5BMl5BanBnXkFtZTcwNDk4MTkzNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 162844,
#   u'rating': 8.3,
#   u'tconst': u'tt0057115',
#   u'title': u'The Great Escape',
#   u'type': u'feature',
#   u'year': u'1963'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTUyMTQ1NjA2OV5BMl5BanBnXkFtZTcwODQ1Njg3OA@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 212661,
#   u'rating': 8.2,
#   u'tconst': u'tt0071315',
#   u'title': u'Chinatown',
#   u'type': u'feature',
#   u'year': u'1974'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTM1NDc4ODkxNV5BMl5BanBnXkFtZTcwNTI4ODE3MQ@@._V1_.jpg',
#    u'width': 345},
#   u'num_votes': 424996,
#   u'rating': 8.2,
#   u'tconst': u'tt0113277',
#   u'title': u'Heat',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 1440,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjE4NzgzNzEwMl5BMl5BanBnXkFtZTgwMTMzMDE0NjE@._V1_.jpg',
#    u'width': 972},
#   u'num_votes': 138266,
#   u'rating': 8.3,
#   u'tconst': u'tt3170832',
#   u'title': u'Room',
#   u'type': u'feature',
#   u'year': u'2015'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjQ0MTgyNjAxMV5BMl5BanBnXkFtZTgwNjUzMDkyODE@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 214273,
#   u'rating': 8.3,
#   u'tconst': u'tt3498820',
#   u'title': u'Captain America: Civil War',
#   u'type': u'feature',
#   u'year': u'2016'},
#  {u'can_rate': True,
#   u'image': {u'height': 1014,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU3ODg2NjQ5NF5BMl5BanBnXkFtZTcwMDEwODgzMQ@@._V1_.jpg',
#    u'width': 689},
#   u'num_votes': 459776,
#   u'rating': 8.2,
#   u'tconst': u'tt0457430',
#   u'title': u"Pan's Labyrinth",
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTcwMTU3MjI1OV5BMl5BanBnXkFtZTgwNjE2OTI3MjE@._V1_.jpg',
#    u'width': 357},
#   u'num_votes': 98960,
#   u'rating': 8.3,
#   u'tconst': u'tt0047296',
#   u'title': u'On the Waterfront',
#   u'type': u'feature',
#   u'year': u'1954'},
#  {u'can_rate': True,
#   u'image': {u'height': 690,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjE3NzY5ODQwMV5BMl5BanBnXkFtZTcwNzY1NzcxNw@@._V1_.jpg',
#    u'width': 500},
#   u'num_votes': 167486,
#   u'rating': 8.3,
#   u'tconst': u'tt0096283',
#   u'title': u'My Neighbor Totoro',
#   u'type': u'feature',
#   u'year': u'1988'},
#  {u'can_rate': True,
#   u'image': {u'height': 938,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNTEyNjg0MDM4OF5BMl5BanBnXkFtZTgwODI0NjUxODE@._V1_.jpg',
#    u'width': 654},
#   u'num_votes': 76341,
#   u'rating': 8.3,
#   u'tconst': u'tt0089881',
#   u'title': u'Ran',
#   u'type': u'feature',
#   u'year': u'1985'},
#  {u'can_rate': True,
#   u'image': {u'height': 446,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTcyMDU0MTQzNV5BMl5BanBnXkFtZTcwOTk2NDQyMQ@@._V1._CR12,28,314,446_.jpg',
#    u'width': 314},
#   u'num_votes': 41290,
#   u'rating': 8.3,
#   u'tconst': u'tt0044741',
#   u'title': u'Ikiru',
#   u'type': u'feature',
#   u'year': u'1952'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjAwMzU5ODkwNF5BMl5BanBnXkFtZTcwNTg4Mjk3OA@@._V1_.jpg',
#    u'width': 330},
#   u'num_votes': 76106,
#   u'rating': 8.3,
#   u'tconst': u'tt0031679',
#   u'title': u'Mr. Smith Goes to Washington',
#   u'type': u'feature',
#   u'year': u'1939'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc2NzA0NTEwNF5BMl5BanBnXkFtZTcwMzA0MTk3OA@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 146589,
#   u'rating': 8.2,
#   u'tconst': u'tt0050212',
#   u'title': u'The Bridge on the River Kwai',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMzYzMDQyNzA4NV5BMl5BanBnXkFtZTYwNDU5NDU5._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 66408,
#   u'rating': 8.3,
#   u'tconst': u'tt0015864',
#   u'title': u'The Gold Rush',
#   u'type': u'feature',
#   u'year': u'1925'},
#  {u'can_rate': True,
#   u'image': {u'height': 3240,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BOTAzODEzNDAzMl5BMl5BanBnXkFtZTgwMDU1MTgzNzE@._V1_.jpg',
#    u'width': 2194},
#   u'num_votes': 533780,
#   u'rating': 8.3,
#   u'tconst': u'tt2488496',
#   u'title': u'Star Wars: Episode VII - The Force Awakens',
#   u'type': u'feature',
#   u'year': u'2015'},
#  {u'can_rate': True,
#   u'image': {u'height': 1315,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgwNTI3OTczOV5BMl5BanBnXkFtZTcwMTM3MTUyMw@@._V1_.jpg',
#    u'width': 889},
#   u'num_votes': 128473,
#   u'rating': 8.2,
#   u'tconst': u'tt1305806',
#   u'title': u'The Secret in Their Eyes',
#   u'type': u'feature',
#   u'year': u'2009'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTUzODUyNjkxM15BMl5BanBnXkFtZTcwODA5MTM1Mg@@._V1_.jpg',
#    u'width': 354},
#   u'num_votes': 109842,
#   u'rating': 8.2,
#   u'tconst': u'tt0050976',
#   u'title': u'The Seventh Seal',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTA4MDQxNTk2NDheQTJeQWpwZ15BbWU3MDE2NjIyODk@._V1_.jpg',
#    u'width': 332},
#   u'num_votes': 454805,
#   u'rating': 8.2,
#   u'tconst': u'tt0083658',
#   u'title': u'Blade Runner',
#   u'type': u'feature',
#   u'year': u'1982'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIzNzg4MzcxNV5BMl5BanBnXkFtZTgwMTgzNTE0MTE@._V1_.jpg',
#    u'width': 324},
#   u'num_votes': 28437,
#   u'rating': 8.3,
#   u'tconst': u'tt0018455',
#   u'title': u'Sunrise',
#   u'type': u'feature',
#   u'year': u'1927'},
#  {u'can_rate': True,
#   u'image': {u'height': 376,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU4MTM1MjUxMF5BMl5BanBnXkFtZTYwOTEzODY4._V1_.jpg',
#    u'width': 270},
#   u'num_votes': 408909,
#   u'rating': 8.2,
#   u'tconst': u'tt0120735',
#   u'title': u'Lock, Stock and Two Smoking Barrels',
#   u'type': u'feature',
#   u'year': u'1998'},
#  {u'can_rate': True,
#   u'image': {u'height': 438,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgzMDk3MzMwMF5BMl5BanBnXkFtZTcwODM1NTAwMQ@@._V1._CR17,36,290,438_.jpg',
#    u'width': 290},
#   u'num_votes': 25160,
#   u'rating': 8.3,
#   u'tconst': u'tt0046438',
#   u'title': u'Tokyo Story',
#   u'type': u'feature',
#   u'year': u'1953'},
#  {u'can_rate': True,
#   u'image': {u'height': 2340,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY1OTg0MjE3MV5BMl5BanBnXkFtZTcwNTUxMTkyMQ@@._V1_.jpg',
#    u'width': 1578},
#   u'num_votes': 209106,
#   u'rating': 8.2,
#   u'tconst': u'tt0347149',
#   u'title': u"Howl's Moving Castle",
#   u'type': u'feature',
#   u'year': u'2004'},
#  {u'can_rate': True,
#   u'image': {u'height': 352,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTMzMjkwMTk4Nl5BMl5BanBnXkFtZTYwNjYxMjk5._V1_.jpg',
#    u'width': 230},
#   u'num_votes': 327556,
#   u'rating': 8.2,
#   u'tconst': u'tt0112641',
#   u'title': u'Casino',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 410,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BODQxMzMyNTY5Nl5BMl5BanBnXkFtZTcwMDMyNTk3OA@@._V1_.jpg',
#    u'width': 262},
#   u'num_votes': 52470,
#   u'rating': 8.2,
#   u'tconst': u'tt0017925',
#   u'title': u'The General',
#   u'type': u'feature',
#   u'year': u'1926'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjgwNjI3NTM1MF5BMl5BanBnXkFtZTgwNzY3MTUyMjE@._V1_.jpg',
#    u'width': 342},
#   u'num_votes': 61998,
#   u'rating': 8.2,
#   u'tconst': u'tt0050986',
#   u'title': u'Wild Strawberries',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTExNTk0MjIzNDZeQTJeQWpwZ15BbWU3MDY5ODI5Nzg@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 159481,
#   u'rating': 8.2,
#   u'tconst': u'tt0080678',
#   u'title': u'The Elephant Man',
#   u'type': u'feature',
#   u'year': u'1980'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjE0OTY0ODk2MF5BMl5BanBnXkFtZTcwNjQ5NjIzMQ@@._V1_.jpg',
#    u'width': 359},
#   u'num_votes': 27431,
#   u'rating': 8.5,
#   u'tconst': u'tt0074896',
#   u'title': u'The Message',
#   u'type': u'feature',
#   u'year': u'1976'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk4ODk5MTMyNV5BMl5BanBnXkFtZTcwMDMyNTg0Ng@@._V1_.jpg',
#    u'width': 1328},
#   u'num_votes': 326204,
#   u'rating': 8.2,
#   u'tconst': u'tt1291584',
#   u'title': u'Warrior',
#   u'type': u'feature',
#   u'year': u'2011'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIxMjgxNTk0MF5BMl5BanBnXkFtZTgwNjIyOTg2MDE@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 758582,
#   u'rating': 8.2,
#   u'tconst': u'tt0993846',
#   u'title': u'The Wolf of Wall Street',
#   u'type': u'feature',
#   u'year': u'2013'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
# ...
#    u'width': 500},
#   u'num_votes': 93998,
#   u'rating': 8.1,
#   u'tconst': u'tt0087544',
#   u'title': u'Nausica\xe4 of the Valley of the Wind',
#   u'type': u'feature',
#   u'year': u'1984'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjU4NDExNDM1NF5BMl5BanBnXkFtZTgwMDIyMTgxNzE@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 365515,
#   u'rating': 8.1,
#   u'tconst': u'tt1663202',
#   u'title': u'The Revenant',
#   u'type': u'feature',
#   u'year': u'2015'},
#  {u'can_rate': True,
#   u'image': {u'height': 1000,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjM2MDgxMDg0Nl5BMl5BanBnXkFtZTgwNTM2OTM5NDE@._V1_.jpg',
#    u'width': 667},
#   u'num_votes': 599216,
#   u'rating': 8.1,
#   u'tconst': u'tt0107290',
#   u'title': u'Jurassic Park',
#   u'type': u'feature',
#   u'year': u'1993'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDY2NjU0NDAxOF5BMl5BanBnXkFtZTgwNjQ4MTI2MTE@._V1_.jpg',
#    u'width': 351},
#   u'num_votes': 66943,
#   u'rating': 8.1,
#   u'tconst': u'tt0079944',
#   u'title': u'Stalker',
#   u'type': u'feature',
#   u'year': u'1979'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQyNTQ4MTAzNl5BMl5BanBnXkFtZTcwMjk2Njk3OA@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 168690,
#   u'rating': 8.1,
#   u'tconst': u'tt0083987',
#   u'title': u'Gandhi',
#   u'type': u'feature',
#   u'year': u'1982'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTcwNzc5MjI5Nl5BMl5BanBnXkFtZTYwNjIwMzc5._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 41223,
#   u'rating': 8.1,
#   u'tconst': u'tt0046911',
#   u'title': u'Diabolique',
#   u'type': u'feature',
#   u'year': u'1955'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQyMTM3MTQxMl5BMl5BanBnXkFtZTcwMDAzNjQ4Mg@@._V1_.jpg',
#    u'width': 346},
#   u'num_votes': 179136,
#   u'rating': 8.1,
#   u'tconst': u'tt0112471',
#   u'title': u'Before Sunrise',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 815,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgzNjMwOTM3N15BMl5BanBnXkFtZTcwMzA5MDY0MQ@@._V1_.jpg',
#    u'width': 550},
#   u'num_votes': 479336,
#   u'rating': 8.1,
#   u'tconst': u'tt0440963',
#   u'title': u'The Bourne Ultimatum',
#   u'type': u'feature',
#   u'year': u'2007'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTczMzE4Nzk3N15BMl5BanBnXkFtZTcwNDg5Mjc4NA@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 571393,
#   u'rating': 8.1,
#   u'tconst': u'tt0246578',
#   u'title': u'Donnie Darko',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTg4NTU3NTAyMF5BMl5BanBnXkFtZTgwNjYwNzc3NjE@._V1_.jpg',
#    u'width': 1012},
#   u'num_votes': 654667,
#   u'rating': 8.1,
#   u'tconst': u'tt0120382',
#   u'title': u'The Truman Show',
#   u'type': u'feature',
#   u'year': u'1998'},
#  {u'can_rate': True,
#   u'image': {u'height': 1748,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ4MTA0NjEzMF5BMl5BanBnXkFtZTgwMDg4NDYxMzE@._V1_.jpg',
#    u'width': 1258},
#   u'num_votes': 77199,
#   u'rating': 8.1,
#   u'tconst': u'tt0056801',
#   u'title': u'8\xbd',
#   u'type': u'feature',
#   u'year': u'1963'},
#  {u'can_rate': True,
#   u'image': {u'height': 550,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTI5OTA5MTI3OF5BMl5BanBnXkFtZTcwMjQyNzYzMQ@@._V1_.jpg',
#    u'width': 382},
#   u'num_votes': 64738,
#   u'rating': 8.1,
#   u'tconst': u'tt0353969',
#   u'title': u'Memories of Murder',
#   u'type': u'feature',
#   u'year': u'2003'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY5MDMzODUyOF5BMl5BanBnXkFtZTcwMTQ3NTMyNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 367431,
#   u'rating': 8.1,
#   u'tconst': u'tt0075148',
#   u'title': u'Rocky',
#   u'type': u'feature',
#   u'year': u'1976'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU0MTA2OTIwNF5BMl5BanBnXkFtZTcwMzA0Njk3OA@@._V1_.jpg',
#    u'width': 371},
#   u'num_votes': 287025,
#   u'rating': 8.1,
#   u'tconst': u'tt0032138',
#   u'title': u'The Wizard of Oz',
#   u'type': u'feature',
#   u'year': u'1939'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BODE1MDczNTUxOV5BMl5BanBnXkFtZTcwMTA0NDQyNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 589625,
#   u'rating': 8.1,
#   u'tconst': u'tt0088247',
#   u'title': u'The Terminator',
#   u'type': u'feature',
#   u'year': u'1984'},
#  {u'can_rate': True,
#   u'image': {u'height': 1000,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY1NTI0ODUyOF5BMl5BanBnXkFtZTgwNTEyNjQ0MDE@._V1_.jpg',
#    u'width': 675},
#   u'num_votes': 571674,
#   u'rating': 8.1,
#   u'tconst': u'tt0198781',
#   u'title': u'Monsters, Inc.',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk1NTAxNzg3Nl5BMl5BanBnXkFtZTcwNjU4OTQwNw@@._V1_.jpg',
#    u'width': 334},
#   u'num_votes': 39709,
#   u'rating': 8.1,
#   u'tconst': u'tt0036868',
#   u'title': u'The Best Years of Our Lives',
#   u'type': u'feature',
#   u'year': u'1946'},
#  {u'can_rate': True,
#   u'image': {u'height': 469,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTUyMzg2MTQ2NV5BMl5BanBnXkFtZTcwMTQxODEzMQ@@._V1._CR10,26,332,469_.jpg',
#    u'width': 332},
#   u'num_votes': 25339,
#   u'rating': 8.2,
#   u'tconst': u'tt0041546',
#   u'title': u'Kind Hearts and Coronets',
#   u'type': u'feature',
#   u'year': u'1949'},
#  {u'can_rate': True,
#   u'image': {u'height': 2000,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY2MTk3MDQ1N15BMl5BanBnXkFtZTcwMzI4NzA2NQ@@._V1_.jpg',
#    u'width': 1350},
#   u'num_votes': 530866,
#   u'rating': 8.1,
#   u'tconst': u'tt1201607',
#   u'title': u'Harry Potter and the Deathly Hallows: Part 2',
#   u'type': u'feature',
#   u'year': u'2011'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjI4MDIxNjk2Ml5BMl5BanBnXkFtZTcwMTA3Njk3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 455429,
#   u'rating': 8.1,
#   u'tconst': u'tt0114746',
#   u'title': u'Twelve Monkeys',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU0MzQyNTExMV5BMl5BanBnXkFtZTgwMjA0Njk1MDE@._V1_.jpg',
#    u'width': 335},
#   u'num_votes': 429393,
#   u'rating': 8.1,
#   u'tconst': u'tt0107048',
#   u'title': u'Groundhog Day',
#   u'type': u'feature',
#   u'year': u'1993'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTI2NjUyMDUyMV5BMl5BanBnXkFtZTcwMzU0OTkyMQ@@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 648498,
#   u'rating': 8.1,
#   u'tconst': u'tt0401792',
#   u'title': u'Sin City',
#   u'type': u'feature',
#   u'year': u'2005'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTcwNzk0MTQxMF5BMl5BanBnXkFtZTcwNjM5NTIwNA@@._V1_.jpg',
#    u'width': 303},
#   u'num_votes': 94446,
#   u'rating': 8.1,
#   u'tconst': u'tt0044079',
#   u'title': u'Strangers on a Train',
#   u'type': u'feature',
#   u'year': u'1951'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc0Mjg2OTY3OV5BMl5BanBnXkFtZTcwNDA3Njk3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 90323,
#   u'rating': 8.1,
#   u'tconst': u'tt0338564',
#   u'title': u'Infernal Affairs',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDcxODkyMjY4MF5BMl5BanBnXkFtZTgwOTk5NTc5MDE@._V1_.jpg',
#    u'width': 1000},
#   u'num_votes': 404631,
#   u'rating': 8,
#   u'tconst': u'tt0073195',
#   u'title': u'Jaws',
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY3OTAyOTMyM15BMl5BanBnXkFtZTcwNTMxMTI0MQ@@._V1_.jpg',
#    u'width': 354},
#   u'num_votes': 101469,
#   u'rating': 8.1,
#   u'tconst': u'tt0113247',
#   u'title': u'La Haine',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 381,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTIzMjI1OTQxNV5BMl5BanBnXkFtZTcwMzc3NTYyMQ@@._V1_.jpg',
#    u'width': 300},
#   u'num_votes': 36374,
#   u'rating': 8.1,
#   u'tconst': u'tt0058946',
#   u'title': u'The Battle of Algiers',
#   u'type': u'feature',
#   u'year': u'1966'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTczNzkyMjQ4N15BMl5BanBnXkFtZTcwOTQ2NjU4Mw@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 99527,
#   u'rating': 8.1,
#   u'tconst': u'tt0072684',
#   u'title': u'Barry Lyndon',
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTg0NTIzMjQ1NV5BMl5BanBnXkFtZTcwNDc3MzM5OQ@@._V1_.jpg',
#    u'width': 1384},
#   u'num_votes': 373630,
#   u'rating': 8.1,
#   u'tconst': u'tt1392214',
#   u'title': u'Prisoners',
#   u'type': u'feature',
#   u'year': u'2013'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQyNjQ5NjczM15BMl5BanBnXkFtZTYwNDA4MTk4._V1_.jpg',
#    u'width': 326},
#   u'num_votes': 179575,
#   u'rating': 8,
#   u'tconst': u'tt0072890',
#   u'title': u'Dog Day Afternoon',
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 1280,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc2MTQ3MDA1Nl5BMl5BanBnXkFtZTgwODA3OTI4NjE@._V1_.jpg',
#    u'width': 865},
#   u'num_votes': 435510,
#   u'rating': 8.1,
#   u'tconst': u'tt3659388',
#   u'title': u'The Martian',
#   u'type': u'feature',
#   u'year': u'2015'},
#  {u'can_rate': True,
#   u'image': {u'height': 2686,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjE0NDUzMDcyOF5BMl5BanBnXkFtZTcwNzAxMTA2Mw@@._V1_.jpg',
#    u'width': 1860},
#   u'num_votes': 163457,
#   u'rating': 8.1,
#   u'tconst': u'tt1220719',
#   u'title': u'Ip Man',
#   u'type': u'feature',
#   u'year': u'2008'},
#  {u'can_rate': True,
#   u'image': {u'height': 681,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDkwNTEyMzkzNl5BMl5BanBnXkFtZTgwNTAwNzk3MjE@._V1_.jpg',
#    u'width': 460},
#   u'num_votes': 448672,
#   u'rating': 8.1,
#   u'tconst': u'tt2084970',
#   u'title': u'The Imitation Game',
#   u'type': u'feature',
#   u'year': u'2014'},
#  {u'can_rate': True,
#   u'image': {u'height': 1400,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BOTUyODUwNjc0NV5BMl5BanBnXkFtZTcwMTk0MTcyMQ@@._V1_.jpg',
#    u'width': 1000},
#   u'num_votes': 42529,
#   u'rating': 8.1,
#   u'tconst': u'tt0083922',
#   u'title': u'Fanny and Alexander',
#   u'type': u'feature',
#   u'year': u'1982'},
#  {u'can_rate': True,
#   u'image': {u'height': 719,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY5MzYzNjc5NV5BMl5BanBnXkFtZTYwNTUyNTc2._V1_.jpg',
#    u'width': 485},
#   u'num_votes': 510185,
#   u'rating': 8,
#   u'tconst': u'tt0264464',
#   u'title': u'Catch Me If You Can',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjAyNDM4MTc2N15BMl5BanBnXkFtZTYwNDk0Mjc3._V1_.jpg',
#    u'width': 321},
#   u'num_votes': 796067,
#   u'rating': 8.1,
#   u'tconst': u'tt0325980',
#   u'title': u'Pirates of the Caribbean: The Curse of the Black Pearl',
#   u'type': u'feature',
#   u'year': u'2003'},
#  {u'can_rate': True,
#   u'image': {u'height': 1024,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk2NTI1MTU4N15BMl5BanBnXkFtZTcwODg0OTY0Nw@@._V1_.jpg',
#    u'width': 692},
#   u'num_votes': 976189,
#   u'rating': 8.1,
#   u'tconst': u'tt0848228',
#   u'title': u'The Avengers',
#   u'type': u'feature',
#   u'year': u'2012'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTAwMjU5OTgxNjZeQTJeQWpwZ15BbWU4MDUxNDYxODEx._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 659607,
#   u'rating': 8.1,
#   u'tconst': u'tt2015381',
#   u'title': u'Guardians of the Galaxy',
#   u'type': u'feature',
#   u'year': u'2014'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTM5OTMyMjIxOV5BMl5BanBnXkFtZTcwNzU4MjIwNQ@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 313306,
#   u'rating': 8.1,
#   u'tconst': u'tt1454029',
#   u'title': u'The Help',
#   u'type': u'feature',
#   u'year': u'2011'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTAzODAxMzg1MzZeQTJeQWpwZ15BbWU3MDgwMzE5ODk@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 143882,
#   u'rating': 8,
#   u'tconst': u'tt0058461',
#   u'title': u'A Fistful of Dollars',
#   u'type': u'feature',
#   u'year': u'1964'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMzU5MjEwMTg2Nl5BMl5BanBnXkFtZTcwNzM3MTYxNA@@._V1_.jpg',
#    u'width': 1401},
#   u'num_votes': 494258,
#   u'rating': 8,
#   u'tconst': u'tt1504320',
#   u'title': u"The King's Speech",
#   u'type': u'feature',
#   u'year': u'2010'},
#  {u'can_rate': True,
#   u'image': {u'height': 1102,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTg1ODgzODA1Nl5BMl5BanBnXkFtZTcwNTI0MzU3Mg@@._V1_.jpg',
#    u'width': 740},
#   u'num_votes': 98594,
#   u'rating': 8.1,
#   u'tconst': u'tt0046250',
#   u'title': u'Roman Holiday',
#   u'type': u'feature',
#   u'year': u'1953'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU4MTUyMTc3MV5BMl5BanBnXkFtZTYwOTg4Mzk5._V1_.jpg',
#    u'width': 334},
#   u'num_votes': 96903,
#   u'rating': 8.1,
#   u'tconst': u'tt0092067',
#   u'title': u'Castle in the Sky',
#   u'type': u'feature',
#   u'year': u'1986'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTM1MTk2NDIzOV5BMl5BanBnXkFtZTcwMTA5ODQxMQ@@._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 30877,
#   u'rating': 8.1,
#   u'tconst': u'tt0050613',
#   u'title': u'Throne of Blood',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTUxMzg0MzIwM15BMl5BanBnXkFtZTgwOTU0MjkwMTE@._V1_.jpg',
#    u'width': 343},
#   u'num_votes': 78946,
#   u'rating': 8.1,
#   u'tconst': u'tt0044706',
#   u'title': u'High Noon',
#   u'type': u'feature',
#   u'year': u'1952'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkyMDgwODY0OV5BMl5BanBnXkFtZTgwODI5NTQ5MTE@._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 302755,
#   u'rating': 8,
#   u'tconst': u'tt0101414',
#   u'title': u'Beauty and the Beast',
#   u'type': u'feature',
#   u'year': u'1991'},
#  {u'can_rate': True,
#   u'image': {u'height': 439,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk0MjY3NjEzN15BMl5BanBnXkFtZTYwNTk2NDI5._V1._CR13,35,325,439_.jpg',
#    u'width': 325},
#   u'num_votes': 74052,
#   u'rating': 8.1,
#   u'tconst': u'tt0118694',
#   u'title': u'In the Mood for Love',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTIwODMwMzA5Ml5BMl5BanBnXkFtZTcwMTQxNTEyMQ@@._V1_.jpg',
#    u'width': 329},
#   u'num_votes': 68664,
#   u'rating': 8.2,
#   u'tconst': u'tt0169102',
#   u'title': u'Lagaan: Once Upon a Time in India',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 2370,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc5NjY4MjUwNF5BMl5BanBnXkFtZTgwODM3NzM5MzE@._V1_.jpg',
#    u'width': 1600},
#   u'num_votes': 43238,
#   u'rating': 8.3,
#   u'tconst': u'tt1954470',
#   u'title': u'Gangs of Wasseypur',
#   u'type': u'feature',
#   u'year': u'2012'},
#  {u'can_rate': True,
#   u'image': {u'height': 1580,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTYzOTE2NjkxN15BMl5BanBnXkFtZTgwMDgzMTg0MzE@._V1_.jpg',
#    u'width': 1090},
#   u'num_votes': 81301,
#   u'rating': 8.3,
#   u'tconst': u'tt2338151',
#   u'title': u'PK',
#   u'type': u'feature',
#   u'year': u'2014'}]

# %% [markdown]
# #### 3. Make a dataframe from the movie data
#
# Keep the fields:
#
#     num_votes
#     rating
#     tconst
#     title
#     year
#
# And discard the rest

# %%
a= imdb.top_250() #This is a list of 250
len(a) #250 movies

df = pd.DataFrame(a) #movies df
df.head(4)
# Out:
#   can_rate                                              image  num_votes  \
# 0     True  {u'url': u'http://ia.media-imdb.com/images/M/M...    1660260
# 1     True  {u'url': u'http://ia.media-imdb.com/images/M/M...    1136368
# 2     True  {u'url': u'http://ia.media-imdb.com/images/M/M...     776109
# 3     True  {u'url': u'http://ia.media-imdb.com/images/M/M...    1645935
#
#    rating     tconst                     title     type  year
# 0     9.3  tt0111161  The Shawshank Redemption  feature  1994
# 1     9.2  tt0068646             The Godfather  feature  1972
# 2     9.0  tt0071562    The Godfather: Part II  feature  1974
# 3     9.0  tt0468569           The Dark Knight  feature  2008

# %%
cols = ['num_votes','rating','tconst','title','year']
df2 =df[cols]
df2.head(4)
# Out:
#    num_votes  rating     tconst                     title  year
# 0    1660260     9.3  tt0111161  The Shawshank Redemption  1994
# 1    1136368     9.2  tt0068646             The Godfather  1972
# 2     776109     9.0  tt0071562    The Godfather: Part II  1974
# 3    1645935     9.0  tt0468569           The Dark Knight  2008

# %% [markdown]
# #### 3. Select only the top 100 movies

# %%
df2 = df2[0:101] #Is this in the right order? What is the rating?
print df2
df2.shape
print df2.head(2)
# Out:
#      num_votes  rating     tconst  \
# 0      1660260     9.3  tt0111161
# 1      1136368     9.2  tt0068646
# 2       776109     9.0  tt0071562
# 3      1645935     9.0  tt0468569
# 4       849374     8.9  tt0108052
# 5       437922     8.9  tt0050083
# 6      1301183     8.9  tt0110912
# 7      1194767     8.9  tt0167260
# 8       494916     8.9  tt0060196
# 9      1321861     8.9  tt0137523
# 10     1218200     8.8  tt0120737
# 11      821418     8.8  tt0080684
# 12     1225084     8.8  tt0109830
# 13     1439479     8.8  tt1375666
# 14     1080893     8.7  tt0167261
# 15      668685     8.7  tt0073486
# 16      715698     8.7  tt0099685
# 17     1196367     8.7  tt0133093
# 18      225396     8.7  tt0047478
# 19      895015     8.7  tt0076759
# 20      524682     8.7  tt0317248
# 21     1004235     8.6  tt0114369
# 22      869467     8.6  tt0102926
# 23      271085     8.6  tt0038650
# 24      727988     8.6  tt0114814
# 25      410934     8.6  tt0118799
# 26      711974     8.6  tt0110413
# 27      212260     8.6  tt0064116
# 28      408101     8.6  tt0245429
# 29      864652     8.6  tt0120815
# ..         ...     ...        ...
# 71      667816     8.4  tt0086190
# 72       61447     8.4  tt0051201
# 73       97400     8.4  tt0022100
# 74      652083     8.4  tt0105236
# 75      525173     8.4  tt0211915
# 76      724729     8.4  tt0112573
# 77      563577     8.4  tt0180093
# 78      547637     8.4  tt0066921
# 79      497021     8.3  tt0075314
# 80       95899     8.4  tt0036775
# 81      532816     8.3  tt0435761
# 82      189381     8.4  tt0056172
# 83      210884     8.4  tt0056592
# 84      654216     8.3  tt0338013
# 85      475809     8.3  tt0093058
# 86      266121     8.3  tt0086879
# 87      172472     8.3  tt0070735
# 88      419124     8.3  tt0062622
# 89       92492     8.3  tt0040522
# 90      147400     8.3  tt0045152
# 91      591621     8.3  tt0208092
# 92      609637     8.3  tt0114709
# 93      376294     8.3  tt0071853
# 94      866609     8.3  tt0361748
# 95       65406     8.4  tt0012349
# 96      408201     8.3  tt0119488
# 97      153861     8.3  tt0059578
# 98      107291     8.3  tt0053604
# 99      100655     8.3  tt0042876
# 100     506362     8.3  tt0097576
#
#                                                  title  year
# 0                             The Shawshank Redemption  1994
# 1                                        The Godfather  1972
# 2                               The Godfather: Part II  1974
# 3                                      The Dark Knight  2008
# 4                                     Schindler's List  1993
# 5                                         12 Angry Men  1957
# 6                                         Pulp Fiction  1994
# 7        The Lord of the Rings: The Return of the King  2003
# 8                       The Good, the Bad and the Ugly  1966
# 9                                           Fight Club  1999
# 10   The Lord of the Rings: The Fellowship of the Ring  2001
# 11      Star Wars: Episode V - The Empire Strikes Back  1980
# 12                                        Forrest Gump  1994
# 13                                           Inception  2010
# 14               The Lord of the Rings: The Two Towers  2002
# 15                     One Flew Over the Cuckoo's Nest  1975
# 16                                          Goodfellas  1990
# 17                                          The Matrix  1999
# 18                                       Seven Samurai  1954
# 19                                           Star Wars  1977
# 20                                         City of God  2002
# 21                                               Se7en  1995
# 22                            The Silence of the Lambs  1991
# 23                               It's a Wonderful Life  1946
# 24                                  The Usual Suspects  1995
# 25                                   Life Is Beautiful  1997
# 26                              Léon: The Professional  1994
# 27                        Once Upon a Time in the West  1968
# 28                                       Spirited Away  2001
# 29                                 Saving Private Ryan  1998
# ..                                                 ...   ...
# 71          Star Wars: Episode VI - Return of the Jedi  1983
# 72                         Witness for the Prosecution  1957
# 73                                                   M  1931
# 74                                      Reservoir Dogs  1992
# 75                                              Amélie  2001
# 76                                          Braveheart  1995
# 77                                 Requiem for a Dream  2000
# 78                                  A Clockwork Orange  1971
# 79                                         Taxi Driver  1976
# 80                                    Double Indemnity  1944
# 81                                         Toy Story 3  2010
# 82                                  Lawrence of Arabia  1962
# 83                               To Kill a Mockingbird  1962
# 84               Eternal Sunshine of the Spotless Mind  2004
# 85                                   Full Metal Jacket  1987
# 86                                             Amadeus  1984
# 87                                           The Sting  1973
# 88                               2001: A Space Odyssey  1968
# 89                                     Bicycle Thieves  1948
# 90                                 Singin' in the Rain  1952
# 91                                             Snatch.  2000
# 92                                           Toy Story  1995
# 93                     Monty Python and the Holy Grail  1975
# 94                                Inglourious Basterds  2009
# 95                                             The Kid  1921
# 96                                   L.A. Confidential  1997
# 97                              For a Few Dollars More  1965
# 98                                       The Apartment  1960
# 99                                            Rashomon  1950
# 100                 Indiana Jones and the Last Crusade  1989
#
# [101 rows x 5 columns]
#    num_votes  rating     tconst                     title  year
# 0    1660260     9.3  tt0111161  The Shawshank Redemption  1994
# 1    1136368     9.2  tt0068646             The Godfather  1972

# %% [markdown]
# #### 4. Get the genres and runtime for each movie and add them to the dataframe
#
# There can be multiple genres per movie, so this will need some finessing.

# %%
b = df2.tconst #Top 100 movies id's
print b[0:2]
# Out:
# 0    tt0111161
# 1    tt0068646
# Name: tconst, dtype: object

# %%
def get_title(tt):
    title = imdb.get_title_by_id(tt)
    return title.genres

# df2['genre'] = df2['tconst'].map(lambda x: get_title(df2.tconst[0]))
# Why so slow?

genres4 = []
#Why didn't DataFrame list work?

for x in b[:]:
    c = get_title(x)
    genres4.append(c)
    print x, " : ", c
    
print genres4
# Out:
# tt0111161  :  [u'Crime', u'Drama']
# tt0068646  :  [u'Crime', u'Drama']
# tt0071562  :  [u'Crime', u'Drama']
# tt0468569  :  [u'Action', u'Crime', u'Thriller']
# tt0108052  :  [u'Biography', u'Drama', u'History']
# tt0050083  :  [u'Crime', u'Drama']
# tt0110912  :  [u'Crime', u'Drama']
# tt0167260  :  [u'Adventure', u'Drama', u'Fantasy']
# tt0060196  :  [u'Western']
# tt0137523  :  [u'Drama']
# tt0120737  :  [u'Adventure', u'Drama', u'Fantasy']
# tt0080684  :  [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# tt0109830  :  [u'Drama', u'Romance']
# tt1375666  :  [u'Action', u'Mystery', u'Sci-Fi', u'Thriller']
# tt0167261  :  [u'Action', u'Adventure', u'Drama', u'Fantasy']
# tt0073486  :  [u'Drama']
# tt0099685  :  [u'Biography', u'Crime', u'Drama']
# tt0133093  :  [u'Action', u'Sci-Fi']
# tt0047478  :  [u'Action', u'Adventure', u'Drama']
# tt0076759  :  [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# tt0317248  :  [u'Crime', u'Drama']
# tt0114369  :  [u'Crime', u'Drama', u'Mystery', u'Thriller']
# tt0102926  :  [u'Crime', u'Drama', u'Thriller']
# tt0038650  :  [u'Drama', u'Family', u'Fantasy', u'Romance']
# tt0114814  :  [u'Crime', u'Drama', u'Mystery', u'Thriller']
# tt0118799  :  [u'Comedy', u'Drama', u'Romance', u'War']
# tt0110413  :  [u'Crime', u'Drama', u'Thriller']
# tt0064116  :  [u'Western']
# tt0245429  :  [u'Animation', u'Adventure', u'Family', u'Fantasy']
# tt0120815  :  [u'Action', u'Drama', u'War']
# tt0120586  :  [u'Crime', u'Drama']
# tt0034583  :  [u'Drama', u'Romance', u'War']
# tt0816692  :  [u'Adventure', u'Drama', u'Sci-Fi']
# tt0054215  :  [u'Horror', u'Mystery', u'Thriller']
# tt0021749  :  [u'Comedy', u'Drama', u'Romance']
# tt0082971  :  [u'Action', u'Adventure']
# tt1675434  :  [u'Biography', u'Comedy', u'Drama']
# tt0047396  :  [u'Mystery', u'Thriller']
# tt0027977  :  [u'Comedy', u'Drama']
# tt0120689  :  [u'Crime', u'Drama', u'Fantasy', u'Mystery']
# tt0103064  :  [u'Action', u'Sci-Fi']
# tt0253474  :  [u'Biography', u'Drama', u'War']
# tt0407887  :  [u'Crime', u'Drama', u'Thriller']
# tt0088763  :  [u'Adventure', u'Comedy', u'Sci-Fi']
# tt2582802  :  [u'Drama', u'Music']
# tt0172495  :  [u'Action', u'Drama']
# tt0209144  :  [u'Mystery', u'Thriller']
# tt0078788  :  [u'Drama', u'War']
# tt0482571  :  [u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']
# tt0110357  :  [u'Animation', u'Adventure', u'Drama', u'Family', u'Musical']
# tt0057012  :  [u'Comedy']
# tt0043014  :  [u'Drama', u'Film-Noir']
# tt0078748  :  [u'Horror', u'Sci-Fi']
# tt0032553  :  [u'Comedy', u'Drama', u'War']
# tt0405094  :  [u'Drama', u'Thriller']
# tt0095765  :  [u'Drama']
# tt1853728  :  [u'Drama', u'Western']
# tt0081505  :  [u'Drama', u'Horror']
# tt0050825  :  [u'Drama', u'War']
# tt0095327  :  [u'Animation', u'Drama', u'War']
# tt0910970  :  [u'Animation', u'Adventure', u'Family', u'Sci-Fi']
# tt1345836  :  [u'Action', u'Thriller']
# tt0169547  :  [u'Drama']
# tt0090605  :  [u'Action', u'Horror', u'Sci-Fi']
# tt0119698  :  [u'Animation', u'Adventure', u'Fantasy']
# tt0364569  :  [u'Drama', u'Mystery', u'Thriller']
# tt0033467  :  [u'Drama', u'Mystery']
# tt0053125  :  [u'Adventure', u'Crime', u'Mystery', u'Thriller']
# tt0087843  :  [u'Crime', u'Drama']
# tt0082096  :  [u'Adventure', u'Drama', u'Thriller', u'War']
# tt0052357  :  [u'Mystery', u'Romance', u'Thriller']
# tt0086190  :  [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# tt0051201  :  [u'Crime', u'Drama', u'Mystery', u'Thriller']
# tt0022100  :  [u'Crime', u'Drama', u'Mystery', u'Thriller']
# tt0105236  :  [u'Crime', u'Drama', u'Thriller']
# tt0211915  :  [u'Comedy', u'Romance']
# tt0112573  :  [u'Biography', u'Drama', u'History', u'War']
# tt0180093  :  [u'Drama']
# tt0066921  :  [u'Crime', u'Drama', u'Sci-Fi']
# tt0075314  :  [u'Crime', u'Drama']
# tt0036775  :  [u'Crime', u'Drama', u'Film-Noir', u'Mystery', u'Thriller']
# tt0435761  :  [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# tt0056172  :  [u'Adventure', u'Biography', u'Drama', u'History', u'War']
# tt0056592  :  [u'Crime', u'Drama']
# tt0338013  :  [u'Drama', u'Romance', u'Sci-Fi']
# tt0093058  :  [u'Drama', u'War']
# tt0086879  :  [u'Biography', u'Drama', u'History', u'Music']
# tt0070735  :  [u'Comedy', u'Crime', u'Drama']
# tt0062622  :  [u'Adventure', u'Mystery', u'Sci-Fi']
# tt0040522  :  [u'Drama']
# tt0045152  :  [u'Comedy', u'Musical', u'Romance']
# tt0208092  :  [u'Comedy', u'Crime']
# tt0114709  :  [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# tt0071853  :  [u'Adventure', u'Comedy', u'Fantasy']
# tt0361748  :  [u'Adventure', u'Drama', u'War']
# tt0012349  :  [u'Comedy', u'Drama', u'Family']
# tt0119488  :  [u'Crime', u'Drama', u'Mystery', u'Thriller']
# tt0059578  :  [u'Western']
# tt0053604  :  [u'Comedy', u'Drama', u'Romance']
# tt0042876  :  [u'Crime', u'Drama']
# tt0097576  :  [u'Action', u'Adventure', u'Fantasy']
# [[u'Crime', u'Drama'], [u'Crime', u'Drama'], [u'Crime', u'Drama'], [u'Action', u'Crime', u'Thriller'], [u'Biography', u'Drama', u'History'], [u'Crime', u'Drama'], [u'Crime', u'Drama'], [u'Adventure', u'Drama', u'Fantasy'], [u'Western'], [u'Drama'], [u'Adventure', u'Drama', u'Fantasy'], [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi'], [u'Drama', u'Romance'], [u'Action', u'Mystery', u'Sci-Fi', u'Thriller'], [u'Action', u'Adventure', u'Drama', u'Fantasy'], [u'Drama'], [u'Biography', u'Crime', u'Drama'], [u'Action', u'Sci-Fi'], [u'Action', u'Adventure', u'Drama'], [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi'], [u'Crime', u'Drama'], [u'Crime', u'Drama', u'Mystery', u'Thriller'], [u'Crime', u'Drama', u'Thriller'], [u'Drama', u'Family', u'Fantasy', u'Romance'], [u'Crime', u'Drama', u'Mystery', u'Thriller'], [u'Comedy', u'Drama', u'Romance', u'War'], [u'Crime', u'Drama', u'Thriller'], [u'Western'], [u'Animation', u'Adventure', u'Family', u'Fantasy'], [u'Action', u'Drama', u'War'], [u'Crime', u'Drama'], [u'Drama', u'Romance', u'War'], [u'Adventure', u'Drama', u'Sci-Fi'], [u'Horror', u'Mystery', u'Thriller'], [u'Comedy', u'Drama', u'Romance'], [u'Action', u'Adventure'], [u'Biography', u'Comedy', u'Drama'], [u'Mystery', u'Thriller'], [u'Comedy', u'Drama'], [u'Crime', u'Drama', u'Fantasy', u'Mystery'], [u'Action', u'Sci-Fi'], [u'Biography', u'Drama', u'War'], [u'Crime', u'Drama', u'Thriller'], [u'Adventure', u'Comedy', u'Sci-Fi'], [u'Drama', u'Music'], [u'Action', u'Drama'], [u'Mystery', u'Thriller'], [u'Drama', u'War'], [u'Drama', u'Mystery', u'Sci-Fi', u'Thriller'], [u'Animation', u'Adventure', u'Drama', u'Family', u'Musical'], [u'Comedy'], [u'Drama', u'Film-Noir'], [u'Horror', u'Sci-Fi'], [u'Comedy', u'Drama', u'War'], [u'Drama', u'Thriller'], [u'Drama'], [u'Drama', u'Western'], [u'Drama', u'Horror'], [u'Drama', u'War'], [u'Animation', u'Drama', u'War'], [u'Animation', u'Adventure', u'Family', u'Sci-Fi'], [u'Action', u'Thriller'], [u'Drama'], [u'Action', u'Horror', u'Sci-Fi'], [u'Animation', u'Adventure', u'Fantasy'], [u'Drama', u'Mystery', u'Thriller'], [u'Drama', u'Mystery'], [u'Adventure', u'Crime', u'Mystery', u'Thriller'], [u'Crime', u'Drama'], [u'Adventure', u'Drama', u'Thriller', u'War'], [u'Mystery', u'Romance', u'Thriller'], [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi'], [u'Crime', u'Drama', u'Mystery', u'Thriller'], [u'Crime', u'Drama', u'Mystery', u'Thriller'], [u'Crime', u'Drama', u'Thriller'], [u'Comedy', u'Romance'], [u'Biography', u'Drama', u'History', u'War'], [u'Drama'], [u'Crime', u'Drama', u'Sci-Fi'], [u'Crime', u'Drama'], [u'Crime', u'Drama', u'Film-Noir', u'Mystery', u'Thriller'], [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy'], [u'Adventure', u'Biography', u'Drama', u'History', u'War'], [u'Crime', u'Drama'], [u'Drama', u'Romance', u'Sci-Fi'], [u'Drama', u'War'], [u'Biography', u'Drama', u'History', u'Music'], [u'Comedy', u'Crime', u'Drama'], [u'Adventure', u'Mystery', u'Sci-Fi'], [u'Drama'], [u'Comedy', u'Musical', u'Romance'], [u'Comedy', u'Crime'], [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy'], [u'Adventure', u'Comedy', u'Fantasy'], [u'Adventure', u'Drama', u'War'], [u'Comedy', u'Drama', u'Family'], [u'Crime', u'Drama', u'Mystery', u'Thriller'], [u'Western'], [u'Comedy', u'Drama', u'Romance'], [u'Crime', u'Drama'], [u'Action', u'Adventure', u'Fantasy']]

# %%
def get_runtime(tt):
    title = imdb.get_title_by_id(tt)
    return title.runtime

runtime = []

b = df2.tconst

for x in b[:]:
    c = get_runtime(x)
    runtime.append(c)
    print x, " : ", c
    
print runtime
# Out:
# tt0111161  :  8520
# tt0068646  :  10500
# tt0071562  :  12120
# tt0468569  :  9120
# tt0108052  :  11700
# tt0050083  :  5760
# tt0110912  :  9240
# tt0167260  :  12060
# tt0060196  :  9660
# tt0137523  :  8340
# tt0120737  :  10680
# tt0080684  :  7440
# tt0109830  :  8520
# tt1375666  :  8880
# tt0167261  :  10740
# tt0073486  :  7980
# tt0099685  :  8760
# tt0133093  :  8160
# tt0047478  :  9480
# tt0076759  :  7260
# tt0317248  :  7800
# tt0114369  :  7620
# tt0102926  :  7080
# tt0038650  :  7800
# tt0114814  :  6360
# tt0118799  :  6960
# tt0110413  :  6600
# tt0064116  :  8700
# tt0245429  :  7500
# tt0120815  :  10140
# tt0120586  :  6060
# tt0034583  :  6120
# tt0816692  :  10140
# tt0054215  :  6540
# tt0021749  :  5220
# tt0082971  :  6900
# tt1675434  :  6720
# tt0047396  :  6720
# tt0027977  :  5220
# tt0120689  :  11340
# tt0103064  :  9180
# tt0253474  :  9000
# tt0407887  :  9060
# tt0088763  :  6960
# tt2582802  :  6420
# tt0172495  :  9300
# tt0209144  :  6780
# tt0078788  :  9180
# tt0482571  :  7800
# tt0110357  :  5340
# tt0057012  :  5700
# tt0043014  :  6600
# tt0078748  :  7020
# tt0032553  :  7500
# tt0405094  :  8220
# tt0095765  :  9300
# tt1853728  :  9900
# tt0081505  :  8640
# tt0050825  :  5280
# tt0095327  :  5340
# tt0910970  :  5880
# tt1345836  :  9840
# tt0169547  :  7320
# tt0090605  :  9240
# tt0119698  :  8040
# tt0364569  :  7200
# tt0033467  :  7140
# tt0053125  :  8160
# tt0087843  :  8340
# tt0082096  :  14340
# tt0052357  :  7740
# tt0086190  :  7860
# tt0051201  :  6960
# tt0022100  :  5940
# tt0105236  :  5940
# tt0211915  :  7320
# tt0112573  :  10680
# tt0180093  :  6120
# tt0066921  :  8160
# tt0075314  :  6780
# tt0036775  :  6420
# tt0435761  :  6180
# tt0056172  :  13620
# tt0056592  :  7740
# tt0338013  :  6480
# tt0093058  :  6960
# tt0086879  :  9600
# tt0070735  :  7740
# tt0062622  :  8940
# tt0040522  :  5340
# tt0045152  :  6180
# tt0208092  :  6120
# tt0114709  :  4860
# tt0071853  :  5460
# tt0361748  :  9180
# tt0012349  :  4080
# tt0119488  :  8280
# tt0059578  :  7920
# tt0053604  :  7500
# tt0042876  :  5280
# tt0097576  :  7620
# [8520, 10500, 12120, 9120, 11700, 5760, 9240, 12060, 9660, 8340, 10680, 7440, 8520, 8880, 10740, 7980, 8760, 8160, 9480, 7260, 7800, 7620, 7080, 7800, 6360, 6960, 6600, 8700, 7500, 10140, 6060, 6120, 10140, 6540, 5220, 6900, 6720, 6720, 5220, 11340, 9180, 9000, 9060, 6960, 6420, 9300, 6780, 9180, 7800, 5340, 5700, 6600, 7020, 7500, 8220, 9300, 9900, 8640, 5280, 5340, 5880, 9840, 7320, 9240, 8040, 7200, 7140, 8160, 8340, 14340, 7740, 7860, 6960, 5940, 5940, 7320, 10680, 6120, 8160, 6780, 6420, 6180, 13620, 7740, 6480, 6960, 9600, 7740, 8940, 5340, 6180, 6120, 4860, 5460, 9180, 4080, 8280, 7920, 7500, 5280, 7620]

# %% [markdown]
# #### 4. Write the Results to a csv

# %%
df2['runtime'] = runtime

df2['genres'] = genres4

df3 = df2

print df2.head(2)

#import io
#df3 = io.open("./out_1_Z.csv", 'w', encoding='utf8')

df3.to_csv('./out_1_Z.csv', encoding='utf-8')
# Out:
#    num_votes  rating     tconst                     title  year  runtime  \
# 0    1660260     9.3  tt0111161  The Shawshank Redemption  1994     8520
# 1    1136368     9.2  tt0068646             The Godfather  1972    10500
#
#            genres
# 0  [Crime, Drama]
# 1  [Crime, Drama]

# %%
df3.to_csv('./out_1_ZB.csv', encoding='utf-8')

# %% [markdown]
# ---
#
# ## Part 2: Wrangle the text data

# %% [markdown]
# #### 1. Scrape the reviews for the top 100 movies

# %% [markdown]
# *Hint*: Use a loop to scrape each page at once

# %%
# title = imdb.get_title_reviews(df2.tconst[0])
# a = title
# a = pd.Series(a)
#reviews = imdb.get_title_reviews("tt0468569")

reviews= []

b = df2.tconst

for x in b[:]:
    c = imdb.get_title_reviews(x)
    reviews.append(c)
#    print x, " : ", c
    
print reviews[0]
# Out:
# [<Review: u'Why do I want to wri'>, <Review: u'\nCan Hollywood, usua'>, <Review: u'\nI have never seen s'>, <Review: u'In its Oscar year, S'>, <Review: u'The reason I became '>, <Review: u'\nI believe that this'>, <Review: u'\nOne of my all time '>, <Review: u'\nOne of the finest f'>, <Review: u'Misery and Stand By '>, <Review: u'\nThe Shawshank Redem'>]

# %% [markdown]
# #### 2. Extract the reviews and the rating per review for each movie
#
# *Note*: "soup" from BeautifulSoup is the html returned from all 25 pages. You'll need to either address each page individually or break them down by elements.

# %%
import requests

movie_tt = b[0]
page_no = 10
x=1

from scrapy.selector import Selector
from scrapy.http import HtmlResponse

# definition to find reviews for each movie
def extract_pages(movie_tt):

    urla = "http://www.imdb.com/title/" + movie_tt + "/reviews?start=" + str(10)
    
    response = requests.get(urla)
    HTML = response.text  
    # This xpath query will find the number of total results

    tot_reviews = "//table/tr/td/text()"
    for_pages = Selector(text=HTML).xpath(tot_reviews)
    page_tot = for_pages.extract()
    #print "Page total: ", page_tot

    page_tot_a = 0
    page_tot_b = 0

    for z in page_tot:
        if "reviews" in z:
            page_tot_b = z
        else:
            page_tot_a = 0

    y = page_tot_b.split()
    page_tot_c = int(y[0])
    #pages = page_tot_c*1.0/10
    pages = page_tot_c

    #import math
    #pages = int(math.ceil(pages))
    #print urla
    return int(pages)
    print pages

# %%
def extract_reviews_txt(movie_tt, pages):

    review_txt = []

    review_df=pd.DataFrame()

    for i in range(0,pages,10):
        page_no = i
        urla = "http://www.imdb.com/title/" + movie_tt + "/reviews?start=" + str(page_no)
        response = requests.get(urla)
        HTML = response.text  
        print urla

        for j in range(1,11):
            
            jb = j*2-1
            
            selector_a = "//div[@id='tn15content']/p[" + str(j) + "]/text()"


            results_a = Selector(text=HTML).xpath(selector_a)
            total_results_a = results_a.extract()

            review_txt.append(total_results_a)


    review_df['txt'] = review_txt
    return review_df

pages =20
print extract_reviews_txt(movie_tt, pages)
# Out:
# http://www.imdb.com/title/tt0111161/reviews?start=0
# http://www.imdb.com/title/tt0111161/reviews?start=10
#                                                   txt
# 0   [\nWhy do I want to write the 234th comment on...
# 1   [\n\nCan Hollywood, usually creating things fo...
# 2   [\n\nI have never seen such an amazing film si...
# 3   [\nIn its Oscar year, Shawshank Redemption (wr...
# 4   [\nThe reason I became a member of this databa...
# 5   [\n\nI believe that this film is the best stor...
# 6   [\n\nOne of my all time favorites. Shawshank R...
# 7   [\n\nOne of the finest films made in recent ye...
# 8   [\nMisery and Stand By Me were the best adapta...
# 9   [\n\nThe Shawshank Redemption is without a dou...
# 10  [\nThis movie is not your ordinary Hollywood f...
# 11  [\n\nWhenever I talk about this movie with my ...
# 12  [\nI'm trying to save you money; this is the l...
# 13  [\nThe Shawshank Redemption is written and dir...
# 14  [\nAt the heart of this extraordinary movie is...
# 15  [\n\n**Yes, there are SPOILERS here**, This fi...
# 16  [\nWe have all see movies, comedies, action an...
# 17  [\nThis touching and heart warming film is the...
# 18  [\nProbably yes, acting was good, plot brillia...
# 19  [\n\nIn recent years the IMDB top 250 movies h...

# %%
def extract_reviews(movie_tt, pages):

    review_score = []
    review_author = []
    review_title = []
    review_df=pd.DataFrame()

    for i in range(0,pages,10): #increments of 10
        page_no = i
        urla = "http://www.imdb.com/title/" + movie_tt + "/reviews?start=" + str(page_no)
        response = requests.get(urla)
        HTML = response.text  
        print urla

        for j in range(1,11):
            
            jb = j*2-1
            
            selector_b = "//div[" + str(jb) + "]/img/@src"
            selector_c = "//div[@id='tn15content']/div[" + str(jb) + "]/a[2]/text()"


            results_b = Selector(text=HTML).xpath(selector_b)
            
            try:
                total_results_b = results_b[0].extract()
            except:
                total_results_b = "" 
                
            results_c = Selector(text=HTML).xpath(selector_c)
            total_results_c = results_c.extract()

            review_title.append(movie_tt)
            review_score.append(total_results_b)
            review_author.append(total_results_c)
        
    review_df['tt'] = review_title
    review_df['score']= review_score
    review_df['author'] = review_author
    return review_df
    
print extract_reviews(movie_tt, pages)        
# print review_txt[2]
# print review_score[2]
# print review_author[2]
# Out:
# http://www.imdb.com/title/tt0111161/reviews?start=0
# http://www.imdb.com/title/tt0111161/reviews?start=10
#            tt                                             score  \
# 0   tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 1   tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 2   tt0111161
# 3   tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 4   tt0111161
# 5   tt0111161   http://i.media-imdb.com/images/showtimes/80.gif
# 6   tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 7   tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 8   tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 9   tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 10  tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 11  tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 12  tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 13  tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 14  tt0111161   http://i.media-imdb.com/images/showtimes/80.gif
# 15  tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 16  tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 17  tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 18  tt0111161  http://i.media-imdb.com/images/showtimes/100.gif
# 19  tt0111161   http://i.media-imdb.com/images/showtimes/80.gif
#
#                                  author
# 0                              [carflo]
# 1                    [Wesley S. Walker]
# 2                           [speedreid]
# 3                 [Justin M (kaspen12)]
# 4                           [Douglas-2]
# 5                             [Si Cole]
# 6             [Thomas McFadden (tmac4)]
# 7                             [Tim Cox]
# 8       [Dan Grant (dan.grant@bell.ca)]
# 9   [Thomas Peluso (tpeluso@gmail.com)]
# 10                   [alexkolokotronis]
# 11                        [chad millar]
# 12                           [EyeDunno]
# 13                         [Spikeopath]
# 14                    [Dennis Littrell]
# 15                      [ProperCharlie]
# 16                           [Bloker Q]
# 17                            [Dave-79]
# 18                 [stozasumodrakinetu]
# 19                     [Theo Robertson]

# %% [markdown]
# #### 3. Remove the non AlphaNumeric characters from reviews

# %%
import re

def remove_nonalphanum(your_string):
    return re.sub(r'\W+', ' ', your_string)

# for i, j in enumerate(review_txt):
#     a = str(review_txt[i])
#     a = a.replace("\\n", " ")
#     a = remove_nonalphanum(a)
#     review_txt[i] = a
    
def remove_nonalphanum_txt(review_txt):
    a = str(review_txt)
    a = a.replace("\\n", " ")
    return re.sub(r'\W+', ' ', a)

# %% [markdown]
# #### 4. Calculate the top 200 ngrams from the user reviews
#
# Use the `TfidfVectorizer` in sklearn.
#
# Recommended parameters:
#
#     ngram_range = (1, 2)
#     stop_words = 'english'
#     binary = False
#     max_features = 200

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#Week 6, lab 4.1 intro to nlp

def vectorize_me(review_txt):

    string1 = str(review_txt)

    tvec = TfidfVectorizer(
        stop_words='english',
        ngram_range = (1, 2),
        binary = False,
        max_features = 200
                          )
    tvec.fit([string1])

    df  = pd.DataFrame(tvec.transform([string1]).todense(),
                       columns=tvec.get_feature_names(),
                       index=['string1'])

    df.transpose().sort_values('string1', ascending=True) #.head(10) #.transpose()
    return df.columns.values

# %%
def extract_reviews_ngram(movie_tt, pages):

    review_txt = []
    review_score = []
    review_author = []
    review_title = []
    review_df=pd.DataFrame()

    review_df=pd.DataFrame()

    for i in range(0,pages,10):
        page_no = i
        urla = "http://www.imdb.com/title/" + movie_tt + "/reviews?start=" + str(page_no)
        response = requests.get(urla)
        HTML = response.text  
        #print urla

        for j in range(1,11):
            
            selector_a = "//div[@id='tn15content']/p[" + str(j) + "]/text()"


            results_a = Selector(text=HTML).xpath(selector_a)
            total_results_a = results_a.extract()
            
            total_results_a = remove_nonalphanum_txt(total_results_a)
            
            try:
                total_results_a = vectorize_me(total_results_a)
            except:
                total_results_a = ""
                
            review_txt.append(total_results_a)

            jb = j*2-1
            
            selector_b = "//div[" + str(jb) + "]/img/@src"
            selector_c = "//div[@id='tn15content']/div[" + str(jb) + "]/a[2]/text()"


            results_b = Selector(text=HTML).xpath(selector_b)
            
            try:
                total_results_b = results_b[0].extract()
            except:
                total_results_b = "" 
                
            results_c = Selector(text=HTML).xpath(selector_c)
            total_results_c = results_c.extract()

            review_title.append(movie_tt)
            review_score.append(total_results_b)
            review_author.append(total_results_c)        

    review_df['title'] = review_title
    review_df['txt'] = review_txt
    review_df['score'] = review_score
    review_df['author'] = review_author
    
    return review_df

# %% [markdown]
# #### 5. Merge the user reviews and ratings

# %%
review_df2 = pd.DataFrame(columns=['title','txt','score','author'])
review_df3 = pd.DataFrame()

dummy = 0

for i, j in enumerate(b):
    maxreviews = extract_pages(b[i])
    #this is taking too long, limit max reviews to 1000
    maxreviews = min(maxreviews, 1000)
    print ("Review", i, " ", maxreviews)
    #maxreviews = 20

    try:
        review_df3 = extract_reviews_ngram(b[i], maxreviews)
        review_df2 = review_df2.append(review_df3, ignore_index=True)
    except:
        dummy=0

# %%
print review_df2.head(50)

# %% [markdown]
# #### 6. Save this merged dataframe as a csv

# %%
review_df2.to_csv('./out_2.csv', encoding='utf-8')

# %% [markdown]
# ---
#
# ## Part 3: Combine Tables in PostgreSQL

# %% [markdown]
# #### 1. Import your two .csv data files into your Postgre Database as two different tables

# %%
#week 5 lab 3.3 local postgres lab - postico
#Connect to local postgres server

# %% [markdown]
# For ease, we can call these table1 and table2

# %%
import pandas as pd
df_table1 = pd.read_csv('./out_1.csv')
df_table2 = pd.read_csv('./out_2.csv')

#df.columns = [c.lower() for c in df.columns] #postgres doesn't like capitals or spaces
#psql -h dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com -p 5432 -U dsi_student titanic
#engine = create_engine('postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com:5432/titanic')



from sqlalchemy import create_engine
#engine = create_engine('postgresql://username:password@localhost:5432/dbname')
engine = create_engine('postgresql://noriogura:@localhost:5432/project6')

df_table1.to_sql("table1", engine)
df_table2.to_sql("table2", engine)

# %%
#pd.read_sql("SELECT * FROM my_table_name, engine)
            
pd.read_sql("SELECT * FROM pg_catalog.pg_tables WHERE schemaname='public'", con=engine)
# Out:
#   schemaname       tablename tableowner tablespace hasindexes hasrules  \
# 0     public  untitled_table  noriogura       None       True    False
# 1     public   my_table_name  noriogura       None       True    False
#
#   hastriggers rowsecurity
# 0       False       False
# 1       False       False

# %%
df_table1 = pd.read_sql("SELECT * FROM table1", con=engine)
df_table1.head(10)
# Out:
#     index  Unnamed: 0  num_votes  rating     tconst  \
# 0       0           0    1659464     9.3  tt0111161
# 1       1           1    1135853     9.2  tt0068646
# 2       2           2     775753     9.0  tt0071562
# 3       3           3    1645164     9.0  tt0468569
# 4       4           4     848954     8.9  tt0108052
# 5       5           5     437710     8.9  tt0050083
# 6       6           6    1300563     8.9  tt0110912
# 7       7           7    1194223     8.9  tt0167260
# 8       8           8     494702     8.9  tt0060196
# 9       9           9    1321233     8.9  tt0137523
# 10     10          10    1217678     8.8  tt0120737
# 11     11          11     820978     8.8  tt0080684
# 12     12          12    1224424     8.8  tt0109830
# 13     13          13    1438762     8.8  tt1375666
# 14     14          14    1080374     8.7  tt0167261
# 15     15          15     668426     8.7  tt0073486
# 16     16          16     715363     8.7  tt0099685
# 17     17          17    1195789     8.7  tt0133093
# 18     18          18     225325     8.7  tt0047478
# 19     19          19     894578     8.7  tt0076759
# 20     20          20     524471     8.7  tt0317248
#
#                                                 title  year  runtime  \
# 0                            The Shawshank Redemption  1994     8520
# 1                                       The Godfather  1972    10500
# 2                              The Godfather: Part II  1974    12120
# 3                                     The Dark Knight  2008     9120
# 4                                    Schindler's List  1993    11700
# 5                                        12 Angry Men  1957     5760
# 6                                        Pulp Fiction  1994     9240
# 7       The Lord of the Rings: The Return of the King  2003    12060
# 8                      The Good, the Bad and the Ugly  1966     9660
# 9                                          Fight Club  1999     8340
# 10  The Lord of the Rings: The Fellowship of the Ring  2001    10680
# 11     Star Wars: Episode V - The Empire Strikes Back  1980     7440
# 12                                       Forrest Gump  1994     8520
# 13                                          Inception  2010     8880
# 14              The Lord of the Rings: The Two Towers  2002    10740
# 15                    One Flew Over the Cuckoo's Nest  1975     7980
# 16                                         Goodfellas  1990     8760
# 17                                         The Matrix  1999     8160
# 18                                      Seven Samurai  1954     9480
# 19                                          Star Wars  1977     7260
# 20                                        City of God  2002     7800
#
#                                               genres
# 0                               [u'Crime', u'Drama']
# 1                               [u'Crime', u'Drama']
# 2                               [u'Crime', u'Drama']
# 3                 [u'Action', u'Crime', u'Thriller']
# 4               [u'Biography', u'Drama', u'History']
# 5                               [u'Crime', u'Drama']
# 6                               [u'Crime', u'Drama']
# 7               [u'Adventure', u'Drama', u'Fantasy']
# 8                                       [u'Western']
# 9                                         [u'Drama']
# 10              [u'Adventure', u'Drama', u'Fantasy']
# 11  [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# 12                            [u'Drama', u'Romance']
# 13   [u'Action', u'Mystery', u'Sci-Fi', u'Thriller']
# 14   [u'Action', u'Adventure', u'Drama', u'Fantasy']
# 15                                        [u'Drama']
# 16                [u'Biography', u'Crime', u'Drama']
# 17                            [u'Action', u'Sci-Fi']
# 18               [u'Action', u'Adventure', u'Drama']
# 19  [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# 20                              [u'Crime', u'Drama']

# %%
df_table2 = pd.read_sql("SELECT * FROM table2", con=engine)
df_table2.head(10)

# %% [markdown]
# #### 2. Connect to database and query the joined set

# %%
#week6-2.1-sql-joins

sql = """
SELECT * from table2 rev_table
LEFT JOIN table1 genre_table
ON rev_table."tconst" = genre_table."tconst"
) as table_12
"""

df = pd.read_sql(sql, con=engine)
df.head(3)

# %% [markdown]
# #### 3. Join the two tables

# %%
df.to_sql("table_12", engine)

# %% [markdown]
# #### 4. Select the newly joined table and save two copies of the into dataframes

# %%
df_table12A = pd.read_sql("SELECT * FROM table_12", con=engine) #copy1
df_table12B = df_table12A #copy2?why

# %% [markdown]
# ---
#
# ## Part 4: Parsing and Exploratory Data Analysis

# %% [markdown]
# #### 1. Rename any columns you think should be renamed for clarity

# %% [markdown]
# #### 2. Describe anything interesting or suspicious about your data (quality assurance)

# %% [markdown]
# #### 3. Make four visualizations of interest to you using the data

# %% [markdown]
# ---
#
# ## Part 5: Decision Tree Classifiers and Regressors

# %% [markdown]
# #### 1. What is our target attribute?
#
# Choose a target variable for the decision tree regressor and the classifier.

# %% [markdown]
# #### 2. Prepare the X and Y matrices and preprocess data as you see fit

# %% [markdown]
# #### 3. Build and cross-validate your decision tree classifier

# %% [markdown]
# #### 4. Gridsearch optimal parameters for your classifier. Does the performance improve?

# %% [markdown]
# #### 5. Build and cross-validate your decision tree regressor

# %% [markdown]
# #### 6. Gridsearch the optimal parameters for your classifier. Does performance improve?

# %% [markdown]
# ---
#
# ## Part 6: Elastic Net

# %% [markdown]
# #### 1. Gridsearch optimal parameters for an ElasticNet using the regression target and predictors you used for the decision tree regressor.

# %% [markdown]
# #### 2. Is cross-validated performance better or worse than with the decision trees?

# %% [markdown]
# #### 3. Explain why the elastic net may have performed best at that particular l1_ratio and alpha

# %% [markdown]
# ---
#
# ## Part 7: Bagging and Boosting: Random Forests, Extra Trees, and AdaBoost

# %% [markdown]
# #### 1. Load the random forest regressor, extra trees regressor, and adaboost regressor from sklearn

# %% [markdown]
# #### 2. Gridsearch optimal parameters for the three different ensemble methods.

# %% [markdown]
# #### 3. Evaluate the performance of the two bagging and one boosting model. Which performs best?

# %% [markdown]
# #### 4. Extract the feature importances from the Random Forest regressor and make a DataFrame pairing variable names with their variable importances.

# %% [markdown]
# #### 5. Plot the ranked feature importances.

# %% [markdown]
# #### 6.1 [BONUS] Gridsearch an optimal Lasso model and use it for variable selection (make a new predictor matrix with only the variables not zeroed out by the Lasso).

# %% [markdown]
# #### 6.2 [BONUS] Gridsearch your best performing bagging/boosting model from above with the features retained after the Lasso. Does the score improve?

# %% [markdown]
# #### 7.1. [BONUS] Select a threshold for variable importance from your Random Forest regressor and use that to perform feature selection, creating a new subset predictor matrix.

# %% [markdown]
# #### 7.2 [BONUS] Using BaggingRegressor with a base estimator of your choice, test a model using the feature-selected dataset you made in 7.1

# %% [markdown]
# ---
#
# ## [VERY BONUS] Part 8: PCA

# %% [markdown]
# #### 1. Perform a PCA on your predictor matrix

# %% [markdown]
# #### 2. Examine the variance explained and determine what components you want to keep based on them.

# %% [markdown]
# #### 3. Plot the cumulative variance explained by the ordered principal components.

# %% [markdown]
# #### 4. Gridsearch an elastic net using the principal components you selected as your predictors. Does this perform better than the elastic net you fit earlier?

# %% [markdown]
# #### 5. Gridsearch a bagging ensemble estimator that you fit before, this time using the principal components as predictors. Does this perform better or worse than the original?

# %% [markdown]
# #### 6. Look at the loadings of the original predictor columns on the first 3 principal components. Is there any kind of intuitive meaning here?
#
# Hint, you will probably want to sort by absolute value of magnitude of loading, and also only look at the obviously important (larger) ones!

# %% [markdown]
# # [Extremely Bonus] Part 9:  Clustering
#
# ![](https://snag.gy/jPSZ6U.jpg)
#
#  ***Bonus Bonus:***
# This extended bonus question is asking to do something we never really talked about but would like for you to attempt based on the assumptions that we learned during this weeks clustering lesson(s).

# %% [markdown]
# #### 1. Import your favorite clustering module

# %% [markdown]
# #### 2. Encode categoricals

# %% [markdown]
# #### 3. Evaluate cluster metics solely based on a range of K
# If K-Means:  SSE/Inertia vs Silhouette (ie: Elbow), silhouette average, etc

# %% [markdown]
# #### 4.  Look at your data based on the subset of your predicted clusters.
# Assign the cluster predictions back to your dataframe in order to see them in context.  This is great to be able to group by cluster to get a sense of the data that clumped together.

# %% [markdown]
# #### 5. Describe your findings based on the predicted clusters
# _How well did it do?  What's good or bad?  How would you improve this? Does any of it make sense?_
